# %%
from hangul_utils import split_syllables, join_jamos
from khaiii import KhaiiiApi
api = KhaiiiApi()

#요에서 는가 빼줘야됨
요 = ['을까', 'ㄹ까', '지', '으니까', '어', '아', '는데', 'ㄴ가', 'ㄹ게', '래', '잖아', '네', '여', 'ㄹ래', '게', '나', '군', '을게', '다고', '지만', '은데', 'ㄴ지', '는지', '라고', 'ㄴ데', '는걸', '아서', '거든', '더라고', '어서', '려고', '을래', '대', 'ㄴ대', '던데', '더군', '여서', '건가', '어야지', 'ㄹ걸', 'ㄹ께', '아야지', '다면서', '는군', 'ㄴ다고', '은가', '다니', '다면', '실까', '가', '신가', '서', '까']
나머지 = ['습니까', '자', 'ㅂ니까', '야', '라', '에요', '죠', '요', '세요', '니', '려요', '던가요', '나아요', '오', '라서요', 'ㅂ시오', '아라', '구나', '는구나', '냐', '더라', '어야죠', '느냐', '렴', '거에요', '예요', '어라', '다네요', '는가','아야죠']
다 = ['다', '습니다', 'ㅂ니다', '니다', 'ㄴ다', '답니다', '는다', 'ㄴ답니다', 'ㅂ시다', '느냐다', '단다', '서다', '란다', 'ㄴ단다', '시다', '랍니다', '읍시다'] 
yoo_tag = ['VA', 'VX', 'XSA', 'XSV', 'JKQ', 'VCP', 'ZN']


##Use in Changer
def to2lists(input):
    lis_word = []
    lis_tag = []
    analyzed = api.analyze(input)  
    for data in analyzed:
        for morph in data.morphs:
            lis_word.append(morph.lex)
            lis_tag.append(morph.tag)
    return lis_word, lis_tag

## Main Class ## 
class Changer(object):
    
    ## High -> Low ##    
    def low_high(self, stc):
        result = stc

        lis_word, lis_tag = to2lists(result)
        print(lis_word)
        print(lis_tag)
        if lis_tag[-2] == 'EF' and result[-3:-1] != '니다' and result[-3:-1] != '시다' and result[-2] != '요':
            #요를 붙였다 땟다해서 처리가능한 애들
            if lis_word[-2] in 요:
                result = result[:-1] + '요.'
            #다로 끝나는 애들
            elif lis_word[-2] in 다:
                jamo = split_syllables(result[-3])
                #는다 -> 습니다
                if lis_word[-2] == '는다':    
                    result = result[:-3] + '습니다.'
                #이가 숨겨진 경우
                elif lis_word[-3][-1] != result[-3] and lis_tag[-3] == 'VCP':
                    result = result[:-2] + '입니다.'
                #ㄹ,ㄴ 받침 
                elif jamo[-1] == 'ㄹ' or jamo[-1] == 'ㄴ':
                    result = result[:-3] + join_jamos(jamo[:-1]+'ㅂ')+'니다.'
                #받침 없음 -> ㅂ니다
                elif jamo[-1]< 'ㄱ' or jamo[-1]>'ㅎ':
                    result = result[:-3] + join_jamos(jamo+'ㅂ')+'니다.'
                #받침있는 경우
                else:
                    result = result[:-2] + '습니다.'
            #딱히 규칙없는 친구들
            elif lis_word[-2] in 나머지:
                #구나
                if '구나' in lis_word[-2]:
                    result = result[:-len(lis_word[-2])-1] + '네요.'
                #어라, 아라
                elif lis_word[-2] == '아라' or lis_word[-2] == '어라':
                    last_word = result[-(len(lis_word[-3])+len(lis_word[-2])+1):-1]
                    jamo = split_syllables(lis_word[-3])
                    if lis_word[-3]+lis_word[-2] == last_word:
                        if jamo[-1] == 'ㄹ':
                            result = result[:-len(last_word)-1] + join_jamos(jamo[:-1]) + '세요.'
                        elif jamo[-1] >= 'ㄱ' and jamo[-1] <= 'ㅎ':
                            result = result[:-len(last_word)-1] + lis_word[-3] + '으세요.'
                        else:
                            result = result[:-len(last_word)-1] + lis_word[-3] + '세요.'
                    elif result[-3:-1] == '라라':
                        result = result[:-len(last_word)-1] + join_jamos(jamo[:-1]) + '르세요.'
                    else:
                        if jamo[-1] == 'ㄹ':
                            result = result[:-len(last_word)] + join_jamos(jamo[:-1]) + '세요.'
                        elif jamo[-1] >= 'ㄱ' and jamo[-1] <= 'ㅎ':
                            result = result[:-len(last_word)] + lis_word[-3] + '으세요.'
                        else:
                            result = result[:-len(last_word)] + lis_word[-3] + '세요.'
                #렴
                elif lis_word[-2] == '렴':
                    jamo = split_syllables(lis_word[-3])
                    if jamo[-1] == 'ㄹ':
                        result = result[:-3] + join_jamos(jamo[:-1]) + '세요.'
                    else:
                        result = result[:-2] + '세요.'
                #야
                elif lis_word[-2] == '야':
                    result = result[:-2] + '에요.'
                #니 냐 느냐
                elif lis_word[-2] == '니' or lis_word[-2] == '냐' or lis_word[-2] == '느냐' or lis_word[-2] == '는가':
                    result = result[:-len(lis_word[-2])-1] + '나요.'
                #자
                elif lis_word[-2] == '자':
                    result = result[:-2] + '지요.'
                #이거해야됨!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
                elif lis_word[-2] == '더라':
                    jamo = split_syllables(result[-4])
                    if jamo[1] == 'ㅏ' or jamo[1] == 'ㅗ':
                        if result[-4] == '하':
                            result = result[:-3] + '여요.'
                        else:
                            result = result[:-3] + '아요.'
                    else:
                        result = result[:-3] + '어요.'
                #라
                elif lis_word[-2] == '라':
                    jamo = split_syllables(result[-3])
                    if lis_tag[-3] == 'VV':
                        if jamo[-1] <= 'ㅎ' and jamo[-1] >= 'ㄱ':
                            result = result[:-1] + '요.'
                        else:
                            result = result[:-2] + '세요.'
                    elif lis_tag[-3] == 'VCN' or lis_tag[-3] == 'VA' or lis_tag[-3] == 'NNB':
                        reulst = result[:-1] + '요.'
                    elif lis_tag[-3] == 'VX' or lis_tag[-3] == 'XSV':
                        if lis_word[-3] == '달':
                            reulst = result[:-3] + '주세요.'
                        elif jamo[-1] == 'ㄹ':
                            result = result[:-3] + join_jamos(jamo[:-1]) + '세요.'
                        else:
                            reulst = result[:-1] + '요.'
        elif lis_tag[-2] in yoo_tag:
            result = result[:-1] + '요.'
        elif lis_tag[-2] == 'ETN':
            if lis_word[-2] == '음':
                result = result[:-2] + '습니다.'
            elif lis_word[-2] == 'ㅁ':
                jamo = split_syllables(result[-2])
                result = result[:-2] + join_jamos(jamo[:-1]+'ㅂ') + '니다.'
        elif lis_tag[-2] == 'VV':
            if lis_word[-2] == '함' or lis_word[-2] == '줌':
                jamo = split_syllables(result[-2])
                result = result[:-2] + join_jamos(jamo[:-1]+'ㅂ') + '니다.'
            else:
                result = result[:-1] + '요'
        elif lis_tag[-2] == 'EC':
            if lis_word[-2] == '야':
                result = result[:-2] + '에요.'
            elif lis_word[-2] == '니':
                result = result[:-2] + '나요.'
            elif lis_word[-2] == '다':
                jamo = split_syllables(result[-3])
                #는다 -> 습니다
                if lis_word[-2] == '는다':    
                    result = result[:-3] + '습니다.'
                #이가 숨겨진 경우
                elif lis_word[-3][-1] != result[-3] and lis_tag[-3] == 'VCP':
                    result = result[:-2] + '입니다.'
                #ㄹ,ㄴ 받침 
                elif jamo[-1] == 'ㄹ' or jamo[-1] == 'ㄴ':
                    result = result[:-3] + join_jamos(jamo[:-1]+'ㅂ')+'니다.'
                #받침 없음 -> ㅂ니다
                elif jamo[-1]< 'ㄱ' or jamo[-1]>'ㅎ':
                    result = result[:-3] + join_jamos(jamo+'ㅂ')+'니다.'
                #받침있는 경우
                else:
                    result = result[:-2] + '습니다.'
            else:
                result = result[:-1] + '요.'
        return result

    def high_low(self,stc):
        result = stc
        
        lis_word, lis_tag = to2lists(result)
        if lis_tag[-2] == 'EF' and result[-3:-1] == '니다' and result[-3:-1] == '시다' and result[-2] == '요':
            #요를 붙였다 땟다해서 처리가능한 애들
            if lis_word[-2][:-1] in 요:
                result = result[:-1] + '.'
            #니다로 끝나는 애들
            elif lis_word[-2] in 다:
                jamo = split_syllables(result[-3])
                #는다 -> 습니다
        
        
        
        
    
    def processText(self,stc):
        result = stc
        
        flag = 0
#         if result[-1]=='\n':
#             result = result.replace('\n','').strip()
#         if result[-1] =='?' or result[-1] =='.' or result[-1] =='!' or result[-1] =='\"' or result[-1] ==':':
#             result = result
#         else:
#             result = result+'.'
#             flag = 1

        res = self.low_high(result)
        
        if flag ==1:
            res = res[:-1]
    
        return res

# %%
ch = Changer()
  
kr = open('/Users/jeonghui/Desktop/aihub.kr.shuf', "r" , encoding = "utf-8")
high = open('/Users/jeonghui/Desktop/aihub.high.shuf' , "w", encoding = "utf-8")
  
text=kr.readline()
  
while(text != ''):
    text = ch.processText(text)
    high.write(text + "\n")
    text=kr.readline()

kr.close()
high.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3f698ac2c5d2> in <module>
#       1 ch = Changer()
#       2
# ----> 3 kr = open('/Users/jeonghui/Desktop/aihub.kr.shuf', "r" , encoding = "utf-8")
#       4 high = open('/Users/jeonghui/Desktop/aihub.high.shuf' , "w", encoding = "utf-8")
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jeonghui/Desktop/aihub.kr.shuf'

# %%
ch = Changer()
  
kr = open('/Users/jeonghui/Desktop/hgu_clean.kr.shuf', "r" , encoding = "utf-8")
high = open('/Users/jeonghui/Desktop/hgu_clean.high.shuf' , "w", encoding = "utf-8")
  
text=kr.readline()
  
while(text != ''):
    text = ch.processText(text)
    high.write(text + "\n")
    text=kr.readline()

kr.close()
high.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-aeaba2c127e0> in <module>
#       1 ch = Changer()
#       2
# ----> 3 kr = open('/Users/jeonghui/Desktop/hgu_clean.kr.shuf', "r" , encoding = "utf-8")
#       4 high = open('/Users/jeonghui/Desktop/hgu_clean.high.shuf' , "w", encoding = "utf-8")
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jeonghui/Desktop/hgu_clean.kr.shuf'

# %%
ch = Changer()
  
kr = open('/Users/jeonghui/Desktop/aihub.kr.shuf', "r" , encoding = "utf-8")
high = open('/Users/jeonghui/Desktop/변경된친구들_only' , "w", encoding = "utf-8")
high1 = open('/Users/jeonghui/Desktop/변경된안된친구들' , "w", encoding = "utf-8")
  
texts=kr.readline()
  
while(texts != ''):
    text = ch.processText(texts)
    if text != texts[:-1]:
        high.write(text + "\n")
        
    texts=kr.readline()

kr.close()
high.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4ff9fee46db4> in <module>
#       1 ch = Changer()
#       2
# ----> 3 kr = open('/Users/jeonghui/Desktop/aihub.kr.shuf', "r" , encoding = "utf-8")
#       4 high = open('/Users/jeonghui/Desktop/변경된친구들_only' , "w", encoding = "utf-8")
#       5 high1 = open('/Users/jeonghui/Desktop/변경된안된친구들' , "w", encoding = "utf-8")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jeonghui/Desktop/aihub.kr.shuf'

# %%
ch = Changer()
text = '나는 너무 힘듭니다.'
text = ch.processText(text)
print(text)


# ##### 1. rfind로 위치를 찾아서 처리한다.
# 1. lis_tag의 부호를 전부 pop하고 마지막이 EF인지 확인
# 2. EF이면 해당 EF의 마지막글자를 rfind로 result에서 찾음
# 3. 찾은 위치로부터 니다, 시다, 요 인지 확인
# 4. 확인되면 그위치로부터 다 없애고 변환
# ##### 2. 맨뒤의 모든 특수문자를 제거하고 처리한다.
# 1. result의 특수문자 제거 후 따로 저장
# 2. strip로 space 제거
# 3. 원래하던대로 하면됨.

# '' 나 " " < >로 끝나는 경우 영화나 책 제목 일수도?
# Out:
# ['나', '는', '너무', '힘들', 'ㅂ니다', '.']
# ['NP', 'JX', 'MAG', 'VA', 'EF', 'SF']
# 나는 너무 힘듭니다.

# %%
import random
 
a = random.sample(range(0,1141059),30000)

open_file = open('/Users/jeonghui/Desktop/변경된친구들_only', "r" , encoding = "utf-8")
save_file = open('/Users/jeonghui/Desktop/확인하자', "w" , encoding = "utf-8")


for i in range(1141060):
    data = open_file.readline()
    if i in a:
        save_file.write(data)

# %%
kr = open('/Users/jeonghui/Desktop/변경된친구들_only', "r" , encoding = "utf-8")

요 = 0
다 = 0

result=kr.readline()

while(result != ''):
    result = result.replace('\n','')
    if result[-1] =='?' or result[-1] =='.' or result[-1] =='!' or result[-1] =='\"':
        result = result[:-1]
    
    if result[-1] == '요':
        요+=1
    else:
        다+=1
    result=kr.readline()

kr.close()

# %%
print(요)
print(다)
# Out:
# 76139
# 1064920

# %%
kr = open('/Users/jeonghui/Desktop/aihub.khaiii.shuf', "r" , encoding = "utf-8")

요 = 0
다 = 0
까 = 0
나머지 = 0

result=kr.readline()

while(result != ''):
    result = result.replace('\n','')
    if result[-1] =='?' or result[-1] =='.' or result[-1] =='!' or result[-1] =='\"':
        result = result[:-1]
    
    if result[-1] == '요':
        요+=1
    elif result[-1] == '다':
        다+=1
    elif result[-1] == '까':
        까+=1
    else:
        나머지+=1
        
    result=kr.readline()

kr.close()

# %%
print(요)
print(다)
print(까)
print(나머지)
# Out:
# 278222
# 1299808
# 10242
# 14146
