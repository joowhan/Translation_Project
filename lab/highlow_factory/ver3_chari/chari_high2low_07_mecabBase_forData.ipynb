# %%
import matplotlib.pyplot as plt
import numpy as np
import math as mt
import seaborn as sns
from tqdm import tqdm
import pandas as pd
from hangul_utils import split_syllables, join_jamos
from tqdm.auto import tqdm
import re
#from eunjeon import Mecab
from konlpy.tag import Mecab
from hanspell import spell_checker
from khaiii import KhaiiiApi

# %%
con_dict = [
    
    ['ㅏㅣ','ㅐ'], ['ㅑㅣ','ㅒ'], ['ㅓㅣ','ㅔ'],
    ['ㅕㅣ','ㅖ'], ['ㅗㅣ','ㅚ'], ['ㅗㅐ','ㅙ'],
    ['ㅜㅓ','ㅝ'], ['ㅜㅔ','ㅞ'], ['ㅡㅣ','ㅢ'],
    ['ㅣㅏ','ㅑ'], ['ㅣㅓ','ㅕ'], ['ㅣㅗ','ㅛ'],
    ['ㅣㅜ','ㅠ'], ['ㅡㅓ','ㅓ'], ['ㅗㅏ','ㅘ'],
    
]

jongsung_list = [ 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']


#lis_beta = ['EP+EF', 'VCP+EF', 'B+EF', 'B+EP+EF', 'B+VCP+EF', 'EF','EP']

lis_beta = ['EP+EF', 'EF', 'B+EF', 'B+EP+EF']

#어말을 처리해 주기 위한 것으로, 나중에 EC등이 필요해 진다면 이 부분에 EC 등을 집어넣어준다. 참고로 말하자면 이는 마지막에 위치해야한다.
#특이 바로 밑의 이 부분은 형태소 태그가 이 리스트 안의 것과 일치하는 경우 단순 삭제를 하는 것이고
lis_beta_ef = ['EP+EP+EF', 'EP+EF', 'EF', 'UNKNOWN']
lis_beta_ef_h = ['EF', 'UNKNOWN']

#이 부분 같은 경우는 마지막에 오는 것을 처리하는 것으로 단독으로만 들어가는게 좋겠지?
lis_tag_last = ['EF', 'UNKNOWN']

lis_end = [
    
    'ㅅㅡㅂㄴㅣㄷㅏ', 'ㅅㅡㅂㄴㅣㄲㅏ',
    'ㅂㄴㅣㄷㅏ', 'ㄴㅣㄷㅏ', 'ㅂㅅㅣㄷㅏ', 'ㅅㅣㄷㅏ', 'ㄹㄹㅐㅇㅛ','ㄹㅐㅇㅛ',
    'ㅇㅡㅅㅔㅇㅛ', 'ㅅㅔㅇㅛ', 'ㄷㅔㅇㅛ', 'ㅇㅔㅇㅛ', 'ㅇㅖㅇㅛ', 'ㄴㅏㅇㅛ', 'ㅇㅡㄹㄲㅏㅇㅛ', 'ㅇㅣㄹㄲㅏㅇㅛ', 'ㄹㄲㅏㅇㅛ', 'ㅇㅡㄴㄱㅏㅇㅛ', 'ㅇㅣㄴㄱㅏㅇㅛ','ㄱㅜㄴㅇㅛ','ㄴㄱㅏㅇㅛ',
    'ㄱㅗㅇㅛ','ㅇㅛ',
    'ㅈㅛ',
    'ㅅㅣㅂㅅㅣㅇㅗ', 'ㅅㅣㅇㅗ', 'ㅇㅗ',
    'ㅂㄴㅣㄲㅏ',  
    
]
lis_wk = [
    
    ['ㄱㅖ', 'ㅇㅣㅆㅇㅡ'], ['ㅈㅜㅁㅜ','ㅈㅏ'], ['ㅈㅏㅂㅅㅜ','ㅁㅓㄱㅇㅡ']
    
]
lis_end_2low = [
    
    'ㄷㅓㄹㅏ','ㄴㄷㅏ', 'ㅆㄷㅏ', 'ㄹㅗㄷㅏ', 'ㄷㅏ', 'ㄱㅔ', 'ㄴㅡㄴㄷㅏ',
    'ㄹㅏ',
    'ㅇㅑ', 
    'ㄴㅣㄲㅏ', 'ㄲㅏ', 'ㄹㄲㅏ', 'ㅈㅣ',
    'ㄴㅣ', 
    'ㅇㅏ', 'ㅇㅓ',
    'ㄷㅔ', 'ㄱㅏ','ㄹㅐ',
    'ㅈㅏㄶㅇㅏ', 'ㄴㅔ','ㅇㅕ', 'ㄴㅏ','ㄱㅜㄴ','ㄱㅗ',
    'ㅈㅣㅁㅏㄴ', 'ㅇㅡㄴㄷㅔ', 'ㅅㅓ', 'ㄷㅐ',
    'ㄱㅓㄹ','ㄲㅔ', 'ㄴㅑ',
]

lis_ic = ['ㅇㅖ', 'ㄴㅔ', 'ㅇㅏㄴㅣㅇㅗ', 'ㅇㅏㄴㅣㅇㅛ']

# yo = [
#     '을까', 'ㄹ까', '지', '으니까', '어', '아',
#     '는데', 'ㄴ가', 'ㄹ게', '래', '잖아', '네',
#     '여', 'ㄹ래', '게', '나', '군', '을게', '다고',
#     '지만', '은데', 'ㄴ지', '는지', '라고', 'ㄴ데',
#     '는걸', '아서', '거든', '더라고', '어서', '려고',
#     '을래', '대', 'ㄴ대', '던데', '더군', '여서', '건가',
#     '어야지', 'ㄹ걸', 'ㄹ께', '아야지', '다면서', '는군',
#     'ㄴ다고', '은가', '다니', '다면', '실까', '가', '신가',
#     '서', '까'
# ]

P_LIST = ['.', '?', '!', '\'', '\"', 'ᆞ', 'ᆢ', 'ㆍ',  '”', '’',')', '(', ',', '”']

SV_LIST = ['\'', '\"', ':', ';']

lis_plus = [
    
    'EP', 'VCP', 
    
]

# %%
mec = Mecab()
khai = KhaiiiApi()

# %%
def detect_h(input, lis_end_h, lis_end_l):
    for i in lis_end_h:
        if len(input)>=len(i):
            if input[-len(i):]==i:
                return 1
            
    for i in lis_end_l:
        if len(input)>=len(i):
            if input[-len(i):]==i:
                return 0
            
    return -1

def unite(input, dict):
    for i in dict:
        input = re.sub(i[0],i[1],input)
    return input
    
## 자모 단위로 문장을 나누고 합칠 때 쓰는 class ##
class Jamodealer:
    jamo = []
    pp = ''
    #각 단어들을 받아와서 자모단위로 나눈다.
    def __init__(self,lis_word):
    
        self.jamo = []
        for i in lis_word:
            self.jamo.append(split_syllables(i))
    
    ##사전에서 변환된 자모단위로 분리된 문장을 합칠 때 쓰는 함수이다.     
    def make_one(self):
        #list 형태로 저장된 자모들의 집합을 하나의 string pp에 저장한다. 
        self.pp = ''
        for i in self.jamo:
             self.pp= self.pp+i
        ##종성과 종성을 합쳐야 하는 경우가 있다면 합친다.        
        self.pp = unite(self.pp, con_dict)
        
        #자모 단위의 string에서 자모 단위로 사전을 만들고 거기에 index를 부여한다.        
        chars = list(set(self.pp))
        char_to_ix = { ch:i for i,ch in enumerate(chars) }
        ix_to_char = { i:ch for i,ch in enumerate(chars) }
        
        #자모 단위로 분리되었던 문장을 다시 하나로 합친다.
        jamo_numbers = [char_to_ix[x] for x in self.pp]
        restored_jamo = ''.join([ix_to_char[x] for x in jamo_numbers])
        #합쳐진 문장을 return 한다.
        restored_text = join_jamos(restored_jamo)
        return restored_text

def to2lists(input):
    lis_word = []
    lis_tag = []
    #data = han.pos(input,ntags=22,flatten=True, join=False)
    data = mec.pos(input)
    for i in data:
        lis_word.append(i[0])
        lis_tag.append(i[1])
    return lis_word, lis_tag

def to2lists_khaiii(input):
    lis_word = []
    lis_tag = []
    analyzed = khai.analyze(input)  
    for data in analyzed:
        for morph in data.morphs:
            lis_word.append(morph.lex)
            lis_tag.append(morph.tag)
    return lis_word, lis_tag


def rememberSpace(lis, input):
    
    rlis = []
    
    for i in range(len(lis)):
        if lis[i]==input:
            rlis.append(i)
            
    for i in range(len(rlis)):
        rlis[i] = rlis[i]-i      
    return rlis

def convertSpace(lis_space,lis_lis):
    
    rlis = []
    k=0
    for i in range(len(lis_lis)):
        
        if k in lis_space:
            rlis.append(i)
            
        k = k+len(lis_lis[i])
        
    #print(rlis)  
    return rlis

def union(lis, lis_lis):
    
    k = 0
    for i in lis:
        lis_lis.insert(i+k,' ')
        k = k+1

def union_t_03(lis_tag):
    
    for i in range(1, len(lis_tag)):
        if lis_tag[i-1] ==' ' or lis_tag[i]==' ':
            lis_tag[i] = lis_tag[i]
        else:
            lis_tag[i] = '/'+lis_tag[i]
            
def union_w_03(lis_w, lis_tag):
    
    for i in range(1, len(lis_w)):
        if lis_tag[i]==' SF':
            lis_w[i] = ' '+lis_w[i+1]
def proc_khaiii_with_Tag(input):
    
    r_sen = input
    
    res1 = ''
    res2 =''
    slis = []
    for i in range(len(input)):
        if r_sen[i]==' ':
            slis.append(1)
        elif r_sen[i]=='  ':
            slis.append(2)
            
    wlis = r_sen.split(' ')
    
    uu = khai.analyze(wlis[0])
    
    elem = ''
    tag =''
    
    for data in uu[0].morphs:
        elem = elem + data.lex+'/'
        tag = tag+data.tag+'/'
    
    res1 = res1+elem
    res2 = res2+tag
    
    for i in range(len(slis)):
        elem = ''
        tag = ''
        elem = elem+slis[i]*' '
        if i != len(wlis)-1:
            uu = khai.analyze(wlis[i+1])
            for data in uu[0].morphs:
                elem = elem+data.lex+'/'
                tag = tag+data.tag+'/'
        res1 = res1+elem
        res2 = res2+tag
    return res1,res2

# %%
def prepro_khaiii(input):
    lis_w, lis_t = to2lists_khaiii(input)

    space_list = rememberSpace(input,' ')
    space_location = convertSpace(space_list, lis_w)
    union(space_location, lis_w)
    union(space_location, lis_t)
    union_t_03(lis_t)
    union_w_03(lis_w, lis_t)
    
    str_w = ''
    str_t = ''
    for i in range(len(lis_w)):
        str_w = str_w + lis_w[i]
        str_t = str_t + lis_t[i]
    
    data_w = str_w.split(' ')
    data_t = str_t.split(' ')
    
    lis_word, lis_tag = to2lists_khaiii(input)
    
    lis_ind = []
    t_ind = 0
    jam1 = Jamodealer(lis_word)
    jam2 = Jamodealer(data_w)
    for i in range(len(data_w)):
        element = []
        leng = len(data_t[i].split('/'))
        res = jam2.jamo[i]
        ind = 0
        lenlen = 0
        #element.append(0)
        for j in range(leng):
            element.append(ind)
            ind = ind + len(jam1.jamo[t_ind])
            res = res[len(jam1.jamo[t_ind]):]
            
            lenlen = len(jam1.jamo[t_ind])+lenlen
            t_ind = t_ind+1

        element.append(len(jam2.jamo[i]))
        lis_ind.append(element)
        
    return data_w, data_t, lis_ind

# %%
def prepro_beta_khaiii(input, lis_ef, tag_last, lis_w_last, lis_w_last_not):
    data_w, data_t, lis_ind = prepro_khaiii(input)
    
    last_words = []

    data_w_jamo = []

    data_t_after = []
    
    lis_target_ind = []
    
    for i in data_w:
        jam_ele = Jamodealer(i)
        ele = ''
        for j in jam_ele.jamo:
            ele = ele+j
        data_w_jamo.append(ele)
    
    for i in range(len(data_t)):
        #if i<len(data_t)-1:
        if i<len(data_t):
            lis_res = []
            for ind in range(len(lis_ind[i])-1):
                lis_res.append(data_w_jamo[i][lis_ind[i][ind]:lis_ind[i][ind+1]])

        
        if 'EF/SF' in data_t[i] or 'EF/SV' in data_t[i] or 'UNKNOWN/SF' in data_t[i] or 'UNKNOWN/SV' in data_t[i]:# and 'EC/SF' not in data_t[i]:
            if 'EF/SF' in data_t[i] or 'UNKNOWN' in data_t[i]:
                elements = data_t[i].split('/')
                flag = 0

                for j in range(len(elements)):
                
                    flag_end = detect_h(lis_res[j], lis_w_last,  lis_w_last_not)

                    if elements[j] in lis_ef and flag_end==1: #and j == len(elements)-1:

                        elements[j] = 'NULL'
                    
                        last_words.append(data_w_jamo[i][lis_ind[i][j]:lis_ind[i][j+1]])
                        lis_res[j]=''
                    
                        lis_target_ind.append(i)
                    
#                         elements_post = '/'.join(elements)
#                         data_t_after.append(elements_post)
                        
                    elif 'EF' in elements[j] and flag_end==1:# + EF를 처리하는 부분이므로 + EF 만을 마지막에서 처리한다.
                        for jam in lis_w_last:
                            if len(lis_res[j])>=len(jam):

                                res_out_punc = lis_res[:lis_ind[i][-2]][j]

                                if res_out_punc[-len(jam):]==jam:

                                    #print(jam)
                                    lis_target_ind.append(i)
                                
                                    last_words.append(jam)
                                    lis_res[j] = lis_res[j].replace(jam, '', 1)

                                    for k in tag_last:

                                        if k in elements[j]:
                                        
                                            if '+' in elements[j]:
                                            
                                                ind = elements[j].index('+'+k)
                                                elements[j] = elements[j][:ind]
                                    break
                                
                                elif lis_w_last.index(jam)==len(lis_w_last)-1:#new
                                    for k in tag_last:

                                        if k in elements[j]:
                                        
                                            if '+' in elements[j]:
                                            
                                                ind = elements[j].index('+'+k)
                                                elements[j] = elements[j][:ind]
                                            
                                    lis_target_ind.append(i)
                                    last_words.append('')
                                    break

                
                elements_post = '/'.join(elements)
                data_t_after.append(elements_post)
                
                data_w_jamo[i] = ''.join(lis_res)

                #elements_post = '/'.join(elements)
                #data_t_after.append(elements_post)
                    
            #######################################
            
            #data_t_after.append(data_t[i])
            
        elif 'EC/SF' in data_t[i] or 'JX/SF' in data_t[i]:
            #print('ee')
            elements = data_t[i].split('/')
            
            flag = 0
            for j in range(len(elements)):
                
                flag_end = -1
                if 'EC' in elements[j] or 'JX' in elements[j]:
                    flag_end = detect_h(lis_res[j], lis_w_last, lis_w_last_not)

                #print(flag_end)
                if flag_end==1 and i not in lis_target_ind:
                    for jam in lis_w_last:

                        if len(jam)<=len(lis_res[j]):
                            #print(lis_res[j])
                            if lis_res[j][-len(jam):]==jam:

                                last_words.append(jam)
                                lis_res[j] = lis_res[j].replace(jam, '', 1)
                                #print(lis_res[j])
                    lis_target_ind.append(i)
                    #last_words.append('')
            data_t_after.append(data_t[i])
            data_w_jamo[i] = ''.join(lis_res)
        ####### #######
            
        else:
            data_t_after.append(data_t[i])
            
    
    
        lis_normal = []
    
        for i in data_w_jamo:
            jam_n = Jamodealer(i)
            lis_normal.append(jam_n.make_one())
    
        
        
    for i in range(len(lis_target_ind)):
        if 'ㅅㅔㅇㅛ' == last_words[i] or 'ㄹㄹㅐㅇㅛ' == last_words[i]:
            
            for wk in lis_wk:
                #print(data_w_jamo[lis_target_ind[i]][-len(wk[0])-1:-1])
                if data_w_jamo[lis_target_ind[i]][-len(wk[0])-1:-1] ==wk[0]:
                    #print('rrrr')
                    ele = data_w_jamo[lis_target_ind[i]][:-len(wk[0])-1]
                    ele = ele + wk[1]
                    ele = ele + data_w_jamo[lis_target_ind[i]][-1]
                    data_w_jamo[lis_target_ind[i]] = ele
                    
                    break
        
    return data_w, data_t, lis_ind, data_w_jamo, data_t_after, last_words, lis_target_ind

# %%
def prepro_ch03(input, lis_ef, tag_last, lis_w_last, lis_w_last_not, lis_ic):
    
    lis_res_word = []
    
    lis_input = input.split()
    lis_word = []
    lis_tag = []
    lis_last_word = []
    lis_ind = []
    
    lis_result = []
    
    for i in range(len(lis_input)):
        ele_w = []
        ele_t = []
        
        an = mec.pos(lis_input[i])
        for j in range(len(an)):
            ele_w.append(an[j][0])
            ele_t.append(an[j][1])
        elem_w = ' '.join(ele_w)
        elem_t = '/'.join(ele_t)
        
        jam_pre = Jamodealer(elem_w)
        lis_word.append(''.join(jam_pre.jamo))
        lis_tag.append(elem_t)
    
    for i in range(len(lis_tag)):
        
        if 'EF/SF' in lis_tag[i] or 'EF/SV' in lis_tag[i] or 'EF/SC' in lis_tag[i] or 'JX/SF' in lis_tag[i] or 'JX/SC' in lis_tag[i] or 'IC' in lis_tag[i] or 'IC' in lis_tag[i] or (('NP' in lis_tag[i] or 'NNG' in lis_tag[i]) and ('ㅈㅓ' in lis_word[i] or 'ㅈㅔ' in lis_word[i] or 'ㄷㅏㅇㅅㅣㄴ' in lis_word[i])):
            elemen_t = lis_tag[i].split('/')
            elemen_w = lis_word[i].split(' ')
            flag = 0
            
            
            for j in range(len(elemen_t)):

                flag_end = detect_h(elemen_w[j], lis_w_last_not, lis_w_last)

                
                if (flag_end == 1 and 'EF' in elemen_t[j]) or (flag_end == 1 and 'JX' in elemen_t[j]):
                    
                    for jam in lis_w_last_not:
                        
                        if len(elemen_w[j])>=len(jam):
                            
                            if elemen_w[j][-len(jam):]==jam:
                                
                                
                                lis_ind.append(i)
                                lis_last_word.append(jam)
                                elemen_w[j] = elemen_w[j][:-len(jam)]
                                elemen_w[j] = elemen_w[j] + '__+__'
                                
                                break
                                
#                 elif 'IC' in elemen_t[j] or 'IC' in elemen_t[j]:
                    
#                     for ii in lis_ic:
                        
#                         if len(elemen_w[j])>=len(ii):
                            
#                             if elemen_w[j][-len(ii):]==ii:
                                
                                
#                                 lis_ind.append(i)
#                                 lis_last_word.append(ii)
#                                 elemen_w[j] = elemen_w[j][:-len(ii)]
#                                 elemen_w[j] = elemen_w[j] + '__+__'
                                
#                                 break
                                
                elif (('NP' in lis_tag[i] or 'NNG' in lis_tag[i]) and ('ㅈㅓ' in lis_word[i] or 'ㅈㅔ' in lis_word[i] or 'ㄷㅏㅇㅅㅣㄴ' in lis_word[i])) or ('IC' in lis_tag[i] and('ㄴㅔ' in lis_word[i] or 'ㅇㅏㄴㅣㅇㅛ' in lis_word[i])):
                    
                    jam1 = Jamodealer(elemen_w)
                    s = jam1.make_one()

                    key_u = 0

                    ss = proc_khaiii_with_Tag(s)
                    tagt = ss[1].split('/')[:-1]
                    wordw = ss[0].split('/')[:-1]

                    for u in range(len(tagt)):
                        if tagt[u]=='NP':
                            if wordw[u]=='저' or wordw[u]=='제':
                                key_u = 1
                            elif wordw[u]=='당신':
                                key_u = 2
                        elif tagt[u]=='IC':
                            if wordw[u]=='네':
                                key_u = 3
                        elif tagt[u]=='VCN' or tagt[u]=='IC':
                            if wordw[u][:2]=='아니':
                                key_u = 4
            
                    flag = 0
                    for ind in range(len(elemen_t)):
                        #print(elemen_w[ind])
                        if flag==0 and key_u>0:

                            if key_u == 1:

                                if elemen_t[ind][:2]=='NP' or elemen_t[ind][:3]=='NNG':
                                    
                                    if elemen_w[ind][:2] == 'ㅈㅓ':
                                        
                                        elemen_w[ind] = 'ㄴㅏ' + elemen_w[ind][2:]
                                        flag = 1

                                    elif elemen_w[ind][:2] == 'ㅈㅔ':

                                        elemen_w[ind] = 'ㄴㅐ' + elemen_w[ind][2:]
                                        flag = 1
                            
                            elif key_u==2:
                                if len(elemen_w[ind])>=6:
                                    if elemen_w[ind][:6] == 'ㄷㅏㅇㅅㅣㄴ':

                                        elemen_w[ind] = 'ㄴㅓ' + elemen_w[ind][6:]
                                        flag = 1
                                        if len(elemen_t)-1 >ind:
                                            if elemen_t[ind+1] == 'JX' or elemen_t[ind+1] == 'JKS' or elemen_t[ind+1] == 'JKO':
                                                if elemen_w[ind+1] == 'ㅇㅡㄹ':
                                                    elemen_w[ind+1] = 'ㄹㅡㄹ'
                                                elif elemen_w[ind+1] == 'ㅇㅡㄴ':
                                                    elemen_w[ind+1] = 'ㄴㅡㄴ'
                                                elif elemen_w[ind+1] == 'ㅇㅣ':
                                                    elemen_w[ind+1] = 'ㄱㅏ'
                                                    
                            elif key_u==3:
                                if len(elemen_t)>1:
                                    
                                    if elemen_t[1]=='SC' or elemen_t[1]=='SF':
                                        if elemen_w[ind][:2] == 'ㄴㅔ':
                                        
                                            elemen_w[ind] = 'ㅇㅡㅇ' + elemen_w[ind][2:]
                                            flag = 1
                            else:
                                if elemen_t[ind][:2] == 'IC':

                                    if elemen_w[ind][4:6] == 'ㅇㅛ':

                                        elemen_w[ind] = elemen_w[ind][:4] + elemen_w[ind][6:]

                                        flag = 1

                    
                                
            res_w = ''.join(elemen_w)
            lis_result.append(res_w)
                                
        else:
            
            rere = lis_word[i].split(' ')
            
            resres = ''.join(rere)
            
            lis_result.append(resres)
            
            
    return lis_result, lis_tag, lis_ind, lis_last_word

# %%
# tt = '아프간 내전에서 저는 눈을 잃었고 제재에 걸려 제 돈을 잃었고 저의 마음은 큰 상처를 받았죠. 전을 먹고싶었어요. 김치전, 부추전, 다 내가 좋아하는 전인데.'
#tt = "제가 당신을 미워했지만, 저의 큰 마음이 당신을 용서했어요. 당신은 정신이 이상하지만 당신을 이해할게요. 당신이 정신이 없는 사람이야 당신."
tt = '전 너무 힘듭니다.당신은 누구십니까?'
print(prepro_ch03(tt, lis_beta_ef, lis_tag_last, lis_end_2low, lis_end, lis_ic))
# Out:
# (['ㄴㅏㄴ', 'ㄴㅓㅁㅜ', 'ㅎㅣㅁㄷㅡ__+__.ㄴㅓㄴㅡㄴ', 'ㄴㅜㄱㅜㅅㅣ__+__?'], ['NNG', 'MAG', 'VA+EF/SF/NP/JX', 'NP/VCP+EP+EF/SF'], [2, 3], ['ㅂㄴㅣㄷㅏ', 'ㅂㄴㅣㄲㅏ'])

# %% [markdown]
# #### Dictionary and Convert Flow

# %%
######높임말 -> 반말
#현재 만들어진 것은 EF만 잘라낼 것이다. 
#원래 ef사전에 mapping 되는 것을 찾아낸다.
#python dictionary로 접근
#종결어미 처리
EF = {
    ###하십시오체###
    #평서문
    #'ㅂㄴㅣㄷㅏ': 'ㄷㅏ',
    'ㅂㄴㅣㄷㅏ': 'special3',
    'ㅅㅡㅂㄴㅣㄷㅏ':'special2',
    'ㅇㅗㄹㅅㅣㄷㅏ':'ㄷㅏ', #**
    'ㅂㅈㅣㅇㅛ':'지', #**
    'ㅅㅣㅂㄴㅣㄷㅏ':'special1',
    'ㅇㅡㅅㅣㅂㄴㅣㄷㅏ':'ㅇㅡㅅㅣㄴㄷㅏ',
    'ㅇㅡㅅㅣㅂㄴㅣㄲㅏ':'ㅇㅡㅅㅣㄴㅣ',

    #의문문
    'ㅅㅡㅂㄴㅣㄲㅏ':'ㄴㅣ',
    'ㅂㄴㅣㄲㅏ': 'ㄴㅣ',
    'ㅅㅣㅂㄴㅣㄲㅏ':'special1', #EP+EF
    #명령법
    'ㅇㅡㅅㅔㅇㅛ': 'special0',
    'ㅅㅔㅇㅛ':'special1',
    'ㅅㅣㅇㅓㅇㅛ': 'special1',
    'ㅅㅣㅂㅅㅣㅇㅗ':'ㅅㅣㅇㅗ',
    #청유법
    'ㅂㅅㅣㄷㅏ':'special4',
    'ㅇㅡㅂㅅㅣㄷㅏ':'special4',
    ###하오체###
    
    ###해요체###
    #평서문
    'ㅇㅓㅇㅛ':'ㅇㅓ',
    'ㅇㅏㅇㅛ':'ㅇㅏ',
    'ㅈㅛ':'ㅈㅣ',
    'ㅇㅔㅇㅛ':'ㅇㅑ',
    'ㅇㅖㅇㅛ':'ㅇㅑ',
    'ㅇㅛ':'special5',
    'ㄷㅐㅇㅛ':'ㄷㅐ',
    'ㄷㅔㅇㅛ':'ㄷㅔ',
    'ㄴㅔㅇㅛ':'ㄴㅔ',
    'ㄴㅡㄴㄷㅔㅇㅛ':'ㄴㅡㄴㄷㅔ',
    'ㄱㅓㄷㅡㄴㅇㅛ':'ㄱㅓㄷㅡㄴ',
    'ㄱㅜㄴㅇㅛ': 'ㄱㅜㄴㅏ',
    'ㅇㅡㄴㄷㅔㅇㅛ':'ㅇㅡㄴㄷㅔ',
    'ㅈㅏㄱㅜㅇㅛ':'ㅈㅏㄱㅜ',
    'ㄴㅣㄲㅏㅇㅛ': 'ㄴㅣㄲㅏ',
    'ㅈㅣㅇㅛ':'ㅈㅣ',
    
    #의문문
    'ㄴㅏㅇㅛ':'special6',
    'ㄹㄲㅏㅇㅛ':'ㄹㄲㅏ',
    'ㅇㅡㄹㄲㅏㅇㅛ':'ㅇㅡㄹㄲㅏ',
    'ㄴㄱㅏㅇㅛ':'ㄴㄱㅏ',
    'ㄹㄹㅐㅇㅛ':'ㄹㄹㅐ',
    'ㄹㅐㅇㅛ':'ㄹㅐ',
    'ㄱㅗㅇㅛ':'ㄱㅗ',
    'ㅇㅡㄴㄱㅏㅇㅛ':'ㅇㅡㄴㄱㅏ',
    'ㅇㅣㄴㄱㅏㅇㅛ':'ㅇㅣㄴㄱㅏ',
}
need_origin_EF = {
    'ㅂㅅㅣㄷㅏ':'ㅈㅏ',
}
#'ㄹ'규칙 활용 -> ㄹ 규칙 활용이 일어나는 동사들을 최대한 모아두고, 만약 하나의 단어에 여러 의미가 담긴다면?
EF_R_rule= {
    'ㄱㅜ':'ㄹ',
    'ㄴㅗ':'ㄹ',
    'ㄴㅏ':'ㄹ',
    'ㄷㅗ':'ㄹ',
    'ㄷㅡ':'ㄹ',
    'ㄷㅏ':'ㄹ',
    'ㄷㅜ':'ㄹ',
    'ㅂㅜ':'ㄹ',
    'ㄲㅗ':'ㄹ',
    'ㅁㅣ':'ㄹ',
    'ㅁㅜ':'ㄹ',
    #'ㅂㅗㅍㅜ':'ㄹ', #error predicate 수정
    'ㅂㅜ':'ㄹ',
    'ㅅㅡ':'ㄹ',
    'ㄸㅓ':'ㄹ',   
}

def treatSF(stc, ex):
    ind_point = -1
    point = ''
    
    # for i in range(len(stc)):
    #     if stc[i] in P_LIST:
    #         point = stc[i]
    #         break
            
    # if point in P_LIST:
    #     ind_point = stc.index(point)
    # print('uhyo',stc)
    if '__+__' in stc:
        ind_point = stc.index('__+__')
        stc = stc.replace('__+__', '', 1)
    
    r_word = ''
    r_pun = ''
    
    if ind_point!=-1:
        r_word = stc[:ind_point]
        r_pun = stc[ind_point:]
    else:
        r_word = stc
    return r_word+ex+r_pun

def delete_EP_si(stn, taglist):
    si = stn[-3:-1]
    eusi = stn[-5:-1]
    check_si = taglist[-11:-2]
    #@
    
    result =''
    flag = 0
    if taglist.find('SF') !=-1:
        if (eusi =='ㅇㅡㅅㅣ') and (check_si.find('EP+EP')!=-1 or check_si.find('EP/NULL')!=-1):
            result = stn[:-5]+stn[-1]
            flag = 1
        elif (si =='ㅅㅣ') and (check_si.find('/EP/')!=-1):
            #@
            #print('alalalalal')
            result = stn[:-3]+stn[-1]
            #print('s')

    return result, flag

def check_VV_VA(sentence, tag):
    #t= tag[-9:-3]
    #print(t, tag)
    tt = tag.split('/SF')
    t= tt[0][-6:]
    if 'VV' in t or 'VX' in t or 'XSV' in t or ('VV/EP' in tag and 'ㅅㅣ' in sentence[-5:-1]) :
        return 1
    elif 'VA' in t:
        return 0
    else:
        return -1
def detach_endmark(sentence):
    endmark = sentence[-6:-1]
    #print(sentence, endmark)
    if endmark == '__+__':
        sentence = sentence[:-6]+sentence[-1]
    else:
        endmark = -1
    return sentence, endmark
def attach_endmark(sentence):
    endmark = '__+__'
    sentence = sentence[:-1]+endmark+sentence[-1]
    return sentence

## 'ㅏ', 'ㅗ' 처리
def convertSpecialCase_AhOh(stc):
    #print(sentence[-1][-2:])
    #print(sentence[-1][-4:])
    ## 수정할 필요 있음!
    #danger
    sentence, endmark = detach_endmark(stc)
    if sentence[-3:-1] == 'ㅍㅡ' or sentence[-3:-1] == 'ㅃㅡ':
        if sentence[-5:-3].find('ㅏ') !=-1 or sentence[-5:-3].find('ㅗ')!=-1:
            return 'ㅏ'
        else:
            return 'ㅓ'
    elif sentence[-3:].find('ㅏ') !=-1 or sentence[-3:].find('ㅗ') !=-1:
        return 'ㅇㅏ'
    else:
        return 'ㅇㅓ'
def treatFormal_vv(sentence):
    formal_vv ={
        'ㄱㅖ':'ㅇㅣㅆㅇㅡ',
        'ㅈㅜㅁㅜ':'ㅈㅏ',
        'ㅈㅏㅂㅅㅜ':'ㅁㅓㄱㅇㅡ'
    }
    for key in formal_vv:
        if sentence.find(key) !=-1:
            sentence = sentence.replace(key,formal_vv[key])
    return sentence
def check_NoRule(stem,predicate):
    #this is temp function. Need to modify this function
    if predicate.find('ㅓ') !=-1:
        #print(stem+predicate)
        if (stem+predicate) =='ㄱㅡㄹㅓ':
            return 'ㅐ'
    else:
        return ''
#'ㅇㅗㄹㅡ'
def convertSpecialCase_SaeYo(stc, ending, tag):
    result = ''
    end_EF=''
    final=''
    sentence, endmark = detach_endmark(stc)
    #print(endmark)
    pun = sentence[-1:]
    predicate = sentence[-3:-1]
    stem = sentence[:-3]
    isVcp = tag[-12:]
    #print(sentence, ending, tag, predicate)
    #만약 VCP가 있다면 '야'를 붙이고 return 한다.
    if isVcp.find('VCP/EP+EF') != -1 or isVcp.find('VCP+EP+EF') !=-1:
        final = 'ㅇㅑ'
        if endmark !=-1: # 문장에 __+__가 있었으면
            sentence = attach_endmark(sentence)
        converted = treatSF(sentence, final)
        return converted
    # 'ㄹ'규칙 활용
    elif predicate in EF_R_rule:
        result= EF_R_rule[predicate]
        #sentence[-1] += result
        ##'아' 또는 '어' 로 처리
        end_EF = convertSpecialCase_AhOh(sentence)
        #sentence.append(end_EF)
        final = result +end_EF
        #print(final)
    #'르' 불규칙 활용
    elif predicate =='ㄹㅡ':
        # 용언 종성에 ㄹ이 있다면
        #sentence[-1] = sentence[-1].replace('ㄹㅡ','')
        predicate = predicate.replace('ㄹㅡ','')
        sentence = stem+predicate + pun
        end_EF = convertSpecialCase_AhOh(sentence)
        end_EF = end_EF[-1]
        #print(end_EF, sentence, 'sss')
        if sentence[-1].find('ㄹ') != -1:
            final = 'ㄹ'+end_EF
        else:
            final  = 'ㄹㄹ'+end_EF
        
    #'우' 불규칙 활용
    # '푸'를 제외한 다른 'ㅜ'는 'ㅓ'와 결합
    elif predicate.find('ㅍㅜ') !=-1:
        #sentence[-1] = sentence[-1].replace('ㅜ','ㅓ')
        predicate = predicate.replace('ㅜ','')
        sentence = stem+predicate + pun
        final = 'ㅓ'
        #final = sentence[-1][-1:]
    #'오' 불규칙 활용(고려하지 않을 수 있음)
    #'하' 불규칙 활용
    elif predicate.find('ㅎㅏ') !=-1:
        #sentence[-1] = sentence[-1].replace('ㅏ','ㅐ')
        predicate = predicate.replace('ㅏ','')
        sentence = stem + predicate + pun
        final = 'ㅐ'
    #활용이 안되었던 용언 처리
    else:
        if predicate.find('ㅡ') !=-1:
            end_EF = convertSpecialCase_AhOh(sentence)
            #sentence[-1] = sentence[-1].replace('ㅡ',end_EF)
            predicate = predicate.replace('ㅡ','')
            sentence = stem + predicate + pun
            #print(sentence, '처리후')
            final = end_EF[-1]
        ## 수정할 필요 있음!!
        elif predicate.find('ㅗ') !=-1:
            #sentence[-1] = sentence[-1].replace('ㅗ','ㅘ')
            predicate = predicate.replace('ㅗ','')
            sentence = stem+predicate+ pun
            final = 'ㅘ'
        elif predicate.find('ㅜ') !=-1:
            #sentence[-1] = sentence[-1].replace('ㅜ','ㅝ')
            predicate = predicate.replace('ㅜ','') 
            sentence = stem + predicate+ pun
            final = 'ㅝ'
        elif predicate.find('ㅣ') !=-1:
            #sentence[-1] = sentence[-1].replace('ㅣ','ㅕ')
#             if predicate == 'ㅇㅣ':
#                 sentence = sentence.replace('ㅇㅣ','')
            predicate = predicate.replace('ㅣ','')
            sentence = stem+predicate+ pun
            final = 'ㅕ'
        else:
            final = convertSpecialCase_AhOh(sentence)
            #sentence = sentence.append(final)
            if  predicate.find('ㅏ') !=-1:
                final = ''
            elif  predicate.find('ㅓ') !=-1:
                final = check_NoRule(stem,predicate)
                #print(sentence)
                if final != '':
                    ind = sentence.rfind('ㅓ')
                    sentence = sentence[:ind]+sentence[ind+1:]
                    #print(sentence,'a')
            elif  predicate.find('ㅐ') !=-1:
                final = ''
#                 return final, sentence
#             return final, sentence
#     return final, sentence
    if endmark !=-1: # 문장에 __+__가 있었으면
        sentence = attach_endmark(sentence)
    converted = treatSF(sentence, final)
    #print(converted)
    return converted
    
def convertSpecialCase_Da(stc, ending, taglist):
    #print(sentence, ending, taglist)
    sentence, endmark = detach_endmark(stc)
    final =''
    isEp = sentence[-2:-1]
    if (isEp == 'ㅆ' or sentence.find('ㅇㅏㄶ') !=-1)and (taglist.find('VV/EF') !=-1 or taglist.find('VX/EF') !=-1):
        final = 'ㄷㅏ'
    elif taglist.find('EP/EF') !=-1 or taglist.find('VA/EF') !=-1 or taglist.find('VX/EF') !=-1:
        #print('다로 변경할 것')
        final = 'ㄷㅏ'
    elif taglist.find('VV/EF') !=-1:
        final = 'ㄴㅡㄴㄷㅏ'
    elif taglist.find('VV') !=-1:
        #print('현재형 동사가 왔으므로, 는다로 변경할 것')
        final = 'ㄴㅡㄴㄷㅏ'
    if endmark !=-1: # 문장에 __+__가 있었으면
        sentence = attach_endmark(sentence)
    converted = treatSF(sentence, final)
    return converted

#def convertSpecialCase_Nida(sentence, ending, taglist, kh_stn, kh_end, kh_tag):
def convertSpecialCase_Nida(sentence, ending, taglist):
    #print(sentence, ending, taglist)
    #시가 있으면 ㄴ다를 붙인다. 
    #형용사, 서술격 조사일 경우 convertSpecialCase_SaeYo를 통해 변경한 다음, 아/어를 제거 후 다를 붙이고
    #동사일 경우 ㄴ다를 붙여서 해결한다. 
    predicate = check_VV_VA(sentence, taglist)
    #VV
    if predicate == 1:
        final = 'ㄴㄷㅏ'
        converted = treatSF(sentence, final)
    #VA
    #형용사의 경우, 세요를 거친 후 마지막을 붙인다면 이상해질 수 있다. 그냥 khaiii를 쓰는 것이 안전하다고 판단된다. 
    elif predicate == 0:
        final = 'ㄷㅏ'
        #print(treatSF(sentence,ending))
        temp=treatSF(sentence,ending)
        jam1 = Jamodealer(temp)
        s = jam1.make_one()
        #print(temp, taglist)
        converted_kh = proc_khaiii(s)
        converted_kh = converted_kh.replace('ㅂ니다', '__+__')
        #print(converted_kh)
        converted = treatSF(converted_kh, final)
    else:
        final = 'ㄷㅏ'
        converted = treatSF(sentence, final)
    return converted
def convertSpecialCase_Yo(stc, ending, tag):
    sentence, endmark = detach_endmark(stc)
    pun = sentence[-1:]
    predicate = sentence[-3:-1]
    stem = sentence[:-3]
    isVcp = tag[-11:]
    #@
    # print(sentence, ending, pun, predicate, stem, isVcp)
    temp =''
    ni = 0
    after_si, ni = delete_EP_si(sentence, tag)
    # print(after_si, ni)
    if after_si != '':
        sentence = after_si
        after_si =''
    
    if isVcp.find('VCP') != -1:
        final = 'ㅇㅑ'
    #temporary condition(일시적으로 넣어둔 오류 문장 처리 기능 -> 에요)
    # elif sentence[-3:-1]=='ㅇㅔ':
    #     sentence = sentence[:-3]+pun
    #     final = 'ㅇㅑ'
    else:
        final = ''
    
    if endmark !=-1: # 문장에 __+__가 있었으면
        sentence = attach_endmark(sentence)
    
    converted = treatSF(sentence, final)
    return converted
def convertSpecialCase_NaYo(sentence, ending, taglist):
    #print(sentence, ending, taglist)
    final ='ㄴㅣ'
    if taglist.find('/VCP+EF/') !=-1:
        final='ㄴㅏㄴㅣ'
    converted = treatSF(sentence, final)
    return converted

##if Verb & adjective
## '-시' 등 선어말 처리
## 습니다는 동사면 '는다', 그외에는 '다'로 간다
def rememberSpace_k(lis, input):
    
    rlis = []
    
    for i in range(len(lis)):
        if lis[i]==input:
            rlis.append(i)
            
    for i in range(len(rlis)):
        rlis[i] = rlis[i]-i      
    return rlis

def convertSpace_k(lis_space,lis_lis):
    
    rlis = []
    k=0
    for i in range(len(lis_lis)):
        
        if k in lis_space:
            rlis.append(i)
            
        k = k+len(lis_lis[i])
        
    #print(rlis)  
    return rlis

def proc_khaiii(input):
    
    r_sen = input
    
    res = ''
    slis = []
    for i in range(len(input)):
        if r_sen[i]==' ':
            slis.append(1)
        elif r_sen[i]=='  ':
            slis.append(2)
            
    wlis = r_sen.split(' ')
    
    uu = khai.analyze(wlis[0])
    
    elem = ''
    
    for data in uu[0].morphs:
        elem = elem + data.lex
    
    res = res+elem
    
    for i in range(len(slis)):
        elem = ''
        elem = elem+slis[i]*' '
        if i != len(wlis)-1:
            uu = khai.analyze(wlis[i+1])
            for data in uu[0].morphs:
                elem = elem+data.lex
        res = res+elem
    return res

def proc_khaiii_with_Tag(input):
    
    r_sen = input
    
    res1 = ''
    res2 =''
    slis = []
    for i in range(len(input)):
        if r_sen[i]==' ':
            slis.append(1)
        elif r_sen[i]=='  ':
            slis.append(2)
            
    wlis = r_sen.split(' ')
    
    uu = khai.analyze(wlis[0])
    
    elem = ''
    tag =''
    
    for data in uu[0].morphs:
        elem = elem + data.lex+'/'
        tag = tag+data.tag+'/'
    
    res1 = res1+elem
    res2 = res2+tag
    
    for i in range(len(slis)):
        elem = ''
        tag = ''
        elem = elem+slis[i]*' '
        if i != len(wlis)-1:
            uu = khai.analyze(wlis[i+1])
            for data in uu[0].morphs:
                elem = elem+data.lex+'/'
                tag = tag+data.tag+'/'
        res1 = res1+elem
        res2 = res2+tag
    return res1,res2

# %%
class Changer(object):
    
    #def make_end_low(self, sentence, ending, taglist, kstn, kend, ktag):
    def convert_EF(self, sentence, taglist, ending):
        re_value =''
        temp =''
        ni = 0
        flag = 0
        
        #존칭 동사 또는 보조 동사를 파악하고 이를 변환 전에 미리 바꿔주어야 한다. 
        for key in EF:
            if ending == key:
                flag = 1
                re_value = EF[key]
                #나요, 으세요(으세요, 세요 모두 함수에서 커버 가능), 습니까 case
                if re_value == 'special0':
                    #시처리하기
                    after_si, ni = delete_EP_si(sentence, taglist)
                    if after_si != '':
                        sentence = after_si
                        after_si =''
                    temp = convertSpecialCase_AhOh(sentence)
                    re_value = treatSF(sentence, temp)
                    #ㅗ,ㅜ 이면 ㅘ, ㅝ로 결합할 것
                    #print(re_value)
                #-세요,십니다, 십니까
                elif re_value == 'special1':
                    #시처리하기
                    after_si, ni = delete_EP_si(sentence, taglist)
                    if after_si != '':
                        sentence = after_si
                        after_si =''
                    re_value = convertSpecialCase_SaeYo(sentence, ending, taglist)
                elif re_value == 'special2':
                    re_value = convertSpecialCase_Da(sentence, ending, taglist)
                elif re_value == 'special3':
                    #시처리 안함 '시' 보존
                    #re_value = convertSpecialCase_Nida(sentence, ending, taglist, kstn, kend, ktag)
                    re_value = convertSpecialCase_Nida(sentence, ending, taglist)
                elif re_value == 'special4':
                    re_value = convertSpecialCase_SaeYo(sentence, ending, taglist)
                    if ending == 'ㅇㅡㅂㅅㅣㄷㅏ':
                        temp = convertSpecialCase_AhOh(sentence)
                        re_value = treatSF(sentence, temp)
                elif re_value == 'special5':
                    re_value = convertSpecialCase_Yo(sentence, ending, taglist)
                elif re_value == 'special6':
                    re_value = convertSpecialCase_NaYo(sentence, ending, taglist)
                else:
                    #위험하기 때문에 데이터 확인 후 수정
#                     if taglist.find('EP') !=-1 and sentence[-4:].find('ㅅㅣ.'):
#                         sentence = delete_EP_si(sentence, taglist)
#                         re_value = convertSpecialCase_SaeYo(sentence, ending)
#                     else:
#                         re_value = treatSF(sentence,re_value)
                    re_value = treatSF(sentence,re_value)
        if flag ==0:
            return treatSF(sentence, ending)
        # print(sentence)
        return re_value
    
    def convert_IC(self, sentence, taglist, ending):
        IC = {'ㅇㅖ':'ㅇㅡㅇ', 'ㄴㅔ':'ㅇㅡㅇ', 'ㅇㅏㄴㅣㅇㅗ':'ㅇㅏㄴㅣ', 'ㅇㅏㄴㅣㅇㅛ':'ㅇㅏㄴㅣ'}
        re_value = ''
        flag = 0
        for key in IC:
            if ending == key:
                re_value = IC[key]
                flag = 1
        if flag != 1:
            re_value = ending
        re_value = treatSF(re_value, sentence)
        return re_value
    
    def make_end_low(self, sentence, taglist, ending):
        re_value =''
        sentence = treatFormal_vv(sentence)
        if taglist.find('IC') !=-1 and len(taglist)<6:
             re_value = self.convert_IC(sentence, taglist, ending)
        else:
            re_value = self.convert_EF(sentence, taglist, ending)
        return re_value
    
    def to_low(self, input):

        if '  ' in input:
            return input
        result = input

        #space_list = rememberSpace(input,' ')
        
#         test_w, test_t = to2lists(result)
#         pre_w, pre_t, pre_ind = prepro(result)

        converted_w, converted_t, target_ind ,last_ef = prepro_ch03(result, lis_beta_ef, lis_tag_last, lis_end_2low, lis_end, lis_ic)

        #ori_w, ori_t, ind, converted_w, converted_t, last_ef,target_ind  = prepro_beta_09(result,lis_beta_ef_h, lis_tag_last, lis_end, lis_end_2low)
         #@
        #print(converted_w, converted_t, target_ind ,last_ef)
        #space_location = convertSpace(space_list, ori_w)
#         lis_target_final = []

        if len(target_ind)!=0:

            #jam = Jamodealer(converted_w)
            for i in range(len(target_ind)):
                #new_end = self.make_end_low(converted_w[target_ind[i]], last_ef[i], converted_t[target_ind[i]], kconverted_w[ktarget_ind[i]], klast_ef[i], kconverted_t[ktarget_ind[i]])
                new_end = self.make_end_low(converted_w[target_ind[i]], converted_t[target_ind[i]], last_ef[i])
                
                converted_w[target_ind[i]] = new_end
            
            res = ' '.join(converted_w)
            jam = Jamodealer(res)
#             jam.jamo.append(w_last)
            #union(space_location, jam.jamo)
            return jam.make_one()

        return input

    def processText(self,stc, count):
        result = stc
        flag = 0
        if result[-1]=='\n':
            result = result.replace('\n','')   
        num = 0
        while 1:
            if result[-1-num]!=' ':
                break
            else:
                num = num+1
                
        if num==0:
            rere = result
        else:
            rere = result[:-num]
            
        
        r_pun = ''
        r_word = rere
        while True:
            if r_word[-1] in SV_LIST:
                r_pun = r_pun+r_word[-1]
                r_word = r_word[:-1]
            else:
                break
        
        num_space = 0
        for i in r_word:
            if i==' ':
                num_space = num_space+1
            else:
                break
            
        if num_space!=0:
            r_word = r_word[num_space:]

        plus = ''
        for s in range(num_space):
            plus = plus+' '
    
        if r_word[-1] =='?' or r_word[-1] =='.' or r_word[-1] =='!' or r_word[-1] =='\"':
            r_word = r_word
        else:
            r_word = r_word+'.'
            flag = 1
        #res = self.to_low(r_word)
        try:
            res = self.to_low(r_word)
        except:
            print('exception sentece number: ', count+1)
            res = r_word
        
        r_word = plus+r_word
        res = plus+res
        
        if flag ==1:
            res = res[:-1]

        return res+r_pun[::-1]

# %%
#txt = '보드의 윗면은 보통 멋진 그림이나 디자인으로 되어 있습니다'
#txt = '그 밖에 화장실의 유지ㆍ관리를 위하여 구청장이 지시하는 사항을 이행 하여야 한다.'
#txt = '‘부패영향평가’란 서울특별시 노원구 현행 및 제정·개정안의 조례, 규칙, 훈령, 예규, 지침 등(이하 “자치법규 등” 이라 한다)에 대한 부패유발요인을 분석ㆍ검토 후 의견을 도출하는 것을 말한다.'
txt = '전 너무 힘듭니다. 당신 어디 계세요? 먹으십시다. 괜찮나요? 걸읍시다. 이제 갈거에요. 받으세요. 닫으세요. 믿으세요. 뭐가 문제래요? 빨리 갈래요. 오래요? 문이래요? 이거에요????? 이거예요. 핸드폰이에요. 멍청이예요. 아름다우시네요. 꽃이에요. 수박이에요. 멍청이에요. 천재에요. 걸읍시다. 안녕하세요. 수박이에요. 누구인가요? 언제요? 저녁에요? 축제가 다가왔어요. 바로 접니다.'
yo = [ 
    '을까', 'ㄹ까', '지', '으니까', '어', '아',
    '는데', 'ㄴ가', 'ㄹ게', '래', '잖아', '네',
    '여', 'ㄹ래', '게', '나', '군', '을게', '다고(JX)',
    '지만(JX)', '은데', 'ㄴ지', '는지', '라고', 'ㄴ데',
    '는걸', '아서', '거든', '더라고', '어서', '려고',
    '을래', '대', 'ㄴ대', '던데', '더군', '여서', '건가',
    '어야지', 'ㄹ걸', 'ㄹ께', '아야지', '다면서', '는군',
    'ㄴ다고', '은가', '다니', '다면', '실까', '가', '신가',
    '서', '까'
]

# %%
#txt = '43세의 패트릭 듀얼은 한때 486kg이었지만 지금은 181kg이라는군요'
#txt = '역사에서 가장 위대한 물리학자이자 수학자 중 한 명인 갈릴레오 갈릴레이는 그의 책 Il Saggiatore에서  수학 이라는 언어로 쓰여질 수 있다라고 썼습니다.'
#'제 마음에 가장 와닿는 예를 보여드리고 싶습니다'
#계세요 주무세요 잡수세요
#txt2= '놉시다. 저기까지는 갑시다. 자릅시다. 지나나요? 떠나요. 생각나요? 잘하길 바라요. 드레싱이요. 생겨나요. 기억나요. 부탁드려요. 전 너무 힘듭니다. 당신은 누구십니까? 사장님께서 부르십니다. 축하드려요.'
# txt2 = '재밌으세요? 그러세요. 갑시다. 밉시다. 해봅시다. 행복합시다. 믿으세요. 갑자기 웬일이세요? 그러세요. 힘내세요. 당신은 노세요. 당신이 오르세요. 당신은 밥을 푸세요. 힘냅시다. 범인은 당신이다. 저 분은 아닙니다. 제 생각은 그래요. 이 차는 이제 제 겁니다. 제 마음대로 사거나 팔 수 있습니다. 저의 생각에 당신은 바보가 아닙니다. 당신의 업적을 생각해봐요.'
txt3 = '그러세요. 주세요.'

# %%
print(prepro_ch03(txt3, lis_beta_ef, lis_tag_last, lis_end_2low, lis_end, lis_ic))
# Out:
# (['ㄱㅡㄹㅓ__+__.', 'ㅈㅜ__+__.'], ['VV/EP+EF/SF', 'VV/EP+EF/SF'], [0, 1], ['ㅅㅔㅇㅛ', 'ㅅㅔㅇㅛ'])

# %%
kori_w, kori_t, kind, kconverted_w, kconverted_t, klast_ef,ktarget_ind  = prepro_beta_khaiii(txt,lis_beta_ef_h, lis_tag_last, lis_end, lis_end_2low)

# %%
# ch = Changer()
# ch.processText(txt3)

# %% [markdown]
# ### Data 추출

# %% [markdown]
# __aihub.low.kr.shuf__

# %%
f0 = open('./data/aihub.kr.shuf', 'r', encoding = 'utf-8')
f1 = open('./aihub.low.shuf', 'w',encoding = 'utf-8')



flag = 0

num = 0
number = 0
ch = Changer()

while True:
    flag = 0
    line = f0.readline()
    if not line: break
    if line[-1]=='\n':
        line = line.replace('\n','')
    
    num_space = 0
    for i in line:
        if i==' ':
            num_space = num_space+1
        else:
            break
            
    if num_space!=0:
        line = line[num_space:]
    
#     try:
    cc = ch.processText(line, num)
#     except:
#         cc = line
    
    plus = ''
    for s in range(num_space):
        plus = plus+' '
    
    line = plus+line
    cc = plus+cc
    f1.write(cc)
    f1.write('\n')
    #print(cc)
    num = num+1
    if cc!=line:
        number = number+1
    #print(num)
    if num%10000 == 0:
        print(num)

f0.close()
f1.close()
# Out:
# exception sentece number:  1584
# exception sentece number:  8708
# 10000
# exception sentece number:  10205
# exception sentece number:  13193
# exception sentece number:  13728
# 20000
# exception sentece number:  21968
# exception sentece number:  23581
# exception sentece number:  25169
# exception sentece number:  25742
# exception sentece number:  26575
# exception sentece number:  26859
# exception sentece number:  29611
# 30000
# exception sentece number:  30509
# exception sentece number:  31257
# exception sentece number:  33593
# exception sentece number:  35609
# exception sentece number:  38099
# 40000
# exception sentece number:  40711
# exception sentece number:  41963
# exception sentece number:  45076
# exception sentece number:  46139
# exception sentece number:  48808
# exception sentece number:  49433
# exception sentece number:  49463
# 50000
# exception sentece number:  50291
# exception sentece number:  51071
# exception sentece number:  53937
# exception sentece number:  54394
# exception sentece number:  55577
# exception sentece number:  55696
# exception sentece number:  56117
# exception sentece number:  56657
# exception sentece number:  58404
# exception sentece number:  58595
# 60000
# exception sentece number:  61024
# exception sentece number:  62755
# exception sentece number:  64153
# exception sentece number:  64708
# exception sentece number:  67735
# exception sentece number:  68773
# exception sentece number:  68805
# exception sentece number:  69883
# exception sentece number:  69930
# 70000
# exception sentece number:  71306
# exception sentece number:  73270
# exception sentece number:  75484
# exception sentece number:  76417
# exception sentece number:  77934
# 80000
# exception sentece number:  80807
# exception sentece number:  81242
# exception sentece number:  84898
# exception sentece number:  86060
# 90000
# exception sentece number:  90185
# exception sentece number:  90409
# exception sentece number:  92860
# exception sentece number:  98308
# exception sentece number:  99318
# 100000
# exception sentece number:  100121
# exception sentece number:  100433
# exception sentece number:  103555
# exception sentece number:  105143
# exception sentece number:  106834
# exception sentece number:  106971
# exception sentece number:  107853
# exception sentece number:  109355
# 110000
# exception sentece number:  111093
# exception sentece number:  112593
# exception sentece number:  113541
# exception sentece number:  114579
# exception sentece number:  114770
# exception sentece number:  115123
# 120000
# exception sentece number:  124663
# exception sentece number:  124988
# exception sentece number:  126798
# exception sentece number:  129536
# 130000
# exception sentece number:  130271
# exception sentece number:  134316
# exception sentece number:  138633
# 140000
# exception sentece number:  142385
# exception sentece number:  144624
# exception sentece number:  146025
# exception sentece number:  146997
# exception sentece number:  147513
# exception sentece number:  149951
# 150000
# exception sentece number:  150106
# exception sentece number:  152914
# exception sentece number:  154885
# exception sentece number:  157151
# exception sentece number:  157171
# exception sentece number:  157214
# 160000
# exception sentece number:  162825
# exception sentece number:  164547
# exception sentece number:  164618
# 170000
# exception sentece number:  170024
# exception sentece number:  173738
# exception sentece number:  174976
# exception sentece number:  175821
# exception sentece number:  176914
# exception sentece number:  177146
# exception sentece number:  177345
# exception sentece number:  178892
# exception sentece number:  179076
# 180000
# exception sentece number:  180853
# exception sentece number:  182610
# exception sentece number:  182784
# exception sentece number:  187222
# exception sentece number:  188938
# exception sentece number:  189089
# 190000
# exception sentece number:  192747
# exception sentece number:  195828
# exception sentece number:  198570
# 200000
# exception sentece number:  207731
# exception sentece number:  208267
# exception sentece number:  208629
# 210000
# exception sentece number:  210296
# exception sentece number:  211695
# exception sentece number:  212987
# exception sentece number:  213739
# exception sentece number:  215852
# 220000
# exception sentece number:  220479
# exception sentece number:  221561
# exception sentece number:  223308
# exception sentece number:  223847
# exception sentece number:  226260
# exception sentece number:  226759
# exception sentece number:  226830
# exception sentece number:  228626
# 230000
# exception sentece number:  233619
# exception sentece number:  234444
# exception sentece number:  234978
# exception sentece number:  238552
# exception sentece number:  238727
# 240000
# exception sentece number:  242767
# exception sentece number:  246047
# exception sentece number:  246784
# exception sentece number:  247294
# exception sentece number:  248541
# 250000
# exception sentece number:  252573
# exception sentece number:  252864
# exception sentece number:  253533
# exception sentece number:  258450
# 260000
# exception sentece number:  260133
# exception sentece number:  260815
# exception sentece number:  261250
# exception sentece number:  265394
# exception sentece number:  265859
# exception sentece number:  267884
# exception sentece number:  268607
# 270000
# exception sentece number:  271799
# exception sentece number:  272529
# exception sentece number:  277313
# 280000
# exception sentece number:  283709
# exception sentece number:  285359
# exception sentece number:  286042
# exception sentece number:  286070
# exception sentece number:  286966
# exception sentece number:  287174
# 290000
# exception sentece number:  290369
# exception sentece number:  294217
# exception sentece number:  294813
# exception sentece number:  295009
# exception sentece number:  297007
# exception sentece number:  298460
# exception sentece number:  299025
# 300000
# exception sentece number:  300103
# exception sentece number:  300665
# exception sentece number:  303229
# exception sentece number:  303293
# exception sentece number:  304006
# exception sentece number:  305874
# 310000
# exception sentece number:  312443
# exception sentece number:  312984
# exception sentece number:  313216
# exception sentece number:  313245
# exception sentece number:  315243
# exception sentece number:  317805
# exception sentece number:  317839
# exception sentece number:  319057
# 320000
# exception sentece number:  320032
# exception sentece number:  320403
# exception sentece number:  322990
# exception sentece number:  329766
# 330000
# exception sentece number:  333628
# exception sentece number:  334347
# exception sentece number:  335358
# exception sentece number:  335412
# exception sentece number:  339319
# 340000
# exception sentece number:  340356
# exception sentece number:  341380
# exception sentece number:  341616
# exception sentece number:  341659
# exception sentece number:  341829
# exception sentece number:  346592
# exception sentece number:  347345
# exception sentece number:  348904
# 350000
# exception sentece number:  351489
# exception sentece number:  354048
# exception sentece number:  354301
# exception sentece number:  357426
# exception sentece number:  357711
# exception sentece number:  358364
# 360000
# exception sentece number:  364699
# exception sentece number:  365747
# exception sentece number:  366007
# exception sentece number:  369119
# exception sentece number:  369536
# 370000
# exception sentece number:  371186
# exception sentece number:  372905
# exception sentece number:  373265
# exception sentece number:  377477
# exception sentece number:  377512
# 380000
# exception sentece number:  382095
# exception sentece number:  383762
# exception sentece number:  384002
# exception sentece number:  385716
# 390000
# exception sentece number:  390137
# exception sentece number:  390148
# exception sentece number:  390371
# exception sentece number:  391880
# exception sentece number:  394569
# exception sentece number:  396250
# exception sentece number:  397429
# exception sentece number:  398130
# 400000
# exception sentece number:  400536
# exception sentece number:  402456
# exception sentece number:  402769
# exception sentece number:  403145
# exception sentece number:  403726
# 410000
# exception sentece number:  411080
# exception sentece number:  411429
# exception sentece number:  414222
# exception sentece number:  414633
# exception sentece number:  415598
# exception sentece number:  415671
# exception sentece number:  417203
# exception sentece number:  419197
# 420000
# exception sentece number:  420949
# exception sentece number:  422135
# exception sentece number:  422324
# exception sentece number:  424836
# exception sentece number:  425832
# 430000
# exception sentece number:  430669
# exception sentece number:  430774
# exception sentece number:  432208
# exception sentece number:  435005
# exception sentece number:  439722
# 440000
# exception sentece number:  440363
# exception sentece number:  447250
# exception sentece number:  447809
# exception sentece number:  447840
# exception sentece number:  447847
# exception sentece number:  448109
# exception sentece number:  449384
# exception sentece number:  449987
# 450000
# exception sentece number:  451557
# exception sentece number:  455045
# exception sentece number:  455622
# exception sentece number:  455833
# exception sentece number:  455884
# exception sentece number:  457398
# exception sentece number:  458971
# exception sentece number:  459270
# 460000
# exception sentece number:  462608
# exception sentece number:  464045
# exception sentece number:  464849
# exception sentece number:  467037
# exception sentece number:  468388
# exception sentece number:  469357
# 470000
# exception sentece number:  471723
# exception sentece number:  475783
# exception sentece number:  477736
# 480000
# exception sentece number:  480699
# exception sentece number:  480832
# exception sentece number:  482466
# exception sentece number:  485499
# 490000
# exception sentece number:  490120
# exception sentece number:  490229
# exception sentece number:  498608
# 500000
# exception sentece number:  501120
# exception sentece number:  502667
# exception sentece number:  506192
# exception sentece number:  507305
# exception sentece number:  507925
# 510000
# exception sentece number:  510564
# exception sentece number:  512487
# exception sentece number:  512577
# exception sentece number:  512674
# exception sentece number:  513890
# exception sentece number:  517644
# exception sentece number:  518986
# 520000
# exception sentece number:  521147
# exception sentece number:  523229
# exception sentece number:  525655
# 530000
# exception sentece number:  530704
# exception sentece number:  532015
# exception sentece number:  532220
# exception sentece number:  533293
# exception sentece number:  535050
# exception sentece number:  535797
# exception sentece number:  536807
# exception sentece number:  537037
# exception sentece number:  538344
# exception sentece number:  538379
# 540000
# exception sentece number:  543478
# exception sentece number:  544571
# exception sentece number:  545369
# exception sentece number:  546011
# exception sentece number:  546066
# exception sentece number:  546801
# exception sentece number:  548659
# exception sentece number:  549153
# 550000
# exception sentece number:  551444
# exception sentece number:  554752
# exception sentece number:  556418
# exception sentece number:  558608
# exception sentece number:  559271
# 560000
# exception sentece number:  560127
# exception sentece number:  561891
# exception sentece number:  562358
# exception sentece number:  562984
# exception sentece number:  568685
# 570000
# exception sentece number:  570287
# exception sentece number:  573776
# exception sentece number:  577093
# 580000
# exception sentece number:  582389
# exception sentece number:  583896
# exception sentece number:  584868
# exception sentece number:  584980
# exception sentece number:  585721
# 590000
# exception sentece number:  594975
# exception sentece number:  596561
# exception sentece number:  596630
# exception sentece number:  598406
# 600000
# exception sentece number:  600426
# exception sentece number:  600688
# exception sentece number:  602309
# exception sentece number:  607323
# exception sentece number:  608874
# 610000
# exception sentece number:  611379
# exception sentece number:  612825
# exception sentece number:  616355
# exception sentece number:  616816
# 620000
# exception sentece number:  621760
# exception sentece number:  622467
# exception sentece number:  622513
# exception sentece number:  623017
# exception sentece number:  623251
# exception sentece number:  624804
# exception sentece number:  627520
# exception sentece number:  627692
# 630000
# exception sentece number:  635407
# exception sentece number:  638452
# exception sentece number:  639452
# exception sentece number:  639514
# 640000
# exception sentece number:  640211
# exception sentece number:  640393
# exception sentece number:  642329
# exception sentece number:  643440
# exception sentece number:  644204
# exception sentece number:  644520
# exception sentece number:  646794
# 650000
# exception sentece number:  650809
# exception sentece number:  654100
# exception sentece number:  657647
# 660000
# exception sentece number:  660245
# exception sentece number:  660292
# exception sentece number:  662781
# exception sentece number:  667782
# exception sentece number:  668295
# exception sentece number:  668478
# exception sentece number:  669228
# 670000
# exception sentece number:  672745
# exception sentece number:  677433
# exception sentece number:  677537
# exception sentece number:  679173
# 680000
# exception sentece number:  683591
# exception sentece number:  687482
# exception sentece number:  688615
# 690000
# exception sentece number:  690301
# exception sentece number:  693698
# exception sentece number:  695863
# exception sentece number:  697261
# exception sentece number:  697293
# exception sentece number:  698193
# 700000
# exception sentece number:  700179
# exception sentece number:  701001
# exception sentece number:  701186
# exception sentece number:  701601
# exception sentece number:  702692
# exception sentece number:  706071
# exception sentece number:  706664
# exception sentece number:  707306
# exception sentece number:  708284
# 710000
# exception sentece number:  710051
# exception sentece number:  711181
# exception sentece number:  712594
# exception sentece number:  715249
# exception sentece number:  715384
# exception sentece number:  716362
# exception sentece number:  718979
# 720000
# exception sentece number:  720029
# exception sentece number:  722357
# exception sentece number:  724035
# exception sentece number:  724421
# exception sentece number:  726598
# exception sentece number:  727088
# exception sentece number:  727359
# exception sentece number:  728266
# exception sentece number:  729510
# 730000
# exception sentece number:  731190
# exception sentece number:  731255
# exception sentece number:  731409
# exception sentece number:  733285
# exception sentece number:  734019
# exception sentece number:  734143
# exception sentece number:  735356
# 740000
# exception sentece number:  740206
# exception sentece number:  742923
# exception sentece number:  743102
# exception sentece number:  744540
# exception sentece number:  745270
# exception sentece number:  749333
# 750000
# exception sentece number:  752120
# exception sentece number:  752389
# exception sentece number:  753529
# exception sentece number:  755557
# exception sentece number:  755842
# 760000
# exception sentece number:  762909
# exception sentece number:  766397
# exception sentece number:  766667
# 770000
# exception sentece number:  772235
# exception sentece number:  773148
# exception sentece number:  776624
# exception sentece number:  776670
# exception sentece number:  776848
# exception sentece number:  777377
# exception sentece number:  777766
# exception sentece number:  778210
# exception sentece number:  778319
# exception sentece number:  778849
# exception sentece number:  779651
# exception sentece number:  779932
# 780000
# exception sentece number:  780596
# exception sentece number:  782243
# exception sentece number:  784773
# exception sentece number:  787490
# exception sentece number:  789706
# 790000
# exception sentece number:  790903
# exception sentece number:  796426
# exception sentece number:  797672
# exception sentece number:  798832
# 800000
# exception sentece number:  801060
# exception sentece number:  801100
# exception sentece number:  806111
# exception sentece number:  806846
# exception sentece number:  807856
# exception sentece number:  808260
# exception sentece number:  808477
# exception sentece number:  809198
# 810000
# exception sentece number:  810211
# exception sentece number:  810345
# exception sentece number:  810499
# exception sentece number:  811603
# exception sentece number:  812994
# exception sentece number:  813121
# exception sentece number:  814963
# exception sentece number:  817998
# 820000
# exception sentece number:  820614
# exception sentece number:  821462
# exception sentece number:  821852
# exception sentece number:  821945
# exception sentece number:  823313
# exception sentece number:  825138
# exception sentece number:  825553
# exception sentece number:  826560
# exception sentece number:  829238
# exception sentece number:  829317
# 830000
# exception sentece number:  830198
# exception sentece number:  833168
# exception sentece number:  833956
# exception sentece number:  839108
# 840000
# exception sentece number:  840879
# exception sentece number:  843465
# exception sentece number:  845804
# exception sentece number:  846208
# exception sentece number:  846638
# exception sentece number:  847899
# exception sentece number:  848096
# 850000
# exception sentece number:  853385
# exception sentece number:  857826
# exception sentece number:  859651
# 860000
# exception sentece number:  860448
# exception sentece number:  862953
# exception sentece number:  862989
# exception sentece number:  863193
# exception sentece number:  865720
# exception sentece number:  865740
# exception sentece number:  867227
# exception sentece number:  868681
# 870000
# exception sentece number:  870240
# exception sentece number:  870646
# exception sentece number:  871461
# exception sentece number:  871671
# exception sentece number:  873668
# exception sentece number:  875593
# exception sentece number:  876391
# exception sentece number:  878411
# 880000
# exception sentece number:  880061
# exception sentece number:  880100
# exception sentece number:  881232
# exception sentece number:  884571
# exception sentece number:  886168
# exception sentece number:  886447
# exception sentece number:  887881
# exception sentece number:  889944
# 890000
# exception sentece number:  894153
# exception sentece number:  898219
# exception sentece number:  899724
# 900000
# exception sentece number:  900279
# exception sentece number:  900530
# exception sentece number:  901036
# exception sentece number:  902501
# exception sentece number:  902662
# exception sentece number:  903408
# exception sentece number:  904235
# exception sentece number:  905636
# exception sentece number:  907208
# exception sentece number:  909630
# exception sentece number:  909674
# 910000
# exception sentece number:  910176
# exception sentece number:  910728
# exception sentece number:  912541
# exception sentece number:  917124
# exception sentece number:  918412
# exception sentece number:  919890
# 920000
# exception sentece number:  920356
# exception sentece number:  920375
# exception sentece number:  922107
# exception sentece number:  924250
# 930000
# exception sentece number:  935628
# exception sentece number:  936217
# exception sentece number:  939729
# 940000
# exception sentece number:  940613
# exception sentece number:  944255
# exception sentece number:  944731
# exception sentece number:  946780
# 950000
# exception sentece number:  953101
# exception sentece number:  953145
# exception sentece number:  955079
# exception sentece number:  955367
# exception sentece number:  955903
# exception sentece number:  957322
# exception sentece number:  959616
# 960000
# exception sentece number:  961722
# exception sentece number:  963067
# exception sentece number:  964789
# exception sentece number:  965868
# exception sentece number:  965945
# exception sentece number:  966384
# exception sentece number:  966575
# exception sentece number:  967094
# exception sentece number:  967118
# exception sentece number:  968371
# 970000
# exception sentece number:  970754
# exception sentece number:  972216
# exception sentece number:  972320
# exception sentece number:  972455
# 980000
# exception sentece number:  980003
# exception sentece number:  980830
# exception sentece number:  982887
# exception sentece number:  984384
# exception sentece number:  988245
# 990000
# exception sentece number:  992011
# exception sentece number:  992396
# exception sentece number:  993035
# exception sentece number:  994422
# exception sentece number:  994616
# exception sentece number:  996783
# exception sentece number:  998798
# 1000000
# exception sentece number:  1004778
# exception sentece number:  1007737
# 1010000
# exception sentece number:  1011456
# exception sentece number:  1011492
# exception sentece number:  1011721
# exception sentece number:  1012123
# exception sentece number:  1012465
# exception sentece number:  1012657
# exception sentece number:  1016039
# exception sentece number:  1016105
# exception sentece number:  1017264
# exception sentece number:  1017540
# exception sentece number:  1017555
# 1020000
# exception sentece number:  1020061
# exception sentece number:  1020280
# exception sentece number:  1021611
# exception sentece number:  1022019
# exception sentece number:  1027588
# exception sentece number:  1028104
# exception sentece number:  1028592
# exception sentece number:  1029504
# exception sentece number:  1029782
# 1030000
# exception sentece number:  1030175
# exception sentece number:  1030482
# exception sentece number:  1031701
# exception sentece number:  1032011
# exception sentece number:  1034426
# exception sentece number:  1034628
# exception sentece number:  1036595
# exception sentece number:  1038568
# exception sentece number:  1039358
# 1040000
# exception sentece number:  1040281
# exception sentece number:  1041147
# exception sentece number:  1044106
# exception sentece number:  1048200
# exception sentece number:  1048895
# 1050000
# exception sentece number:  1050804
# exception sentece number:  1050857
# exception sentece number:  1052242
# exception sentece number:  1054996
# exception sentece number:  1055834
# 1060000
# exception sentece number:  1060519
# exception sentece number:  1063452
# exception sentece number:  1066119
# exception sentece number:  1066636
# exception sentece number:  1067855
# 1070000
# exception sentece number:  1070488
# exception sentece number:  1071344
# exception sentece number:  1071686
# exception sentece number:  1078421
# exception sentece number:  1078450
# 1080000
# exception sentece number:  1081899
# exception sentece number:  1086516
# exception sentece number:  1089038
# 1090000
# exception sentece number:  1092771
# exception sentece number:  1094301
# exception sentece number:  1094728
# exception sentece number:  1096278
# exception sentece number:  1097773
# exception sentece number:  1098907
# exception sentece number:  1099111
# 1100000
# exception sentece number:  1101290
# exception sentece number:  1101466
# exception sentece number:  1101502
# exception sentece number:  1101878
# exception sentece number:  1106782
# exception sentece number:  1109539
# 1110000
# exception sentece number:  1110112
# exception sentece number:  1111984
# exception sentece number:  1112332
# exception sentece number:  1114393
# exception sentece number:  1114631
# exception sentece number:  1114900
# exception sentece number:  1114958
# exception sentece number:  1115967
# exception sentece number:  1116107
# 1120000
# exception sentece number:  1122534
# exception sentece number:  1123847
# exception sentece number:  1124910
# exception sentece number:  1125527
# exception sentece number:  1126173
# exception sentece number:  1126572
# exception sentece number:  1129066
# exception sentece number:  1129724
# exception sentece number:  1129968
# 1130000
# exception sentece number:  1130789
# exception sentece number:  1133110
# exception sentece number:  1133579
# exception sentece number:  1134248
# exception sentece number:  1137631
# exception sentece number:  1138781
# 1140000
# exception sentece number:  1140921
# exception sentece number:  1144682
# exception sentece number:  1145446
# exception sentece number:  1146539
# exception sentece number:  1147074
# exception sentece number:  1147524
# 1150000
# exception sentece number:  1150735
# exception sentece number:  1151358
# exception sentece number:  1151412
# exception sentece number:  1151833
# exception sentece number:  1152333
# exception sentece number:  1155222
# exception sentece number:  1155845
# exception sentece number:  1156051
# exception sentece number:  1157401
# exception sentece number:  1158678
# 1160000
# exception sentece number:  1165321
# 1170000
# exception sentece number:  1172412
# exception sentece number:  1176873
# exception sentece number:  1176952
# exception sentece number:  1178115
# exception sentece number:  1178878
# exception sentece number:  1178996
# 1180000
# exception sentece number:  1183173
# exception sentece number:  1183539
# exception sentece number:  1183926
# exception sentece number:  1184019
# exception sentece number:  1184262
# 1190000
# exception sentece number:  1190064
# exception sentece number:  1190347
# exception sentece number:  1192740
# exception sentece number:  1199474
# 1200000
# exception sentece number:  1200824
# exception sentece number:  1201036
# exception sentece number:  1201673
# exception sentece number:  1201810
# exception sentece number:  1207219
# exception sentece number:  1207760
# exception sentece number:  1209409
# 1210000
# exception sentece number:  1211103
# exception sentece number:  1211229
# exception sentece number:  1211886
# exception sentece number:  1214017
# exception sentece number:  1214915
# exception sentece number:  1215192
# exception sentece number:  1215252
# 1220000
# exception sentece number:  1220840
# exception sentece number:  1222993
# exception sentece number:  1225806
# exception sentece number:  1227367
# exception sentece number:  1228012
# 1230000
# exception sentece number:  1230622
# exception sentece number:  1231570
# exception sentece number:  1232428
# exception sentece number:  1233742
# exception sentece number:  1235257
# exception sentece number:  1235538
# exception sentece number:  1236821
# exception sentece number:  1238550
# exception sentece number:  1238628
# 1240000
# exception sentece number:  1241143
# exception sentece number:  1243965
# exception sentece number:  1246558
# exception sentece number:  1247216
# exception sentece number:  1249037
# 1250000
# exception sentece number:  1251148
# exception sentece number:  1251706
# exception sentece number:  1251715
# exception sentece number:  1251982
# exception sentece number:  1252861
# exception sentece number:  1254212
# exception sentece number:  1254323
# exception sentece number:  1257321
# exception sentece number:  1257927
# exception sentece number:  1259253
# 1260000
# exception sentece number:  1260567
# exception sentece number:  1263596
# exception sentece number:  1266088
# exception sentece number:  1267608
# exception sentece number:  1268119
# 1270000
# exception sentece number:  1271017
# exception sentece number:  1272183
# exception sentece number:  1273899
# exception sentece number:  1275100
# exception sentece number:  1275650
# exception sentece number:  1275877
# exception sentece number:  1278958
# exception sentece number:  1279722
# 1280000
# exception sentece number:  1280304
# exception sentece number:  1280321
# exception sentece number:  1281496
# exception sentece number:  1281898
# exception sentece number:  1282828
# exception sentece number:  1282853
# exception sentece number:  1285502
# exception sentece number:  1286012
# exception sentece number:  1287514
# exception sentece number:  1287739
# exception sentece number:  1288400
# exception sentece number:  1289291
# 1290000
# exception sentece number:  1290714
# exception sentece number:  1292580
# exception sentece number:  1298482
# exception sentece number:  1299166
# exception sentece number:  1299346
# 1300000
# exception sentece number:  1301026
# exception sentece number:  1301393
# exception sentece number:  1304409
# exception sentece number:  1305874
# exception sentece number:  1307717
# exception sentece number:  1307927
# exception sentece number:  1309137
# 1310000
# exception sentece number:  1310473
# exception sentece number:  1311088
# exception sentece number:  1314986
# exception sentece number:  1315779
# exception sentece number:  1318349
# exception sentece number:  1319695
# 1320000
# exception sentece number:  1321371
# exception sentece number:  1324182
# exception sentece number:  1324918
# exception sentece number:  1325161
# exception sentece number:  1329682
# 1330000
# exception sentece number:  1331654
# exception sentece number:  1332105
# exception sentece number:  1335925
# exception sentece number:  1336980
# exception sentece number:  1338213
# exception sentece number:  1339929
# exception sentece number:  1339941
# 1340000
# exception sentece number:  1343644
# exception sentece number:  1343776
# exception sentece number:  1345816
# exception sentece number:  1346403
# exception sentece number:  1346899
# exception sentece number:  1347691
# exception sentece number:  1347711
# exception sentece number:  1349870
# 1350000
# exception sentece number:  1354659
# exception sentece number:  1356190
# exception sentece number:  1359863
# 1360000
# exception sentece number:  1361301
# exception sentece number:  1361981
# exception sentece number:  1363528
# exception sentece number:  1368623
# 1370000
# exception sentece number:  1370099
# exception sentece number:  1372799
# exception sentece number:  1374554
# 1380000
# exception sentece number:  1382308
# exception sentece number:  1383894
# exception sentece number:  1384355
# exception sentece number:  1385256
# exception sentece number:  1386066
# exception sentece number:  1386840
# exception sentece number:  1388319
# exception sentece number:  1389065
# 1390000
# exception sentece number:  1390260
# exception sentece number:  1394294
# exception sentece number:  1397223
# exception sentece number:  1398426
# exception sentece number:  1398791
# exception sentece number:  1398913
# 1400000
# exception sentece number:  1401231
# exception sentece number:  1401528
# exception sentece number:  1403152
# exception sentece number:  1409231
# exception sentece number:  1409861
# 1410000
# exception sentece number:  1414363
# exception sentece number:  1415541
# exception sentece number:  1417409
# exception sentece number:  1419148
# 1420000
# exception sentece number:  1420550
# exception sentece number:  1423976
# exception sentece number:  1424320
# exception sentece number:  1427280
# exception sentece number:  1428725
# 1430000
# exception sentece number:  1433429
# exception sentece number:  1433950
# exception sentece number:  1433961
# exception sentece number:  1435606
# exception sentece number:  1435665
# exception sentece number:  1438353
# 1440000
# exception sentece number:  1446595
# 1450000
# exception sentece number:  1452597
# exception sentece number:  1458696
# 1460000
# exception sentece number:  1460467
# exception sentece number:  1462749
# exception sentece number:  1464104
# exception sentece number:  1465480
# exception sentece number:  1465806
# exception sentece number:  1466120
# exception sentece number:  1466532
# exception sentece number:  1468701
# 1470000
# exception sentece number:  1473411
# exception sentece number:  1473662
# exception sentece number:  1475818
# exception sentece number:  1478415
# 1480000
# exception sentece number:  1481020
# exception sentece number:  1481103
# exception sentece number:  1482062
# exception sentece number:  1485565
# exception sentece number:  1486402
# exception sentece number:  1486499
# exception sentece number:  1486514
# exception sentece number:  1489062
# 1490000
# exception sentece number:  1491574
# exception sentece number:  1494293
# exception sentece number:  1494498
# exception sentece number:  1494595
# exception sentece number:  1494936
# exception sentece number:  1495356
# exception sentece number:  1497448
# exception sentece number:  1499551
# 1500000
# exception sentece number:  1500321
# exception sentece number:  1501853
# exception sentece number:  1504573
# exception sentece number:  1505636
# 1510000
# exception sentece number:  1512284
# exception sentece number:  1512953
# exception sentece number:  1513853
# exception sentece number:  1513942
# exception sentece number:  1514586
# 1520000
# exception sentece number:  1525919
# 1530000
# exception sentece number:  1530158
# exception sentece number:  1534064
# exception sentece number:  1535136
# exception sentece number:  1537933
# exception sentece number:  1538565
# exception sentece number:  1539872
# 1540000
# exception sentece number:  1540515
# exception sentece number:  1541592
# exception sentece number:  1546522
# exception sentece number:  1548161
# 1550000
# exception sentece number:  1551688
# exception sentece number:  1553795
# exception sentece number:  1558215
# 1560000
# exception sentece number:  1566859
# exception sentece number:  1567348
# exception sentece number:  1567745
# 1570000
# exception sentece number:  1570245
# exception sentece number:  1572278
# exception sentece number:  1575961
# exception sentece number:  1578078
# 1580000
# exception sentece number:  1580244
# exception sentece number:  1580528
# exception sentece number:  1586856
# exception sentece number:  1588074
# 1590000
# exception sentece number:  1594769
# exception sentece number:  1596387
# exception sentece number:  1596787
# 1600000
# exception sentece number:  1602169

# %%
f0 = open('./data/hgu_clean.kr.shuf', 'r', encoding = 'utf-8')
f1 = open('./hgu_clean.low.shuf', 'w',encoding = 'utf-8')



flag = 0

num = 0
number = 0
ch = Changer()

while True:
    flag = 0
    line = f0.readline()
    if not line: break
    if line[-1]=='\n':
        line = line.replace('\n','')
    
    num_space = 0
    for i in line:
        if i==' ':
            num_space = num_space+1
        else:
            break
            
    if num_space!=0:
        line = line[num_space:]
    
#     try:
    cc = ch.processText(line, num)
#     except:
#         cc = line
    
    plus = ''
    for s in range(num_space):
        plus = plus+' '
    
    line = plus+line
    cc = plus+cc
    f1.write(cc)
    f1.write('\n')
    #print(cc)
    num = num+1
    if cc!=line:
        number = number+1
    #print(num)
    if num%10000 == 0:
        print(num)

f0.close()
f1.close()
# Out:
# 10000
# exception sentece number:  15116
# 20000
# exception sentece number:  26214
# 30000
# 40000
# 50000
# exception sentece number:  59911
# 60000
# exception sentece number:  68441
# 70000
# exception sentece number:  79698
# 80000
# exception sentece number:  87092
# 90000
# exception sentece number:  91904
# 100000
# 110000
# exception sentece number:  117801
# 120000
# exception sentece number:  123338
# 130000
# exception sentece number:  136100
# 140000
# 150000
# 160000
# exception sentece number:  163900
# 170000
# 180000
# exception sentece number:  181968
# 190000
# 200000
# exception sentece number:  201887
# exception sentece number:  208009
# 210000
# 220000
# exception sentece number:  222064
# 230000
# exception sentece number:  234867
# 240000
# 250000
# exception sentece number:  251013
# exception sentece number:  259391
# 260000
# exception sentece number:  265456
# 270000
# 280000
# 290000
# exception sentece number:  291764
# exception sentece number:  295985
# 300000
# exception sentece number:  306068
# 310000
# 320000
# exception sentece number:  326866
# 330000
# 340000
# exception sentece number:  344644
# 350000
# 360000
# 370000
# exception sentece number:  370435
# exception sentece number:  378274
# 380000
# exception sentece number:  387150
# 390000
# 400000
# 410000
# exception sentece number:  413593
# 420000
# exception sentece number:  427136
# 430000
# exception sentece number:  436131
# 440000
# exception sentece number:  445645
# 450000
# exception sentece number:  452136
# exception sentece number:  455668
# 460000
# exception sentece number:  461283
# 470000
# 480000
# 490000
# exception sentece number:  495461
# 500000
# 510000
# 520000
# 530000
# exception sentece number:  532626
# 540000
# exception sentece number:  544631
# 550000
# exception sentece number:  553103
# exception sentece number:  558053
# 560000
# 570000
# exception sentece number:  572957
# 580000
# exception sentece number:  587477
# 590000
# exception sentece number:  590062
# exception sentece number:  597207
# 600000
# 610000
# 620000
# exception sentece number:  629694
# 630000
# 640000
# 650000
# 660000
# exception sentece number:  668861
# 670000
# 680000
# 690000
# exception sentece number:  698909
# 700000
# 710000
# 720000
# 730000
# exception sentece number:  730884
# 740000
# exception sentece number:  746259
# 750000
# exception sentece number:  756044
# 760000
# exception sentece number:  760761
# 770000
# 780000
# exception sentece number:  785596
# 790000
# exception sentece number:  795056
# 800000
# exception sentece number:  800122
# 810000
# 820000
# 830000
# exception sentece number:  830380
# exception sentece number:  839318
# 840000
# exception sentece number:  843622
# 850000
# exception sentece number:  856476
# exception sentece number:  857554
# 860000
# exception sentece number:  862974
# 870000
# exception sentece number:  876276
# 880000
# 890000
# 900000
# exception sentece number:  901384
# exception sentece number:  902036
# exception sentece number:  903115
# 910000
# exception sentece number:  912314
# 920000
# exception sentece number:  922346
# 930000
# 940000
# 950000
# exception sentece number:  952721
# 960000
# exception sentece number:  963674
# 970000
# exception sentece number:  970863
# 980000
# exception sentece number:  986820
# 990000
# exception sentece number:  993731
# exception sentece number:  996071
# 1000000
# exception sentece number:  1009435
# 1010000
# 1020000
# exception sentece number:  1023405
# 1030000
# 1040000
# 1050000
# 1060000
# exception sentece number:  1065904
# 1070000
# exception sentece number:  1076172
# 1080000
# 1090000
# exception sentece number:  1098023
# 1100000
# 1110000
# exception sentece number:  1110320
# 1120000
# 1130000
# exception sentece number:  1135021
# exception sentece number:  1139964
# 1140000
# exception sentece number:  1143280
# exception sentece number:  1146439
# 1150000
# 1160000
# exception sentece number:  1168169
# exception sentece number:  1168401
# 1170000
# exception sentece number:  1172245
# 1180000
# 1190000
# 1200000
# exception sentece number:  1205490
# 1210000
# exception sentece number:  1215985
# exception sentece number:  1216682
# 1220000
# 1230000
# exception sentece number:  1234609
# 1240000
# exception sentece number:  1246998
# 1250000
# 1260000
# 1270000
# 1280000
# exception sentece number:  1283080
# 1290000
# 1300000
# 1310000
# 1320000
# exception sentece number:  1322092
# exception sentece number:  1326339
# exception sentece number:  1328700
# 1330000
# exception sentece number:  1339649
# 1340000
# 1350000
# 1360000
# 1370000
# 1380000
# exception sentece number:  1384607
# 1390000
# 1400000
# exception sentece number:  1409920
# 1410000
# 1420000
# 1430000
# 1440000
# 1450000
# exception sentece number:  1451608
# exception sentece number:  1454577
# exception sentece number:  1456535
# 1460000
# 1470000
# exception sentece number:  1476808
# 1480000
# 1490000
# 1500000
# 1510000
# exception sentece number:  1518729
# 1520000
# 1530000
# 1540000
# exception sentece number:  1548659
# 1550000
# exception sentece number:  1554887
# 1560000
# 1570000
# 1580000
# 1590000
# 1600000
# exception sentece number:  1600860
# exception sentece number:  1602263
# 1610000
# 1620000
# 1630000
# exception sentece number:  1638214
# 1640000
# 1650000
# 1660000
# exception sentece number:  1664054
# exception sentece number:  1665707
# 1670000
# 1680000
# exception sentece number:  1680123
# exception sentece number:  1681892
# exception sentece number:  1684367
# exception sentece number:  1688916
# 1690000
# exception sentece number:  1691011
# 1700000
# 1710000
# 1720000
# exception sentece number:  1722652
# exception sentece number:  1728506
# 1730000
# 1740000
# 1750000
# exception sentece number:  1753141
# exception sentece number:  1753912
# 1760000
# 1770000
# 1780000
# exception sentece number:  1787860
# 1790000
# exception sentece number:  1795804
# 1800000
# exception sentece number:  1802744
# exception sentece number:  1802794
# 1810000
# exception sentece number:  1815455
# 1820000
# exception sentece number:  1821211
# exception sentece number:  1827765
# 1830000
# exception sentece number:  1834533
# exception sentece number:  1836619
# 1840000
# 1850000
# 1860000
# exception sentece number:  1864838
# 1870000
# exception sentece number:  1871794
# exception sentece number:  1877593
# 1880000
# 1890000
# 1900000
# 1910000
# 1920000
# exception sentece number:  1923767
# 1930000
