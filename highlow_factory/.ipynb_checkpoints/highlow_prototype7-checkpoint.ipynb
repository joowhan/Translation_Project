# %%
import time
import matplotlib.pyplot as plt
import numpy as np
import math as mt
import seaborn as sns
from tqdm import tqdm
import pandas as pd
from konlpy.tag import Hannanum, Mecab
from hangul_utils import split_syllables, join_jamos
from tqdm.auto import tqdm
from kiwipiepy import Kiwi
import re
from pykospacing import Spacing
#from eunjeon import Mecab
han = Hannanum()
mec = Mecab()

number = 100

# 초성 리스트. 00 ~ 18
CHOSUNG_LIST = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
# 중성 리스트. 00 ~ 20
JUNGSUNG_LIST = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']
# 종성 리스트. 00 ~ 27 + 1(1개 없음)
JONGSUNG_LIST = ['_', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

H_LIST = ['니다', '니까', '요', '시오', '죠']


EF_ONLY = [
    
    [['ㅅ','ㅡ','ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㄷ','ㅏ']],
    [['ㄴ','ㅏ','ㅇ','ㅛ'],['ㄴ','ㅏ']],
    [['ㄷ','ㅐ','ㅇ','ㅛ'],['ㄷ','ㅐ']],
    [['ㅇ','ㅔ','ㅇ','ㅛ'],['ㅇ','ㅑ']],
    [['ㄴ','ㅔ','ㅇ','ㅛ'],['ㄷ','ㅏ']],
    [['ㄴ','ㅡ','ㄴ','ㄷ','ㅔ','ㅇ','ㅛ'],['ㄴ','ㅡ','ㄴ','ㄷ','ㅔ']],
    [['ㅈ','ㅛ'],['ㅈ','ㅣ']],
    [['ㅇ','ㅏ','ㅇ','ㅛ'],['ㅇ','ㅏ']],
    [['ㅇ','ㅓ','ㅇ','ㅛ'],['ㅇ','ㅓ']],
    [['ㅇ','ㅡ','ㅅ','ㅔ','ㅇ','ㅛ'],['ㅇ','ㅓ']],
    [['ㄱ','ㅓ','ㄷ','ㅡ','ㄴ','ㅇ','ㅛ'],['ㄱ','ㅓ','ㄷ','ㅡ','ㄴ']],
    #[['ㅎ','ㅅ','ㅡ','ㅂ','ㄴ','ㅣ','ㄲ','ㅏ'],['ㅎ','ㅇ','ㅏ']],
    [['ㅅ','ㅡ','ㅂ','ㄴ','ㅣ','ㄲ','ㅏ'],['ㅇ','ㅓ']],
    [['ㄴ','ㅡ','ㄴ','ㄷ','ㅔ','ㅇ','ㅛ'],['ㄴ','ㅡ','ㄴ','ㄷ','ㅔ']],
    [['ㅇ','ㅛ'],['']],
    
]

EP_EF = [
    
    [['ㅅ','ㅔ','ㅇ','ㅛ'],['ㄴ', 'ㅏ']]
    #-시오 family
    ,[['ㅡ','ㅅ','ㅣ','ㅂ','ㅅ','ㅣ','ㅇ','ㅗ'],['ㅓ']]
    ,[['ㅅ','ㅣ','ㅂ','ㅅ','ㅣ','ㅇ','ㅗ'],['ㄹ', 'ㅏ']],
    [['ㅅ','ㅣ','ㅂ','ㄴ','ㅣ','ㄲ','ㅏ'],['ㄴ','ㅣ']],
    [['ㅅ','ㅣ','ㄹ','ㄹ','ㅐ','ㅇ','ㅛ'],['ㄹ','ㄹ','ㅐ']],
]

#VCP+EF
VCP_EF = [
    
    [['ㅇ','ㅣ','ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㅇ','ㅣ','ㄷ','ㅏ']],
    [['ㅇ','ㅣ','ㅂ','ㄴ','ㅣ','ㄲ','ㅏ'],['ㅇ','ㅣ','ㅇ','ㅑ']],
    [['ㅈ','ㅛ'],['ㅇ','ㅑ']],
    [['ㅇ','ㅣ','ㅇ','ㅔ','ㅇ','ㅛ'],['ㅇ','ㅣ','ㅇ','ㅑ']],
    [['ㅇ','ㅖ','ㅇ','ㅛ'],['ㅇ','ㅑ']],
    [['ㄱ','ㅓ','ㅇ','ㅛ'],['ㅇ','ㅑ']],
    [['ㄹ','ㅏ','ㄷ','ㅓ','ㄴ','ㄷ','ㅔ','ㅇ','ㅛ'],['ㄹ','ㅏ','ㄷ','ㅓ','ㄴ','ㄷ','ㅔ']],
    [['ㄱ','ㅓ','ㅇ','ㅔ','ㅇ','ㅛ'],['ㄱ','ㅓ','ㅇ','ㅔ','ㅇ','ㅛ']],
    
]

XSA_EF = [
    [['ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㄷ','ㅏ']],
    [['ㅇ','ㅛ'],['']]
]
XSV_EF = [
    [['ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㄷ','ㅏ']],
    [['ㅎ','ㅐ','ㅇ','ㅛ'],['ㅎ','ㅏ','ㅈ','ㅏ']],
]
A_EF = [
    [['ㄱ','ㅓ','ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㄷ','ㅏ']],
    [['ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㄴ','ㄷ','ㅏ']],
    [['ㄱ','ㅖ','ㅅ','ㅔ','ㅇ','ㅛ'],['ㅇ','ㅣ','ㅆ','ㅇ','ㅓ']],
    [['ㅂ','ㄴ','ㅣ','ㄲ','ㅏ'],['ㄴ','ㅏ']],
    [['ㅇ','ㅛ'],['']]
    
    
]
EP=[
    [['ㅅ','ㅣ'],['ㄹ']],
    [['ㄱ','ㅔ','ㅆ'],['']]
]
#종결 어미
EF = [
    [['ㅅ','ㅡ','ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㄷ','ㅏ']],
    [[' ','ㅈ','ㅓ','ㄴ',' '],['ㄴ','ㅏ','_','ㄴ','ㅡ','ㄴ']],
    [['ㅇ','ㅓ','_','ㅇ','ㅛ','_'],['ㄷ','ㅏ','_']],
    [['ㅂ','ㄴ','ㅣ','ㄷ','ㅏ'],['ㄴ','ㄷ','ㅏ']],
    [['ㅇ','ㅔ','ㅇ','ㅛ'],['ㅇ','ㅑ']],
    [['ㅇ','ㅛ'],['']]
    #,[['ㅅ','ㅔ'],['ㅝ'],['ㅘ']]
]

NP = [
    
    [['ㅈ','ㅓ','ㄴ'],['ㄴ','ㅏ','ㄴ']],
    [['ㅈ','ㅓ'],['ㄴ','ㅏ']]
    
]

# 보조사
JX = [
    [['ㅇ','ㅣ','ㅇ','ㅛ'],['ㅇ','ㅣ','ㅇ','ㅑ']],
    [['ㅇ','ㅛ'],['']]
]

VX = [
    
    [['ㅈ','ㅜ'],['ㅈ','ㅜ'],['ㅈ','ㅝ']]
    
]

VV = [
    
    [['ㅇ','ㅗ'],['ㅇ','ㅗ'],['ㅇ','ㅘ']],
    [['ㅈ','ㅜ'],['ㅈ','ㅜ'],['ㅈ','ㅝ']],
    [['ㅎ','ㅏ'],['ㅎ','ㅏ'],['ㅎ','ㅐ']]
    
]

XR = [
    [['ㅈ','ㅚ','ㅅ','ㅗ','ㅇ'],['ㅁ','ㅣ','ㅇ','ㅏ','ㄴ'] ]
]
NNG = [
    [['ㅈ','ㅏ','ㅇ','ㅛ'],['ㅈ','ㅏ']]
]

#이거 이제 안쓴다
EXC = [
    
    ['ㅜ',1],
    ['ㅗ',2],
    ['ㅏ',3]
    
]

EXC_word = [
    
    ['ㅅㅔ',2]
    ,['ㅅㅣㅂ',2]
    
]

EXC_tags = [
    
    'EP',
    'EF'
    
]

class Jamodealer:
    jamo = []
    pp = ''
    def __init__(self,lis_word):
        
        self.jamo = []
        for i in lis_word:
            self.jamo.append(split_syllables(i))
        
    def make_one(self):
        self.pp = ''
        for i in self.jamo:
             self.pp= self.pp+i
                
        chars = list(set(self.pp))
        char_to_ix = { ch:i for i,ch in enumerate(chars) }
        ix_to_char = { i:ch for i,ch in enumerate(chars) }
        
        jamo_numbers = [char_to_ix[x] for x in self.pp]
        restored_jamo = ''.join([ix_to_char[x] for x in jamo_numbers])
        restored_text = join_jamos(restored_jamo)
        return restored_text

def tojamo(korean_word):
    r_lst = []
    for w in list(korean_word.strip()):
        ## 영어인 경우 구분해서 작성함. 
        if '가'<=w<='힣':
            ## 588개 마다 초성이 바뀜. 
            ch1 = (ord(w) - ord('가'))//588
            ## 중성은 총 28가지 종류
            ch2 = ((ord(w) - ord('가')) - (588*ch1)) // 28
            ch3 = (ord(w) - ord('가')) - (588*ch1) - 28*ch2
            r_lst.append([CHOSUNG_LIST[ch1], JUNGSUNG_LIST[ch2], JONGSUNG_LIST[ch3]])
        else:
            r_lst.append([w])
    return r_lst
    

def to1dim(input):
    result=[]
    for i in input:
        for j in i:
            result.append(j)
    return result

def to2dim(input):
    result = []
    li = []
    for i in input:
        if i == ' ':
            result.append([' '])
        else:
            li.append(i)
        if len(li)==3:
            result.append(li)
            li = []
    return result

def makeone(input):
    result = ''
    li = ''
    for i in input:
        if i[0]==' ':
            result = result+' '
        else:
            ind = ord('가')
            ind +=CHOSUNG_LIST.index(i[0])*588
            ind +=JUNGSUNG_LIST.index(i[1])*28
            ind +=JONGSUNG_LIST.index(i[2])
            result = result+chr(ind)
    return result
        
def li2str(input):
    st = ""
    for i in input:
        st = st+i
    return st

def str2li(input):
    li = []
    for i in range(len(input)):
        li.append(input[i])
    return li

def makejamodict(input):
    result = []
    for i in input:
        bullet = []
        one = []
        two = []
        gre1 = tojamo(i[0])
        for j in gre1:
            for k in j:
                one.append(k)
        bullet.append(one)
        gre2 = tojamo(i[1])
        for j in gre2:
            for k in j:
                two.append(k)
        bullet.append(two)
        result.append(bullet)
    return result

def makestrdict(input):
    result = []
    for i in input:
        bullet = []
        for j in range(len(i)):
            gre = li2str(i[j])
            bullet.append(gre)
        result.append(bullet)
    return result

#추가한 사전에 대한 str 사전을 생성, mapping 시키는 부분
EP_dict = makestrdict(EP)
EF_dict = makestrdict(EF)
NP_dict = makestrdict(NP)
JX_dict = makestrdict(JX)
VX_dict = makestrdict(VX)
VV_dict = makestrdict(VV)
XR_dict = makestrdict(XR)
NNG_dict = makestrdict(NNG)

Dict_list=['EP','EF','NP','JX','VX','VV','XR','NNG']

Dict_map = [EP_dict, EF_dict,NP_dict,JX_dict,VX_dict, VV_dict, XR_dict, NNG_dict]

EF_ONLY_dict = makestrdict(EF_ONLY)
EP_EF_dict = makestrdict(EP_EF)
VCP_EF_dict = makestrdict(VCP_EF)
A_EF_dict = makestrdict(A_EF)
XSA_EF_dict = makestrdict(XSA_EF)
XSV_EF_dict = makestrdict(XSV_EF)
#End of Mapping 

def to2lists(input):
    lis_word = []
    lis_tag = []
    #data = han.pos(input,ntags=22,flatten=True, join=False)
    data = mec.pos(input)
    for i in data:
        lis_word.append(i[0])
        lis_tag.append(i[1])
    return lis_word, lis_tag

#add in 2021.09.26
#To restore the space of sentence
def indee(lis, input):
    
    rlis = []
    
    for i in range(len(lis)):
        if lis[i]==input:
            rlis.append(i)
            
    for i in range(len(rlis)):
        rlis[i] = rlis[i]-i
            
    return rlis

def ind_lili(lis_space,lis_lis):
    
    rlis = []
    k=0
    for i in range(len(lis_lis)):
        
        if k in lis_space:
            rlis.append(i)
            
        k = k+len(lis_lis[i])
        
    
    return rlis

def union(lis, lis_lis):
    
    k = 0
    for i in lis:
        lis_lis.insert(i+k,' ')
        k = k+1
    
    

class Changer(object):
        
    def high_low(self, stc):
        result = stc
        
        space_list = indee(stc,' ')
        
        lis_word, lis_tag = to2lists(result)
        space_location = ind_lili(space_list, lis_word)
        
        key = -1
        for i in H_LIST:
            if i in lis_word[-2]:
                key = 1
        lis = []
        jam = Jamodealer(lis_word)       
        if key>0:
            
            
            for i in range(len(lis_tag)):
                res = jam.jamo[i]
                for k in range(len(Dict_list)):
                    dic = []
                    if 'EF' in lis_tag[i]:
                        if 'EF' == lis_tag[i]:
                            dic = EF_ONLY_dict
                        elif 'EP' in lis_tag[i]:
                            dic = EP_EF_dict
                        elif 'VCP' in lis_tag[i]:
                            dic = VCP_EF_dict
                        elif 'XSA' in lis_tag[i]:
                            dic = XSA_EF_dict
                        elif 'XSV' in lis_tag[i]:
                            dic = XSV_EF_dict
                        else:
                            dic = A_EF_dict
                        
                    elif Dict_list[k] in lis_tag[i]:
                        dic = Dict_map[Dict_list.index(Dict_list[k])]
                    for j in range(len(dic)):
                        if self.isExcept(dic[j])==1:
                            ind = self.indicator(i,jam.jamo,lis_tag,EXC_word, EXC_tags)
                            res = re.sub(dic[j][0],dic[j][ind],res)
                        else:
                            res = re.sub(dic[j][0],dic[j][1],res)
                lis.append(res)
            
            
            #print(jam.jamo[i])
        #print(lis)
        union(space_location, lis)
        jam.jamo = []
        for i in range(len(lis)):
            jam.jamo.append(lis[i])
        
        
        
        return jam.make_one()
    
    def low_high(self, stc):
        result = stc
        
        space_list = indee(stc, ' ')
        
        lis_word, lis_tag = to2lists(result)
        space_location = ind_lili(space_list, lis_word)
        
        key = -1
        
        for i in H_LIST:
            if i in lis_word[-2]:
                key = H_LIST.index(i)
                
        if key==-1:
            jam = Jamodealer(lis_word)
            
        
        
        
    def isExcept(self, input):
        if len(input)>=3:
            return 1
        else:
            return 0
        
    def indicator(self, ind, lis, tag, ex_word, exc_tags):
        re = 1
        for j in range(len(ex_word)):
            if exc_tags[j] in tag[ind+1]:
                for i in range(len(ex_word)):
                    if ex_word[i][0] in lis[ind+1]:
                        re = ex_word[i][1]
                        break
                        print(lis[ind-1])
        return re
        
    
    def processText(self,stc):
        result = stc
        res = self.high_low(result)
        #spacing = Spacing()
        #res = spacing(res)
        return res

# %%
#txt = '전 그것이 맞다고 생각합니다.'
tx = '그것을 먹어.'
ch = Changer()
ttt = ch.processText(tx)
#print(tt)
print(ttt)

# %%
import pandas as pd
number = 200
texts = pd.read_table('./data/hgu_clean.kr', sep ='\n')[:number]
texts = texts['26일이요?']

for i in range(0, number):
    tt = mec.pos(texts[i], flatten=True, join=True) 
    print(tt)
# Out:
# ['27/SN', '일/NNBC', '은/JX', '괜찮/VA', '나요/EF', '?/SF']
# ['중단/NNG', '시켜서/XSV+EC', '죄송/XR', '해요/XSA+EF', './SF']
# ['중단/NNG', '시켜서/XSV+EC', '죄송/XR', '해요/XSA+EF', './SF']
# ['아/IC', ',/SC', '이런/MM', '!/SF', '도저히/MAG', '생각/NNG', '이/JKS', '안/MAG', '나/VV', '는/ETM', '걸/NNB+JKO', './SF']
# ['Joe/SL', "'/SY", 's/SL', 'Café/SL', '라는/VCP+ETM', '레스토랑/NNG', '에/JKB', '가/VV', '고/EC', '싶/VX', '은데/EC', ',/SC', '알/VV', '고/EC', '계세요/VX+EF', '?/SF']
# ['보다/MAG', '나/VA', '은/ETM', '건강/NNG', '과/JC', '생활/NNG', '회사/NNG', '의/JKG', '글렌/NNP', '토마스/NNP', '입니다/VCP+EF', './SF']
# ['스타워즈/NNP', '는/JX', '어때/VA+EF', '?/SF']
# ['데이터/NNG', '코디네이터/NNG', '나/JC', '데이터/NNG', '매니저/NNG', '가/JKS', '어떨까/VA+EC', '요/JX', '?/SF']
# ['화성/NNG', '에서/JKB', '온/VV+ETM', '로봇/NNG', '이/VCP', '요/EF', '!/SF', '좋/VA', '아요/EF', '!/SF', '특수/NNG', '효과/NNG', '가/JKS', '대단/XR', '하/XSA', '대요/EF', './SF']
# ['팩스/NNG', '를/JKO', '보내/VV+EC', '줘서/VX+EC', '감사/NNG', '합니다/XSV+EF', './SF']
# ['11/SN', '월/NNBC', '30/SN', '일/NNBC', '날짜/NNG', '로/JKB', '팩스/NNG', '를/JKO', '보내/VV+EC', '줘서/VX+EC', '감사/NNG', '합니다/XSV+EF', './SF']
# ['자격/NNG', '을/JKO', '취득/NNG', '하/XSV', '기/ETN', '위해/VV+EC', '공부/NNG', '중/NNB', '이/VCP', '에요/EF', './SF']
# ['간호사/NNG', '자격/NNG', '을/JKO', '취득/NNG', '하/XSV', '기/ETN', '위해/VV+EC', '공부/NNG', '중/NNB', '이/VCP', '에요/EF', './SF']
# ['국가/NNG', '시험/NNG', '을/JKO', '향해/VV+EC', '공부/NNG', '중/NNB', '이/VCP', '에요/EF', './SF']
# ['공무원/NNG', '에/JKB', '되/VV', '기/ETN', '위한/VV+ETM', '국가/NNG', '시험/NNG', '을/JKO', '향해/VV+EC', '공부/NNG', '중/NNB', '이/VCP', '에요/EF', './SF']
# ['잘/MAG', '됐/VV+EP', '어요/EF', './SF', '그럼/MAJ', '이제/MAG', '집/NNG', '에/JKB', '가/VV', '도/EC', '되/VV', '나요/EF', '?/SF']
# ['죄송/XR', '합니다/XSA+EF', './SF', '그녀/NP', '는/JX', '안/NNG', '에/JKB', '없/VA', '네요/EF', './SF', '메모/NNG', '남겨/VV+EC', '드릴까요/VX+EF', '?/SF']
# ['내려/VV+EC', '줄래요/VX+EF', './SF']
# ['올려/VV+EC', '줄래요/VX+EF', './SF']
# ['작/VA', '은/ETM', '목소리/NNG']
# ['스미스/NNP', '선생/NNG', '님/XSN', './SF', '저/MM', '화장실/NNG', '에/JKB', '가/VV', '야/EC+VX', '겠/EP', '는데요/EF', './SF']
# ['화장실/NNG', '이/JKS', '정말/MAG', '급해요/VA+EF', '!/SF']
# ['그럼/MAJ', '총수입/NNG', '의/JKG', '얼마나/MAG', '되/VV', '는/ETM', '거/NNB', '죠/VCP+EF', '?/SF']
# ['0136521798/SN', '이/VCP', '에요/EF', './SF']
# ['1/SN', ',/SC', '199/SN', '달러/NNBC', '예요/VCP+EF', '?/SF']
# ['100/SN', '그램/NNBC', '에/JKB', '비타민/NNG', 'C/SL', '의/JKG', '함유량/NNG', '은/JX', '레몬/NNG', '보다/JKB', '높/VA', '습니다/EF', './SF']
# ['ABC/SL', '사/VV', '는/ETM', '힘든/VA+ETM', '상대/NNG', '라고/VCP+EC', '들/VX', '었/EP', '어요/EF', './SF']
# ['A/SL', '열/NR', '10/SN', '번/NNBC', '자리/NNG', '를/JKO', '찾/VV', '고/EC', '있/VX', '는데요/EF', './SF']
# ['B/SL', '애/NNG', '비뉴/NNG', '에/JKB', '있/VV', '는/ETM', '그/MM', '스테이크/NNG', '식당/NNG', '어때요/VA+EF', '?/SF', '전/NNG', '부터/JX', '거기/NP', '에/JKB', '가/VV+EC', '보/VX', '고/EC', '싶/VX', '었/EP', '거든요/EF', './SF']

# %%
import pandas as pd
number = 200
texts = pd.read_table('./data/hgu_clean.kr', sep ='\n')[:number]
texts = texts['26일이요?']

ch = Changer()

for i in range(0, number):
    tt = ch.processText(texts[i])
    print(tt)
# Out:
# 27일은 괜찮나?
# 중단시켜서 미안해.
# 중단시켜서 미안해.
#
# Joe's Café 라는 레스토랑에 가고 싶은데, 알고 있어?
# 보다 나은 건강과 생활 회사의 글렌 토마스이다.
#
# 데이터 코디네이터나 데이터 매니저가 어떨까?
# 화성에서 온 로봇이! 좋아! 특수 효과가 대단하대.
# 팩스를 보내줘서 감사하다.
# 11월30일 날짜로 팩스를 보내줘서 감사하다.
# 자격을 취득하기 위해 공부 중이야.
# 간호사 자격을 취득하기 위해 공부 중이야.
# 국가시험을 향해 공부 중이야.
# 공무원에 되기 위한 국가시험을 향해 공부 중이야.
# 잘 됐어. 그럼 이제 집에 가도 되나?
# 미안하다. 그녀는 안에 없다. 메모 남겨 드릴까?
# 내려 줄래.
# 올려 줄래.
#
# 스미스 선생님. 저 화장실에 가야는데.
# 화장실이 정말 급해!
# 그럼 총수입의 얼마나 되는 거야?
# 0136521798이야.
# 1,199달러야?
# 100그램에 비타민C의 함유량은 레몬보다 높다.
#
# 105번이 그 근처에 서는 것 같은데, 확실하진 않아.
# 낸시에게 물어 보나. 낸시는 나보다 더 자주 그 버스를 이용하거든.
# 105편의 탑승게이트는 변경되었어?
# 10분 정도 후에 다시 걸어줘나.
# 10분 후에 다시 걸지.
# 10분 후에 와.
# 10분정도 기다릴ㄹ 수 있어?
# 10세 여자 아이의 선물로는 무엇이 좋을 것 같어?
# 10시 정각이야.
# 10시 정각이야.
# 10시쯤에 목욕하자.
# 10일에는 바쁘니?
# 11번가와 브로드웨이가 만나는 모퉁이로 가는 버스가 있나?
# 123호실 좀 대 줘나?
#
# 125쪽이다.
# 12시부터 1시까지야.
# 12시쯤에 자.
# 12일 월요일에 뉴욕에서 필라델피아로 가는 표를 구하려고 하는데.
# 12페이지 밖에 안 돼. 인쇄하는데 오래 걸리지 않을 거야.
# 14달러 47센트이다. 정말 미안하다.
# 15분 쯤 뒤에 내 방으로 와 줄래?
# 15세이기때문에 술은 마실 수 없다.
# 15일이야.
# 17일은 몇 요일이야?
# 1981년에 태어났어.
# 1990년에 동화대학에 입학을 했어.
# 1995년에 고등학교를 졸업했어.
# 1개월 있을 예정이다.
# 1달러 50센트에요.
# 1달러25센트야.
# 1박에 12달러밖에 안 돼.
# 1번 전철을 타.
# 1시간 반정도 걸리나.
# 1시간야.
# 1시반부터 3시까지야.
# 1주일정도 전부터 이다.
#
# 2, 3시간이면 돌아올 것이라 생각이 되.
#
#
# 2,3일 전부터 귀 울림이 있었다.
# 2,3일 전부터 눈이 굉장히 가렵다.
#
#
# 2007년 6월이야.
#
# 20달러짜리 지폐 좀 잔돈으로 바꿔 줄어?
# 20분 정도이다.
# 20분 후에 문 닫다.
# 20센트자리 우표 3장이랑 50센트짜리 우표 2장 줘나.
# 20센트짜리 우표 5장 줘나.
# 20일의 오전 중이야.
# 20일의 오후야.
# 20일이야.
# 21퍼센트가 약간 안 되지.
# 23달러 92센트 되다.
# 23달러 92센트라. 그 금액이 확실한가?
# 2개 살 테니까 조금 깎아 줘나.
# 2달러 20센트, 허클베리 핀과 미국 단편 소설을 대출했군.
# 2달러 90센트이다.
# 2번 전철에 타.
# 2번이나 3번 계산대를 이용하라.
# 2블럭을 걸어가.
# 2시 10분이다.
# 2시 조금 넘었어.
# 2시10분 조금 넘었어.
# 2시10분이야.
# 2시15분이야.
# 2시30분이야.
# 2시간이야.
# 2시간정도야.
# 2천달러이다.
#
# 30분 내로 될 거요. 식탁이나 차리지 그래?
# 30분 정도야.
# 30분정도이다.
# 30분쯤이. 출발하다. 안전벨트 매나.
#
# 30일은 괜찮아.
# 32달러 78센트이다.
# 38도 정도의 열이 있어.
# 3교대로 운영하는 건 어떨까?
# 3년 전에 재혼했어.
#
# 3년만인가요?
# 3년전에 위궤양으로 입원했다.
# 3시 몇 분 전이야.
# 3시5분 전이야.
# 3시가 어때?
# 3시에서 5시까지 시간이 있어.
# 3시쯤에 와나. 아무것도 안 가져와도 되. 구워 먹을 음식이 많이 있거든.
# 3일 빌리고 싶은데.
#
# 3일간 금연했지만, 담배를 피우지 못하니 죽을 것 같았어.
# 3일날 셀러스 박사님 진료 예약을 할 수 있을까?
# 3일에 한 번 데이트를 해.
# 3일정도 머무를 겁니다.
# 3주 연휴는 어떻게 지냈어?
#
# 3주정도 된다.
#
# 4년쯤 됐어. 처음에는 텔레마케터로 시작했는데, 지금은 뉴잉글랜드 지역 담당 영업 대리야.
# 4명이야.
#
# 4월25일이야.
# 500달러.
# 500달러짜리 여행자 수표를 사용할 수 있어?
# 50달러짜리 10장, 10달러짜리 50장 부탁하다.
# 50세 여성에게는 어떤 것이 좋어?
# 555-3401이다.
# 555-8765이다.
# 55달러이다.
# 5갤런 부탁하다.
# 5년전에 결혼했어.
# 5년전에 김 전기에 입사했어.
# 5달러75센트가 되다.
# 5달러의 수수료가 듭니다.
# 5달러짜리 두 개랑 나머지는 전부 1달러짜리로 줘나?
#
#
# 5번 전철에 타.
# 5분 간격으로 와.
#
#
# 5시20분에 와.
# 5시까지 도착해야 돼.
# 5시반쯤에 만나.
# 5월초에 필기시험을 본다.
# 5일간 정도야.
# 5일은 몇 요일이었어?
# 600달러는 너무 싸요! 800달러가 어때?
#
# 6살짜리 딸이 천식이어서, 금연하기로 했다.
# 6시 30분에 사무실 앞에서 만나. 화랑은 여기서 조금만 걸어가면 돼.
# 6시까지이구. 내일 아침 8시에 다시 문을 열어.
# 6시반에 일어나.
# 6시에 끝나요.
# 6시. 잘됐다. 그럼 5시 30분쯤에 들를게. 감사하다.
#
#
# 6시쯤에 끝나요.
# 6월 21일 샌디이고 공항에서.
# 6일간이야.
# 76에 128이로군. 그것도 좋다.
# 798-092이다.
# 7과 1/2사이즈 정도 신을 거야.
# 7번 버스에 타.
# 7시 15분에 극장 앞에서 봐.
# 7시 이후엔 시간이 있어.
# 7시반에 집에서 나와.
# 7시부터 8시까지 1시간이다.
# 7시에 아침밥을 먹어.
# 7시야.
# 8사이즈도 한번 입어 봐야 될 것 같아.
# 8시 전에 집에 도착하자.
# 8월 3일부터 10일까지 사용할 방 있어?
# 90026이야.
# 911에 전화 해줘나.
# 9년이야. 처음에는 아동 도서를 편집하는 준 편집 직원으로 시작해서 결국 젊은 독자부 편집장이 됐어.
# 9달러 95센트이다.
# 9시 25분 라 과르디아 공항을 출발하는 항공편이 있는데, 코네티컷 주의 하트 포드에 잠시 들렀다가 나서 11시 15분에 보스턴의 로건 공항에 도착하다.
#
# 9시반부터 6시까지야.
# 9시반부터야.
#
# 9시부터이다.
#
# 9월 20일 7872편, 인천행을 예약했다.
# 이코노미 트리뷴 지에서 ABC 기업이 곧 생산을 증가시킬 거라던데.
# ABC사는 힘든 상대라고 들었어.
# A열 10번 자리를 찾고 있는데.
# B 애비뉴에 있는 그 스테이크 식당 어때? 전부터 거기에 가 보고 싶었거든.

# %%
import pandas as pd
number = 700
texts = pd.read_table('./data/hgu_clean.kr', sep ='\n')[:number]
texts = texts['26일이요?']

for i in range(200, number):
    tt = mec.pos(texts[i], flatten=True, join=True) 
    print(tt)
# Out:
# ['Boyz/SL', 'Ⅱ/SN', 'Men/SL', '콘서트/NNG', '표/NNG', '가/JKS', '두/MM', '장/NNBC', '있/VV', '어/EF', './SF']
# ['나/NP', '하고/JKB', '갈래/VV+EF', '?/SF']
# ['CD/SL', '가/JKS', '테이프/NNG', '보다/JKB', '더/MAG', '비싸/VA', '죠/EF', '?/SF']
# ['CD/SL', '가게/NNG', '로/JKB', '갈/VV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['CD/SL', '가게/NNG', '에서/JKB', '남부/NNG', '올/VV+ETM', '스타즈/NNP', '의/JKG', '앨범/NNG', '을/JKO', '샀/VV+EP', '어요/EF', './SF']
# ['CD/SL', '는/JX', '어디/NP', '에/JKB', '있/VV', '어/EF', './SF']
# ['DVD/SL', '는/JX', '화질/NNG', '이/JKS', '좋/VA', '아서/EC', '좋/VA', '습니다/EF', '?/SF']
# ['DVD/SL', '를/JKO', '사/VV', '는/ETM', '것/NNB', '은/JX', '영원히/MAG', '소장/NNG', '할/XSV+ETM', '수/NNB', '있/VV', '기/ETN', '때문/NNB', '입니다/VCP+EF', './SF']
# ['가까운/VA+ETM', '시일/NNG', '내/NNB', '에/JKB', '다시/MAG', '와/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['가까운/VA+ETM', '편의점/NNG', '까지/JX', '얼마나/MAG', '걸립니까/VV+EF', '?/SF']
# ['가끔/MAG', '골프/NNG', '를/JKO', '하/VV', '는/ETM', '정도/NNG', '입니다/VCP+EF', './SF']
# ['가끔/MAG', '수업/NNG', '에/JKB', '빠져요/VV+EF', './SF']
# ['가끔/MAG', '영화/NNG', '를/JKO', '보/VV', '러/EC', '나가/VX', '요/EF', './SF']
# ['가끔/MAG', '온천/NNG', '에/JKB', '가요/NNG', './SF']
# ['가끔/MAG', '씩/XSN', '은/JX', '스테이크/NNG', '를/JKO', '드셔도/VV+EP+EC', '돼요/VV+EF', './SF', '자/IC', ',/SC', '이걸/NP+JKO', '한/MM', '번/NNBC', '맛보/VV', '세요/EP+EF', './SF']
# ['가끔/MAG', '은/JX', '휴일/NNG', '도/JX', '출근/NNG', '을/JKO', '해요/VV+EF', './SF']
# ['가능/NNG', '하/XSA', '면/EC', '매일/MAG', '영어/NNG', '를/JKO', '공부/NNG', '하/XSV', '도록/EC', '유의/NNG', '하/XSV', '고/EC', '있/VX', '어요/EF', './SF']
# ['가능/NNG', '하/XSA', '면/EC', '몇/MM', '주/NNBC', '안/VV', '에요/EF', './SF', '접수/NNG', '계원/NNG', '이/JKS', '검사/NNG', '날짜/NNG', '를/JKO', '잡/VV', '아/EC', '드릴/VX+ETM', '수/NNB', '있/VV', '을/ETM', '겁니다/NNB+VCP+EF', './SF']
# ['가능/NNG', '한/XSA+ETM', '한/MM', '가까운/VA+ETM', '길/NNG', '로/JKB', '가/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['가능/NNG', '한/XSA+ETM', '한/MM', '빨리/MAG', '주문/NNG', '해/XSV+EC', '주/VX', '셨/EP+EP', '으면/EC', '합니다/VX+EF', './SF']
# ['가드레일/NNG', '을/JKO', '들이받/VV', '았/EP', '습니다/EF', './SF']
# ['가랑비/NNG', '가/JKS', '내려요/VV+EF', './SF']
# ['가래/NNG', '가/JKS', '나와서/VV+EC', '곤란/NNG', '합니다/XSA+EF', './SF']
# ['가래/NNG', '가/JKS', '생겨요/VV+EF', './SF']
# ['가래/NNG', '는/JX', '무슨/MM', '색/NNG', '입니까/VCP+EF', '?/SF']
# ['가려워/VA+EC', '요/JX', './SF']
# ['가르치/VV', '는/ETM', '것/NNB', '이/JKS', '특기/NNG', '예요/VCP+EF', './SF']
# ['가만/MAG', '있/VV', '자/EF', './SF', '포레스트/NNP', '검프/NNP', '였/VCP+EP', '던가/EF', '?/SF']
# ['가만/MAG', '있/VV', '자/EF', './SF', '우리/NP', '가/JKS', '어디/NP', '까지/JX', '이야기/NNG', '했었/XSV+EP', '지/EF', '?/SF']
# ['가만히/MAG', '있/VV', '어서/EC', '미안/NNG', '해/XSV+EF', './SF']
# ['가방/NNG', '매장/NNG', '은/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['가방/NNG', '안/NNG', '에/JKB', '면도기/NNG', '가/JKS', '들/VV', '어/EC', '있/VX', '는/ETM', '데/NNB', '괜찮/VA', '습니까/EF', '?/SF']
# ['가방/NNG', '한/MM', '번/NNBC', '더/MAG', '확인/NNG', '해/XSV+EC', '봐/VX+EF', './SF']
# ['가방/NNG', '은/JX', '이리/MAG', '주/VV', '세요/EP+EF', './SF']
# ['가방/NNG', '은/JX', '자기/NP', '방/NNG', '에/JKB', '가지/VV', '고/EC', '가/VX', '세요/EP+EF', './SF']
# ['가방/NNG', '을/JKO', '찾/VV', '고/EC', '있/VX', '어요/EF', './SF']
# ['가벼운/VA+ETM', '운동/NNG', '을/JKO', '좋/VA', '아/EC', '해요/VX+EF', './SF']
# ['가/VV', '볼/EC+VX+ETM', '만/NNB', '한/XSA+ETM', '곳/NNG', '을/JKO', '알려/VV+EC', '주/VX', '시/EP', '겠/EP', '어요/EF', '?/SF']
# ['가사/NNG', '를/JKO', '해요/VV+EF', './SF']
# ['가스/NNG', '는/JX', '언제/NP', '부터/JX', '넣/VV', '어/EC', '주/VX', '나요/EF', '?/SF']
# ['전자/NNG', '레인지/NNG', '도/JX', '새/MM', '것/NNB', '으로/JKB', '썼/VV+EP', '으면/EC', '합니다/VX+EF', './SF']
# ['최/XPN', '고급/NNG', '가전제품/NNG', '을/JKO', '갖/VV', '고/EC', '싶/VX', '습니다/EF', './SF']
# ['허리/NNG', '부분/NNG', '을/JKO', '줄여/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['가요/NNG', '프로그램/NNG', '을/JKO', '많이/MAG', '좋/VA', '아/EC', '해요/VX+EF', './SF']
# ['가을/NNG', '옷/NNG', '을/JKO', '갖/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['가을/NNG', '은/JX', '내/NP', '가/JKS', '좋/VA', '아/EC', '하/VV', '는/ETM', '계절/NNG', '이/VCP', '에요/EF', './SF']
# ['가을/NNG', '은/JX', '단풍/NNG', '이/JKS', '아름다워요/VA+EF', './SF']
# ['가장/MAG', '가까운/VA+ETM', '관광/NNG', '안내소/NNG', '가/JKS', '어디/NP', '입니까/VCP+EF', '?/SF']
# ['가장/MAG', '가까운/VA+ETM', '전철역/NNG', '은/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['가장/MAG', '가까운/VA+ETM', '지하철역/NNG', '은/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['가장/MAG', '싼/VA+ETM', '것/NNB', '은/JX', '어느/MM', '것/NNB', '입니까/VCP+EF', '?/SF']
# ['가장/MAG', '싼/VA+ETM', '항공사/NNG', '를/JKO', '가르쳐/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['가장/MAG', '하/VV', '고/EC', '싶/VX', '은/ETM', '것/NNB', '은/JX', '뭐/NP', '예요/VCP+EF', '?/SF']
# ['가정/NNG', '용품/NNG', '은/JX', '어디/NP', '에/JKB', '있/VV', '습니까/EF', '?/SF']
# ['가져가/VV', '실/EP+ETM', '겁니까/NNB+VCP+EC', ',/SC', '아니면/MAJ', '안/NNG', '에서/JKB', '드실/VV+EP+ETM', '겁니까/NNB+VCP+EF', '?/SF']
# ['가져오/VV', '지/EC', '않/VX', '았/EP', '는데요/EF', './SF']
# ['가족/NNG', '모두/NNG', '가/JKS', '기뻐하/VV', '고/EC', '있/VX', '어요/EF', './SF']
# ['가족/NNG', '끼리/XSN', '만/JX', '의/JKG', '오붓/XR', '한/XSA+ETM', '시간/NNG', '을/JKO', '보내/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['가족/NNG', '들/XSN', '에게/JKB', '안부/NNG', '전해/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['가족/NNG', '은/JX', '평안/NNG', '하/XSA', '십니까/EP+EF', '?/SF']
# ['가족/NNG', '을/JKO', '돌봐/VV+EC', '줘서/VX+EC', '감사/NNG', '해요/XSV+EF', './SF']
# ['가족/NNG', '이랑/JC', '느긋/XR', '하/XSA', '게/EC', '있/VX', '어요/EF', './SF']
# ['가족/NNG', '이랑/JC', '리노/NNP', '에/JKB', '일박/NNG', '여행/NNG', '을/JKO', '갔/VV+EP', '어요/EF', './SF']
# ['가족/NNG', '이랑/JC', '워싱턴/NNP', '디/NNP', '씨/NNB', '에/JKB', '일박/NNG', '여행/NNG', '을/JKO', '할/VV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['가족/NNG', '이랑/JKB', '하이킹/NNG', '에/JKB', '갔/VV+EP', '어요/EF', './SF']
# ['가죽/NNG', '부츠/NNG', '를/JKO', '갖/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['가지각색/NNG', '인/VCP+ETM', '사람/NNG', '들/XSN', '이/JKS', '있/VA', '으니깐요/EF', './SF']
# ['가지/VV', '러/EC', '오/VX', '실/EP+ETM', '겁니까/NNB+VCP+EF', '?/SF', '아니면/MAJ', '배달/NNG', '하/XSV', '실/EP+ETM', '겁니까/NNB+VCP+EF', '?/SF']
# ['각/MM', '페이지/NNG', '를/JKO', '2/SN', '장/NNBC', '씩/XSN', '복사/NNG', '해/XSV+EC', '줄래요/VX+EF', '?/SF']
# ['각각/MAG', '계산/NNG', '해/XSV+EC', '주/VX', '세요/EP+EF', './SF']
# ['각자/NNG', '계산/NNG', '합시다/XSV+EF', './SF']
# ['간단/XR', '하/XSA', '게/EC', '먹/VV', '고/EC', '싶/VX', '은데요/EF', './SF']
# ['간단/XR', '한/XSA+ETM', '식사/NNG', '는/JX', '뭐/NP', '예요/VCP+EF', '?/SF']
# ['간단/XR', '한/XSA+ETM', '아침/NNG', '을/JKO', '먹/VV', '어요/EF', './SF']
# ['간단/XR', '한/XSA+ETM', '아침/NNG', '을/JKO', '먹/VV', '어요/EF', './SF']
# ['간단/XR', '한/XSA+ETM', '요리/NNG', '몇/MM', '가지/NNBC', '만/JX', '했/VV+EP', '는데/EF', './SF']
# ['간단/XR', '해/XSA+EF', './SF', '밀가루/NNG', '한/MM', '파운드/NNBC', ',/SC', '버터/NNG', '한/MM', '파운드/NNBC', '그리고/MAJ', '설탕/NNG', '한/MM', '파운드/NNBC', '가/JKS', '들어가/VV', '거든/EF', './SF']
# ['간단/XR', '해요/XSA+EF', './SF', '브로드웨이/NNP', '로/JKB', '해서/VV+EC', '89/SN', '번/NNBC', '가/VV+EC', '까지/JX', '가요/NNG', './SY', '서쪽/NNG', '으로/JKB', '계속/MAG', '가/VV', '면/EC', '포레스트/NNP', '애/NNG', '비뉴/NNG', '가/JKS', '나오/VV', '는데/EC', ',/SC', '사무실/NNG', '은/JX', '89/SN', '번/NNBC', '가와/NNP', '포레스트/NNP', '가/JKS', '만나/VV', '는/ETM', '모퉁이/NNG', '에/JKB', '있/VV', '어요/EF', './SF']
# ['간단히/MAG', '말/NNG', '하/XSV', '면/EC', ',/SC', 'A/SL', '형/XSN', '과/JC', 'B/SL', '형/XSN', '의/JKG', '특징/NNG', '을/JKO', '함께/MAG', '가진/VV+ETM', '사람/NNG', '입니다/VCP+EF', './SF']
# ['간단히/MAG', '말/NNG', '해서/XSV+EC', ',/SC', '당신/NP', '의/JKG', '영업/NNG', '철학/NNG', '은/JX', '뭐/NP', '죠/VCP+EF', '?/SF']
# ['간식/NNG', '은/JX', '피하/VV', '는/ETM', '것/NNB', '이/JKS', '좋/VA', '아요/EF', './SF']
# ['노인/NNG', '건강/NNG', '보험/NNG', '에/JKB', '대해/VV+EC', '어떻게/MAG', '생각/NNG', '해요/XSA+EF', '?/SF']
# ['갈림길/NNG', '을/JKO', '우측/NNG', '으로/JKB', '가요/NNG', './SF']
# ['감격/NNG', '스럽/XSA', '네요/EF', '!/SF']
# ['감격/NNG', '스럽/XSA', '네요/EF', '!/SF']
# ['감기/NNG', '는/JX', '거의/MAG', '안/MAG', '걸려요/VV+EF', './SF']
# ['감기/NNG', '에/JKB', '걸렸/VV+EP', '어요/EF', './SF']
# ['감기/NNG', '에/JKB', '걸렸/VV+EP', '어요/EF', './SF']
# ['감독/NNG', '하/XSV', '고/EC', '있/VX', '는/ETM', '거/NNB', '지/VCP+EF', './SF']
# ['감동/NNG', '을/JKO', '했/VV+EP', '어요/EF', './SF']
# ['감동/NNG', '했/XSA+EP', '어/EF', './SF', '마음/NNG', '깊이/MAG', '느꼈/VV+EP', '어요/EF', './SF', '인상/NNG', '적/XSN', '이/VCP', '었/EP', '어요/EF', './SF']
# ['감동/NNG', '했/XSA+EP', '어요/EF', './SF']
# ['감명/NNG', '을/JKO', '받/VV', '았/EP', '어요/EF', './SF']
# ['감사/NNG', '는/JX', '무슨/MM', './SF']
# ['감사/NNG', '한/XSA+ETM', '마음/NNG', '을/JKO', '전하/VV', '고/EC', '싶/VX', '어서/EC', '작/VA', '은/ETM', '선물/NNG', '을/JKO', '준비/NNG', '했/XSV+EP', '어요/EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', ',/SC', '스타인/NNP', '씨/NNB', './SY', '필요/NNG', '한/XSA+ETM', '것/NNB', '은/JX', '이게/NP+JKS', '전부/NNG', '입니다/VCP+EF', './SF']
# ['대단히/MAG', '감사/NNG', '합니다/XSV+EF', './SF']
# ['대단히/MAG', '감사/NNG', '합니다/XSV+EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', './SF', '고객/NNG', '께서/JKS', '는/JX', '이/MM', '항공편/NNG', '으로/JKB', '200/SN', '마일리지/NNG', '를/JKO', '받/VV', '으시/EP', '게/EC', '되/VV', '고/EC', ',/SC', '앞/NNG', '으로/JKB', '여행/NNG', '할/XSV+ETM', '수/NNB', '있/VV', '는/ETM', '100/SN', '달러/NNBC', '쿠폰/NNG', '을/JKO', '받/VV', '으시/EP', '게/EC', '됩니다/VV+EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', './SF', '그/IC', '새/MM', '항공편/NNG', '은/JX', '노스/NNP', '이스트/NNP', '8988/SN', '편/NNBC', '으로/JKB', '8/SN', '시/NNBC', '15/SN', '분/NNBC', '에/JKB', 'JFK/SL', '공항/NNG', '을/JKO', '출발/NNG', '합니다/XSV+EF', './SF', '저희/NP', '단골/NNG', '고객/NNG', '클럽/NNG', '의/JKG', '회원/NNG', '이/VCP', '세요/EP+EF', '?/SF']
# ['감사/NNG', '합니다/XSV+EF', './SF', '또/MAG', '방문/NNG', '해/XSV+EC', '주/VX', '십시오/EP+EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', './SF', '실례/NNG', '했/XSV+EP', '습니다/EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', './SF', '아르고/NNP', '씨/NNB', '대신/NNG', '사과/NNG', '드리/VV', '겠/EP', '습니다/EF', './SF', '일/NR', '주일/NNBC', '내내/MAG', '회의/NNG', '에/JKB', '참석/NNG', '하/XSV', '시/EP', '느라고/EC', '바쁘/VA', '세요/EP+EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', './SF', '오늘/MAG', '실험실/NNG', '에서/JKB', '선생/NNG', '님/XSN', '의/JKG', '신체/NNG', '검사/NNG', '결과/NNG', '가/JKS', '나왔/VV+EP', '습니다/EF', './SF']
# ['감사/NNG', '합니다/XSV+EF', './SF', '조디/NNP', ',/SC', '여기/NP', '않/VV', '아/EF', './SF', '내/NP', '가/JKS', '커피/NNG', '사/VV+EC', '올게/VX+EF', './SF']
# ['감사/NNG', '해요/XSV+EF', './SF']
# ['감사/NNG', '해요/XSV+EF', './SF']
# ['감사/NNG', '해요/XSV+EF', './SF']
# ['감자/NNG', '튀김/NNG', '을/JKO', '곁들이/VV', '시/EP', '겠/EP', '어요/EF', '?/SF']
# ['감자/NNG', '는/JX', '비타민/NNG', 'C/SL', '가/JKS', '풍부/XR', '합니다/XSA+EF', './SF']
# ['감자/NNG', '는/JX', '어떻게/MAG', '해/VV+EC', '드릴까요/VX+EF', '?/SF']
# ['감자/NNG', '를/JKO', '삶/VV', '아/EC', '줄래/VX+EF', '?/SF']
# ['감자/NNG', '수프/NNG', '가/JKS', '있/VA', '습니까/EF', '?/SF']
# ['감자/NNG', '에/JKB', '는/JX', '칼슘/NNG', '도/JX', '풍부/XR', '하/XSA', '게/EC', '포함/NNG', '되/XSV', '어/EC', '있/VX', '습니다/EF', './SF']
# ['감자튀김/NNG', '으로/JKB', '주/VV', '세요/EP+EF', './SF']
# ['감정/NNG', '표현/NNG', '이/JKS', '서툴러요/VA+EF', './SF']
# ['갑자기/MAG', '왜/MAG', '?/SF']
# ['갑자기/MAG', '회의/NNG', '가/JKS', '생겨서/VV+EC', '요/JX', './SF']
# ['갑작스러운/VA+ETM', '한마디/NNG', '가/JKS', '잘/MAG', '나오/VV', '지/EC', '않/VX', '아요/EF', './SF']
# ['강/NNG', '선생/NNG', '님/XSN', '계세요/VV+EF', '?/SF']
# ['강도/NNG', '들/XSN', '이/JKS', '나와/VV+EC', '린다/NNP', '를/JKO', '강탈/NNG', '하/XSV', '려고/EC', '했/VX+EP', '어/EF', './SF', '그래서/MAJ', '힘껏/MAG', '빨리/MAG', '달렸/VV+EP', '지/EF', './SF']
# ['강/NNG', '에/JKB', '어린/VA+ETM', '여자/NNG', '아이/NNG', '가/JKS', '빠졌/VV+EP', '습니다/EF', './SF']
# ['강요/NNG', '하/XSV', '지/EC', '않/VX', '아도/EC', '돼/VV+EF', './SF']
# ['내/NP', '가/JKS', '얼마나/MAG', 'Boyz/SL', 'Ⅱ/SN', 'Men/SL', '을/JKO', '좋아하/VV', '는지/EC', '알/VV', '잖아/EF', './SF']
# ['강의/NNG', '중/NNB', '에/JKB', '는/JX', '별로/MAG', '발언/NNG', '하/XSV', '지/EC', '않/VX', '아요/EF', './SF']
# ['강하/VA', '게/EC', '해/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['강하/VA', '게/EC', '해/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['갖/VV', '고/EC', '싶/VX', '은/ETM', '것/NNB', '이/JKS', '보이/VV', '질/EC+JX', '않/VX', '습니다/EF', './SF']
# ['같/VA', '은/ETM', '실수/NNG', '를/JKO', '반복/NNG', '하/XSV', '는/ETM', '것/NNB', '같/VA', '아요/EF', './SF']
# ['같/VA', '은/ETM', '토양/NNG', '층/NNG', '에서/JKB', '동물/NNG', '의/JKG', '뼈/NNG', '와/JC', '불/NNG', '을/JKO', '사용/NNG', '한/XSV+ETM', '증거/NNG', '를/JKO', '발견/NNG', '했/XSV+EP', '는데/EC', ',/SC', '방사성/NNG', '탄소/NNG', '연대/NNP', '측/NNB', '정법/NNG', '을/JKO', '사용/NNG', '해서/XSV+EC', '그걸/NP+JKO', '분석/NNG', '했/XSV+EP', '어요/EF', './SF']
# ['같이/MAG', '못/MAG', '가/VV', '세요/EP+EF', '?/SF']
# ['같이/MAG', '쇼핑/NNG', '을/JKO', '하/VV', '러/EC', '가/VX', '지/EC', '않/VX', '을래요/EF', './SF']
# ['같이/MAG', '캠프/NNG', '에/JKB', '가/VV', '지/EC', '않/VX', '을래요/EF', '?/SF']
# ['같이/MAG', '클래식/NNG', '콘서트/NNG', '에/JKB', '가/VV', '지/EC', '않/VX', '을래요/EF', '?/SF']
# ['같이/MAG', '파티/NNG', '에/JKB', '가/VV', '지/EC', '않/VX', '겠/EP', '어요/EF', '?/SF']
# ['개관/NNG', '은/JX', '몇/MM', '시/NNBC', '입니까/VCP+EF', '?/SF']
# ['개인/NNG', '적/XSN', '인/VCP+ETM', '만남/NNG', '은/JX', '그만두/VV', '자/EF', './SF']
# ['개찰구/NNG', '는/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['개찰구/NNG', '를/JKO', '나간/VV+ETM', '데/NNB', '서/JKB', '만나/VV', '요/EF', './SF']
# ['개찰구/NNG', '에서/JKB', '만나/VV', '요/EF', './SF']
# ['거기/NP', '123/SN', '-/SY', '456/SN', '번/NNBC', '맞/VV', '습니까/EF', '?/SF']
# ['거기/NP', '날씨/NNG', '는/JX', '맑/VA', '아요/EF', '?/SF']
# ['거기/NP', '어떻/VA', '게/EC', '가/VX', '는지/EC', '알/VV', '아요/EF', '?/SF', '난/NP+JX', '잘/MAG', '모르/VV', '겠/EP', '어요/EF', './SF']
# ['거기/NP', '있/VA', '는/ETM', '동안/NNG', '차/NNG', '를/JKO', '렌트/NNG', '해야/XSV+EC', '할/VX+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['거기/NP', '가/JKS', '우리/NP', '보다/JKB', '8/SN', '시간/NNBC', '빨라요/VA+EF', './SF']
# ['거기/NP', '까지/JX', '가/VV', '는/ETM', '데/NNB', '얼마나/MAG', '걸려요/VV+EF', '?/SF']
# ['거기/NP', '는/JX', '25/SN', '-/SY', '4488/SN', '이/VCP', '에요/EF', '?/SF']
# ['거기/NP', '는/JX', '비/NNG', '가/JKS', '오/VV', '고/EC', '있/VX', '나요/EF', '?/SF']
# ['거기/NP', '를/JKO', '오른쪽/NNG', '으로/JKB', '돌/VV', '아/EF', './SF']
# ['거기/NP', '에/JKB', '소풍/NNG', '갈/VV+ETM', '때/NNG', '필요/NNG', '한/XSA+ETM', '물품/NNG', '도/JX', '있/VA', '을까요/EF', '?/SF']
# ['거리/NNG', '를/JKO', '걸어가/VV', '면서/EC', '담배/NNG', '를/JKO', '피우/VV', '는/ETM', '사람/NNG', '을/JKO', '보/VV', '면/EC', '정말/MAG', '못/MAG', '참/VV', '겠/EP', '어/EF', './SF']
# ['거스름돈/NNG', '여기/NP', '있/VA', '습니다/EF', './SF', '감사/NNG', '합니다/XSV+EF', './SF']
# ['거스름돈/NNG', '을/JKO', '잘못/MAG', '주/VV', '신/EP+ETM', '것/NNB', '같/VA', '은데요/EF', './SF']
# ['거의/MAG', '20/SN', '년/NNBC', '쯤/XSN', './SF', '우린/NP+JX', '죽마고우/NNG', '야/VCP+EF', './SF']
# ['거의/MAG', '나가/VV', '지/EC', '않/VX', '고/EC', '집/NNG', '에서/JKB', '빈둥빈둥/MAG', '놀/VV', '고/EC', '있/VX', '어요/EF', './SF']
# ['거의/MAG', '다/MAG', '됐/VV+EP', '어요/EF', './SF', '15/SN', '분/NNBC', '전/NNG', '이/VCP', '에요/EF', './SF']
# ['거의/MAG', '잔업/NNG', '을/JKO', '해요/VV+EF', './SF']
# ['거절/NNG', '하/XSV', '겠/EP', '어/EF', './SF']
# ['거짓말/NNG', '!/SF']
# ['거짓말/NNG', '은/JX', '하/VV', '지/EC', '않/VX', '아요/EF', './SF']
# ['거짓말/NNG', '을/JKO', '해서/VV+EC', '죄송/XR', '해요/XSA+EF', './SF']
# ['거짓/NNG', '스러웠/XSA+EP', '어요/EF', './SF']
# ['걱정/NNG', '말/VV', '아요/EF', './SF', '내/NP', '가/JKS', '비디오/NNG', '녹화/NNG', '해/XSV+EC', '놨으니까/VX+EP+EC', './SF']
# ['걱정/NNG', '을/JKO', '끼쳐/VV+EC', '드려서/VX+EC', '죄송/XR', '해요/XSA+EF', './SF']
# ['걱정/NNG', '을/JKO', '끼치/VV', '고/EC', '싶/VX', '지/EC', '않/VX', '아서/EC', '가만히/MAG', '있/VV', '었/EP', '어요/EF', './SF']
# ['걱정/NNG', '하/XSV', '지/EC', '말/VX', '아요/EF', './SF']
# ['걱정/NNG', '하/XSV', '지/EC', '말/VX', '아요/EF', './SF']
# ['걱정/NNG', '하/XSV', '지/EC', '말/VX', '아요/EF', './SF']
# ['건강/NNG', '쪽/NNB', '은/JX', '문제/NNG', '가/JKS', '하나/NR', '도/JX', '없/VA', '어요/EF', './SF']
# ['건강/NNG', '쪽/NNB', '은/JX', '문제/NNG', '가/JKS', '하나/NR', '도/JX', '없/VA', '어요/EF', './SF']
# ['건강/NNG', '에/JKB', '좋/VA', '아요/EF', './SF']
# ['건강/NNG', '에/JKB', '도/JX', '좋/VA', '답니다/EF', './SF', '난/NP+JX', '피라미드/NNG', '의/JKG', '하단/NNG', '부/NNG', '를/JKO', '먹/VV', '고/EC', '있/VX', '어요/EF', './SF']
# ['건강/NNG', '을/JKO', '위해서/VV+EC', '금연/NNG', '하/XSV', '려고/EC', '합니다/VX+EF', './SF']
# ['건강/NNG', '이/VCP', '길/ETN+JKO', '빌/VV', '어요/EF', './SF']
# ['건강/NNG', '하/XSA', '게/EC', '오래/MAG', '살/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['건강/NNG', '한/XSA+ETM', '것/NNB', '을/JKO', '감사/NNG', '하/XSV', '게/EC', '여기/VV', '고/EC', '있/VX', '습니다/EF', './SF']
# ['건강/NNG', '한/XSA+ETM', '아기/NNG', '를/JKO', '출산/NNG', '하/XSV', '세요/EP+EF', '!/SF']
# ['건강/NNG', '해요/XSA+EF', './SF']
# ['건널목/NNG', '을/JKO', '건너/VV', '가요/EF', './SF']
# ['건물/NNG', '앞/NNG', '에/JKB', '있/VV', '는/ETM', '나무/NNG', '를/JKO', '베/VV', '어/EC', '버릴/VX+ETM', '거/NNB', '래요/VCP+EF', './SF']
# ['건배/NNG', '!/SF']
# ['건배/NNG', '합시다/XSV+EF', './SF']
# ['걸어서/VV+EC', '15/SN', '분/NNBC', '걸려요/VV+EF', './SF']
# ['걸어서/VV+EC', '5/SN', '분/NNBC', '이/VCP', '에요/EF', './SF']
# ['검/VA', '은/ETM', '빵/NNG', '으로/JKB', '할게요/VV+EF', './SF']
# ['게/NNG', '는/JX', '비타민/NNG', 'B/SL', '군/NNG', '과/JC', 'E/SL', '를/JKO', '풍부/XR', '하/XSA', '게/EC', '함유/NNG', '하/XSA', '고/EC', '있/VX', '습니다/EF', './SF']
# ['게/NNG', '는/JX', '칼슘/NNG', ',/SC', '마그네슘/NNG', '등/NNB', '의/JKG', '미네랄/NNG', '을/JKO', '듬뿍/MAG', '포함/NNG', '하/XSV', '고/EC', '있/VX', '습니다/EF', './SF']
# ['게/NNG', '는/JX', '타우린/NNG', ',/SC', '키틴/NNG', '이/JKS', '풍부/XR', '하/XSA', '게/EC', '포함/NNG', '하/XSV', '고/EC', '있/VX', '습니다/EF', './SF']
# ['게다가/MAG', '연기/NNG', '도/JX', '아주/MAG', '훌륭/XR', '했/XSA+EP', '어/EC']
# ['게다가/MAG', '연기/NNG', '도/JX', '아주/MAG', '훌륭/XR', '했/XSA+EP', '어요/EF', './SF']
# ['겨우/MAG', '생각났/VV+EP', '습니다/EF', './SF']
# ['겨울/NNG', '옷/NNG', '을/JKO', '갖/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['겨울/NNG', '방학/NNG', '은/JX', '무엇/NP', '을/JKO', '할/VV+ETM', '거/NNB', '예요/VCP+EF', '?/SF']
# ['겨울/NNG', '방학/NNG', '은/JX', '무엇/NP', '을/JKO', '했/VV+EP', '니/EF', '?/SF']
# ['겨울/NNG', '은/JX', '공기/NNG', '가/JKS', '건조/NNG', '해요/XSV+EF', './SF']
# ['겨울/NNG', '은/JX', '피부/NNG', '가/JKS', '건조/NNG', '해요/XSV+EF', './SF']
# ['견본/NNG', '주/VV', '셔서/EP+EC', '감사/NNG', '합니다/XSV+EF', './SF']
# ['결과/NNG', '가/JKS', '증명/NNG', '을/JKO', '하/VV', '는군요/EF', './SF', '심전/NNG', '도/JX', '결과/NNG', '도/JX', '좋/VA', '게/EC', '나왔/VV+EP', '습니다/EF', './SF', '심장/NNG', '박동/NNG', '수/NNG', '는/JX', '70/SN', '이/VCP', '군요/EF', './SF', '아주/MAG', '좋/VA', '습니다/EF', './SF']
# ['결국/NNG', '사이즈/NNG', '가/JKS', '맞/VV', '지/EC', '않/VX', '아서요/EF', './SF']
# ['결단력/NNG', '있/VV', '는/ETM', '사람/NNG', '이/JKS', '되/VV', '세요/EP+EF', './SF']
# ['결론/NNG', '으로/JKB', '넘/VV', '어/EC', '가지/VX', '마/EF', './SF']
# ['결론/NNG', '이/JKS', '뭐/NP', '야/VCP+EF', '?/SF']
# ['결점/NNG', '으로/JKB', '는/JX', ',/SC', '쉽/VA', '게/EC', '뜨거워지/VV', '고/EC', '쉽/VA', '게/EC', '식/VV', '는/ETM', '타입/NNG', '입니다/VCP+EF', './SF']
# ['결정/NNG', '을/JKO', '내리/VV', '기/ETN', '가/JKS', '쉽/VA', '지/EC', '않/VX', '겠/EP', '어요/EF', './SF']
# ['결정/NNG', '하/XSV', '셨/EP+EP', '어요/EF', '?/SF']
# ['결정/NNG', '하/XSV', '시/EP', '면/EC', '불러/VV+EC', '주/VX', '십시오/EP+EF', './SF']
# ['결혼/NNG', '축하/NNG', '드려요/VV+EF', '!/SF']
# ['결혼기념일/NNG', '축하/NNG', '드려요/VV+EF', '!/SF']
# ['결혼/NNG', '생활/NNG', '이/JKS', '잘/MAG', '되/VV', '지/EC', '않/VX', '고/EC', '있/VX', '어요/EF', './SF']
# ['결혼/NNG', '을/JKO', '언제/MAG', '했/VV+EP', '어요/EF', '?/SF']
# ['결혼/NNG', '을/JKO', '중단/NNG', '해요/XSV+EF', './SF']
# ['결혼/NNG', '축하/NNG', '선물/NNG', '감사/NNG', '합니다/XSV+EF', './SF']
# ['결혼/NNG', '하/XSV', '면/EC', '일/NNG', '을/JKO', '그만두/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['결혼/NNG', '할까/XSV+EF', '?/SF']
# ['결혼/NNG', '합시다/XSV+EF', './SF']
# ['결혼/NNG', '해서/XSV+EC', '도/JX', '일/NNG', '은/JX', '계속/NNG', '하/XSV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['결혼/NNG', '해요/XSV+EF', './SF']
# ['경력/NNG', '이/JKS', '많/VA', '은/ETM', '사람/NNG', '들/XSN', '을/JKO', '따라잡/VV', '을/ETM', '수/NNB', '있/VV', '겠/EP', '어요/EF', '?/SF']
# ['경리/NNG', '담당자/NNG', '를/JKO', '부탁/NNG', '드려요/VV+EF', './SF']
# ['경리부/NNG', '샤/NNG', '론/XSN', '이/JKS', '그런/MM', '일/NNG', '을/JKO', '담당/NNG', '해요/XSV+EF', './SF']
# ['경리부/NNG', '조지/NNP', '한테/JKB', '그/MM', '쪽/NNB', '프린터/NNG', '를/JKO', '쓸/VV+ETM', '수/NNB', '있/VV', '는지/EC', '물/VV', '어/EC', '보/VX', '세요/EP+EF', './SF', '거기/NP', '있/VA', '는/ETM', '게/NNB+JKS', '제일/MAG', '속도/NNG', '가/JKS', '빠를/VA+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['경망/NNG', '스러운/XSA+ETM', '짓/NNB', '은/JX', '하/VV', '지/EC', '않/VX', '도/EC', './SF']
# ['경비/NNG', '를/JKO', '아끼/VV', '려고/EC', '만/JX', '하/VV', '지/EC', '말/VX', '아/EF', '!/SF']
# ['경솔/NNG', '한/XSA+ETM', '행동/NNG', '은/JX', '삼가/VV', '도록/EF', './SF']
# ['경제/NNG', '적/XSN', '으로/JKB', '독립/NNG', '하/XSA', '고/EC', '싶/VX', '어요/EF', './SF']
# ['경찰/NNG', '을/JKO', '불러/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['경치/NNG', '가/JKS', '좋/VA', '은/ETM', '길/NNG', '을/JKO', '통해/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['경치/NNG', '는/JX', '어땠/VA+EP', '어요/EF', '?/SF']
# ['경험/NNG', '이/JKS', '없/VA', '어서/EC', '일/NNG', '을/JKO', '못/MAG', '구했/VV+EP', '어요/EF', './SF']
# ['계단/NNG', '을/JKO', '내려가/VV', '십시오/EP+EF', './SF']
# ['계단/NNG', '을/JKO', '내려가/VV', '요/EF', './SF']
# ['계단/NNG', '을/JKO', '사용/NNG', '해요/XSV+EF', './SF']
# ['계단/NNG', '을/JKO', '올라가/VV', '십시오/EP+EF', './SF']
# ['계단/NNG', '을/JKO', '올라가/VV', '요/EF', './SF']
# ['계란/NNG', '후/NNG', '라이/NNG', '는/JX', '부드러운/VA+ETM', '걸로/NNB+JKB', '해/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['계란/NNG', '후/NNG', '라이/NNG', '로/JKB', '할게요/VV+EF', './SF']
# ['계란/NNG', '후/NNG', '라이/NNG', '로/JKB', '할게요/VV+EF', './SF']
# ['계란/NNG', '에/JKB', '는/JX', '치매/NNG', '를/JKO', '예방/NNG', '하/XSV', '는/ETM', '물질/NNG', '이/JKS', '들/VV', '어/EC', '있/VX', '다고/EC', '합니다/VX+EF', './SF']
# ['계란/NNG', '은/JX', '매일/MAG', '식탁/NNG', '에/JKB', '오르/VV', '는/ETM', '식품/NNG', '입니다/VCP+EF', './SF']
# ['계란/NNG', '은/JX', '양질/NNG', '의/JKG', '단백질/NNG', '을/JKO', '듬뿍/MAG', '가지/VV', '고/EC', '있/VX', '습니다/EF', './SF']
# ['계란/NNG', '은/JX', '어떻게/MAG', '해/VV+EC', '드릴까요/VX+EF', '?/SF']
# ['계란/NNG', '을/JKO', '두/MM', '개/NNBC', '깨/VV+EC', '줄래/VX+EF', '?/SF']
# ['계란/NNG', '을/JKO', '한/MM', '바구니/NNBC', '에/JKB', '담/VV', '지/EC', '말/VX', '라는/ETM', '말/NNG', '도/JX', '있/VA', '잖아요/EC+VX+EF', './SF', '다시/MAG', '한/MM', '번/NNBC', '생각/NNG', '해/XSV+EC', '보/VX', '세요/EP+EF', './SF']
# ['계란/NNG', '의/JKG', '단백질/NNG', '은/JX', '소화/NNG', '흡수/NNG', '에/JKB', '뛰어납니다/VA+EF', './SF']
# ['계산대/NNG', '는/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['계산대/NNG', '는/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['계산대/NNG', '는/JX', '어디/NP', '입니까/VCP+EF', '?/SF']
# ['계산대/NNG', '에서/JKB', '해/VV+EC', '주/VX', '십시오/EP+EF', './SF']
# ['계산서/NNG', '가/JKS', '얼마/NNG', '죠/VCP+EF', '?/SF']
# ['계산/NNG', '은/JX', '계좌/NNG', '로/JKB', '올릴까요/VV+EF', '?/SF']
# ['계산/NNG', '은/JX', '못/MAG', '해요/VV+EF', './SF']
# ['워싱턴/NNP', '애/NNG', '비뉴/NNG', '에서/JKB', '좌회전/NNG', '하/XSV', '면/EC', '오른쪽/NNG', '으로/JKB', '세/MM', '번/NNBC', '째/XSN', '집/NNG', '이/VCP', '에요/EF', ',/SC', '822/SN', '호/NNBC', '요/JX', './SF']
# ['계속/MAG', '보/VV', '려고/EC', '했/VX+EP', '던/ETM', '비디오/NNG', '를/JKO', '볼/VV+ETM', '생각/NNG', '입니다/VCP+EF', './SF']
# ['계속/MAG', '연락/NNG', '하/XSV', '자/EF', './SF']
# ['계속/NNG', '적/XSN', '으로/JKB', '아파요/VA+EF', './SF']
# ['계속/NNG', '해서/XSV+EC', '30/SN', '도/NNBC', '넘/VV', '고/EC', '있/VX', '어/EF', './SF']
# ['계약서/NNG', '에/JKB', '서명/NNG', '했/VV+EP', '어요/EF', '?/SF']
# ['계약/NNG', '하/XSV', '겠/EP', '습니다/EF', './SF']
# ['계절/NNG', '음식/NNG', '은/JX', '맛있/VA', '어요/EF', './SF']
# ['계절/NNG', '이/JKS', '바뀔/VV+ETM', '때/NNG', '컨디션/NNG', '을/JKO', '망치/VV', '기/ETN', '쉬/VV', '어요/EF', './SF']
# ['계좌/NNG', '를/JKO', '확인/NNG', '해/XSV+EC', '드릴게요/VX+EF', './SF']
# ['당신/NP', '의/JKG', '수표/NNG', '가/JKS', '저희/NP', '은행/NNG', '으로/JKB', '왔/VV+EP', '을/ETM', '때/NNG', '손님/NNG', '의/JKG', '통장/NNG', '잔액/NNG', '은/JX', '345/SN', '달러/NNBC', '였/VCP+EP', '습니다/EF', './SF']
# ['이/MM', '수표/NNG', '는/JX', '490/SN', '달러/NNBC', '짜리/XSN', '잖/VCP+UNA', '아요/EF', './SF']
# ['고객/NNG', '임대/NNG', '번호/NNG', '가/JKS', 'Y/SL', '-/SY', '97623/SN', '입니다/VCP+EF', './SF']
# ['고객/NNG', '들/XSN', '이/JKS', '그런/MM', '태도/NNG', '에/JKB', '질리/VV', '지/EC', '않/VX', '았/EP', '을까요/EF', '?/SF']
# ['고객/NNG', '서비스/NNG', '센터/NNG', '를/JKO', '부탁/NNG', '드려요/VV+EF', './SF']
# ['고객/NNG', '이/JKS', '당신/NP', '을/JKO', '화나/VV', '게/EC', '해도/VV+EC', '요/JX', '?/SF']
# ['고객/NNG', '이/VCP', '죠/EF', './SF', '물론/MAG', './SF']
# ['고구마/NNP', '는/JX', '비타민/NNG', 'C/SL', '를/JKO', '풍부/XR', '하/XSA', '게/EC', '함유/NNG', '하/XSA', '고/EC', '있/VX', '습니다/EF', './SF']
# ['고구마/NNP', '는/JX', '최고/NNG', '의/JKG', '미용/NNG', '식품/NNG', '이/VCP', '라고/EC', '해도/VV+EC', '좋/VA', '습니다/EF', './SF']
# ['고구마/NNG', '에/JKB', '는/JX', '비타민/NNG', 'E/SL', ',/SC', '베타/NNG', '카로틴/NNG', '도/JX', '함유/NNG', '되/XSV', '어/EC', '있/VX', '습니다/EF', './SF']
# ['고구마/NNG', '에/JKB', '는/JX', '식이/NNG', '섬유/NNG', '가/JKS', '풍부/XR', '하/XSA', '게/EC', '포함/NNG', '되/XSV', '어/EC', '있/VX', '습니다/EF', './SF']
# ['고귀/XR', '한/XSA+ETM', '선물/NNG', '을/JKO', '고마워요/VA+EC', './SF']
# ['고급/NNG', '차/NNG', '에/JKB', '굉장히/MAG', '흥미/NNG', '가/JKS', '있/VA', '습니다/EF', './SF']
# ['고기/NNG', '종류/NNG', '는/JX', '무엇/NP', '입니까/VCP+EF', '?/SF']
# ['고기/NNG', '가/JKS', '딱딱/XR', '해요/XSA+EF', './SF']
# ['고기/NNG', '가/JKS', '부드러워/VA+EC', '요/JX', './SF']
# ['고기/NNG', '감자조림/NNG', '을/JKO', '만들/VV+ETM', '거/NNB', '야/VCP+EF', './SF']
# ['고기/NNG', '는/JX', '우리/NP', '들/XSN', '의/JKG', '중요/NNG', '한/XSA+ETM', '단백/NNG', '질원/NNG', '입니다/VCP+EF', './SF']
# ['고기/NNG', '요리/NNG', '는/JX', '좋/VA', '아/EC', '하/VX', '세요/EP+EF', '?/SF']
# ['고기/NNG', '의/JKG', '육질/NNG', '이/JKS', '좋/VA', '아요/EF', './SF']
# ['고등학교/NNG', '시절/NNG', '의/JKG', '친구/NNG', '랑/JKB', '만날/VV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['고등학교/NNG', '시절/NNG', '의/JKG', '친구/NNG', '랑/JKB', '만났/VV+EP', '어요/EF', './SF']
# ['고등학교/NNG', '입학/NNG', '축하/NNG', '드려요/VV+EF', '!/SF']
# ['고등학교/NNG', '를/JKO', '졸업/NNG', '하/XSV', '면/EC', '대학/NNG', '에/JKB', '진학/NNG', '할/XSV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['고등학교/NNG', '를/JKO', '졸업/NNG', '하/XSV', '면/EC', '전문학교/NNG', '에/JKB', '다닐/VV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['고등학교/NNG', '를/JKO', '졸업/NNG', '하/XSV', '면/EC', '취직/NNG', '할/XSV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['고등학교/NNG', '에/JKB', '떨어졌/VV+EP', '어요/EF', './SF']
# ['고름/NNG', '이/JKS', '나옵니다/VV+EF', './SF']
# ['고리/NNG', '요리/NNG', '를/JKO', '먹/VV', '고/EC', '싶/VX', '어/EF', './SF']
# ['고마워/VA+EF', ',/SC', '존/NNP', '!/SF']
# ['고마워/VA+EF', ',/SC', '톰/NNG', './SF']
# ['고마워/VA+EF', './SF']
# ['고마워/VA+EF', './SF', '보다/MAG', '완벽/NNG', '하/XSA', '고/EC', '체계/NNG', '적/XSN', '으로/JKB', '만들/VV', '려고/EC', '노력/NNG', '했/XSV+EP', '거든요/EF', './SF', '내/NP+JKG', '생각/NNG', '에/JKB', '는/JX', '이번/NNG', '게/NNG', '사용/NNG', '하/XSV', '기/ETN', '가/JKS', '훨씬/MAG', '더/MAG', '편리/NNG', '한/XSA+ETM', '것/NNB', '같/VA', '아요/EF', './SF']
# ['고마워요/VA+EC', ',/SC', '소모품/NNG', '캐비닛/NNG', '부터/JX', '확인/NNG', '해/XSV+EC', '볼게요/VX+EF', './SF']
# ['고마워요/VA+EC', ',/SC', '수잔/NNP', './SF', '정말/MAG', '고마워요/VA+EC', './SF']
# ['고마워요/VA+EC', ',/SC', '앨런/NNG', './SF', '몇/MM', '시/NNBC', '까지/JX', '하/VV', '죠/EF', '?/SF']
# ['고마워요/VA+EC', ',/SC', '하지만/MAJ', '전/MM', '온라인/NNG', '으로/JKB', '물건/NNG', '사/VV', '는/ETM', '거/NNB', '안/MAG', '좋/VA', '아/EC', '해요/VX+EF', './SF', '상점/NNG', '에/JKB', '직접/MAG', '가/VV', '서/EC', '물건/NNG', '사기/NNG', '전/NNG', '에/JKB', '한/MM', '번/NNBC', '입/VV', '어/EC', '보/VX', '는/ETM', '게/NNB+JKS', '좋/VA', '거든요/EF', './SF']
# ['고마워요/VA+EC', './SF']
# ['고마워요/VA+EC', './SF']
# ['고마워요/VA+EC', './SF', '그/MM', '소식/NNG', '들으면/VV+EC', '기뻐하/VV', '겠/EP', '네요/EF', './SF']
# ['고마워요/VA+EC', './SY', '금요일/NNG', '까지/JX', '필요/NNG', '할/XSV+ETM', '것/NNB', '같/VA', '아요/EF', './SF']
# ['고마워요/VA+EC', './SF', '당신/NP', '도/JX', '요/JX', './SF']
# ['고마워요/VA+EC', './SY', '도표/NNG', '한/MM', '개/NNBC', '만/JX', '확인/NNG', '해/XSV+EC', '보/VX', '면/EC', '되/VV', '요/EF', './SF']
# ['고마워요/VA+EC', './SF', '우리/NP', '둘/NR', '다/MAG', '잘/MAG', '되/VV', '어/EF', '야/IC', '겠/EP', '죠/EF', '!/SF']
# ['고마워요/VA+EC', './SF', '이거/NP', '무슨/MM', '문제/NNG', '가/JKS', '있/VA', '는/ETM', '게/NNB+JKS', '분명/MAG', '해요/XSA+EF', './SF', '수리공/NNG', '을/JKO', '불러서/VV+EC', '한/MM', '번/NNBC', '살펴보/VV', '라고/EC', '해야/VX+EC+VX', '겠/EP', '어요/EF', './SF']
# ['고마워요/VA+EC', './SF', '좋/VA', '군요/EF', './SF', '아주/MAG', '새/MM', '거/NNB', '예요/VCP+EF', './SF']
# ['고마워요/VA+EC', './SY', '출장/NNG', '여행/NNG', '중/NNB', '이/VCP', '세요/EP+EF', '?/SF']
# ['고마워요/VA+EC', './SY', '회사/NNG', '측/NNB', '에서/JKB', '도/JX', '우리/NP', '가/JKS', '이런/MM', '방식/NNG', '으로/JKB', '작업/NNG', '을/JKO', '진행/NNG', '해야/XSV+EC', '할/VX+ETM', '거/NNB', '라는/VCP+ETM', '데/NNB', '동의/NNG', '해/XSV+EC', '주/VX', '면/EC', '좋/VA', '겠/EP', '어요/EF', './SF']
# ['대단히/MAG', '고맙/VA', '습니다/EF', './SF']
# ['대단히/MAG', '감사/NNG', '합니다/XSV+EF', './SF']
# ['고맙/VA', '습니다/EF', './SF']
# ['고맙/VA', '습니다/EF', './SF', '이번/NNG', '주/NNG', '월요일/NNG', '에/JKB', '사용/NNG', '하/XSV', '실/EP+ETM', '건가요/NNB+VCP+EF', '?/SF']
# ['고맙/VA', '습니다/EF', './SF', '정말/MAG', '고맙/VA', '습니다/EF', './SF', '수고/NNG', '하/XSV', '세요/EP+EF', './SF']
# ['고맙/VA', '지만/EC', ',/SC', '다른/MM', '분/NNB', '이/JKS', '도와/VV+EC', '주/VX', '고/EC', '있/VX', '어요/EF', './SF']
# ['고민/NNG', '거린/XSV+ETM', '금방/MAG', '해결/NNG', '될/XSV+ETM', '거/NNB', '야/VCP+EF', './SF']
# ['고민/NNG', '을/JKO', '들/VV', '어/EC', '줘서/VX+EC', '고마워요/VA+EC', './SF']
# ['고민/NNG', '을/JKO', '상담/NNG', '할/XSV+ETM', '수/NNB', '있/VV', '는/ETM', '사람/NNG', '이/JKS', '없/VA', '어요/EF', './SF']
# ['고상/XR', '한/XSA+ETM', '취미/NNG', '를/JKO', '가지/VV', '고/EC', '계시/VX', '네요/EF', './SF']
# ['고생/NNG', '하/XSA', '고/EC', '있/VX', '어요/EF', './SF']
# ['고추/NNG', '같/VA', '은/ETM', '자극/NNG', '성/XSN', '강한/VA+ETM', '것/NNB', '은/JX', '먹/VV', '지/EC', '않/VX', '도록/EF', './SF']
# ['고치/VV', '는/ETM', '비용/NNG', '은/JX', '얼마/NNG', '입니까/VCP+EF', '?/SF']
# ['고/MM', '혈압/NNG', '이/VCP', '에요/EF', './SF']
# ['곧/MAG', '그곳/NP', '으로/JKB', '응급/NNG', '구조/NNG', '원/NNG', '들/XSN', '을/JKO', '출동/NNG', '시키/XSV', '겠/EP', '습니다/EF', './SF']
# ['곧/MAG', '그렇게/MAG', '할/VV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['곧/MAG', '그렇게/MAG', '할/VV+ETM', '것/NNB', '같/VA', '아요/EF', './SF']
# ['곧/MAG', '도착/NNG', '할/XSV+ETM', '것/NNB', '입니다/VCP+EF', './SF']
# ['곧/MAG', '또/MAG', '짐/NNG', '을/JKO', '꾸려야/VV+EC', '하/VV', '는/ETM', '것/NNB', '아닌가/VCN+EC', '모르/VV', '겠/EP', '어요/EF', './SF']
# ['골프/NNG', '를/JKO', '꽤/MAG', '잘/MAG', '해요/VV+EF', './SF']
# ['골프/NNG', '에/JKB', '푹/MAG', '빠졌/VV+EP', '어요/EF', './SF']
# ['공/NNG', '도/JX', '세/VA', '답니다/EF', './SF']
# ['공부/NNG', '는/JX', '잘/MAG', '돼/VV+EC', '가/VX', '고/EC', '있/VX', '어요/EF', '?/SF']
# ['공부/NNG', '하/XSV', '고/EC', '있/VX', '었/EP', '어요/EF', './SF']
# ['공사/NNG', '중/NNB', '인/VCP+ETM', '간선/NNG', '도로/NNG', '를/JKO', '운전/NNG', '해/XSV+EC', '가/VX', '는데/EC', '조그마/XR', '한/XSA+ETM', '돌/NNG', '이/JKS', '날아와/VV+EC', '유리/NNG', '가/JKS', '깨졌/VV+EP', '어요/EF', './SF']
# ['공연/NNG', '안/MAG', '내처/NNG', '는/JX', '어디/NP', '입니까/VCP+EF', '?/SF']
# ['공연/NNG', '은/JX', '어땠/VA+EP', '어요/EF', '?/SF']
# ['공원/NNG', '에/JKB', '벗/NNG', '꽃/NNG', '구경/NNG', '을/JKO', '보/VV', '러/EC', '갈/VX+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['공중/NNG', '전화/NNG', '는/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['공중/NNG', '전화/NNG', '를/JKO', '찾/VV', '고/EC', '있/VX', '습니다만/EF', './SF']
# ['공통/NNG', '적/XSN', '인/VCP+ETM', '입장/NNG', '을/JKO', '찾아보/VV', '면서/EC', '시작/NNG', '해야/XSV+EC', '할/VX+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['공포/NNG', '영화/NNG', '였/VCP+EP', '어요/EF', './SF']
# ['공포/NNG', '는/JX', '싫/VA', '어/EC', '해요/VX+EF', './SF']
# ['공학/NNG', '학위/NNG', '정도/NNG', '는/JX', '있/VX', '어야지/EC', '설치/NNG', '할/XSV+ETM', '수/NNB', '있/VV', '을/ETM', '것/NNB', '같/VA', '네요/EF', './SF']
# ['공항/NNG', '근처/NNG', '에/JKB', '가격/NNG', '이/JKS', '적당/XR', '한/XSA+ETM', '호텔/NNG', '을/JKO', '알려/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['공항/NNG', '근처/NNG', '의/JKG', '호텔/NNG', '까지/JX', '가/VV+EC', '주/VX', '세요/EP+EF', '?/SF']
# ['공항/NNG', '까지/JX', '가장/MAG', '간단/XR', '하/XSA', '게/EC', '갈/VX+ETM', '수/NNB', '있/VV', '는/ETM', '방법/NNG', '을/JKO', '가르쳐/VV+EC', '줄/VX+ETM', '수/NNB', '있/VV', '어요/EF', '?/SF']
# ['공항/NNG', '에/JKB', '도착/NNG', '해서/XSV+EC', '해도/VV+EC', '되/VV', '나요/EF', '?/SF']
# ['공항/NNG', '에서/JKB', '호텔/NNG', '에/JKB', '어떻/VA', '게/EC', '가/VX', '죠/EF', '?/SF']
# ['과식/NNG', '하/XSV', '지/EC', '않/VX', '게/EC', '조심/NNG', '해요/XSV+EF', './SF']
# ['과식/NNG', '하/XSV', '지/EC', '않/VX', '도록/EC', '하/VV', '고/EC', '있/VX', '어요/EF', './SF']
# ['과음/NNG', '하/XSV', '지/EC', '않/VX', '게/EC', '조심/NNG', '해요/XSV+EF', './SF']
# ['과일/NNG', '좋/VA', '아/EC', '하/VX', '십니까/EP+EF', '?/SF']
# ['과일/NNG', '과/JC', '야채/NNG', ',/SC', '그리고/MAJ', '완전/MAG', '곡물식/NNG', '을/JKO', '먹/VV', '어요/EF', './SF', '붉/VA', '은/ETM', '색/NNG', '육류/NNG', '는/JX', '많이/MAG', '먹/VV', '지/EC', '않/VX', '아요/EF', './SF']
# ['과일/NNG', '은/JX', '매일/MAG', '먹/VV', '고/EC', '있/VX', '습니다/EF', './SF']
# ['과일/NNG', '주스/NNG', '를/JKO', '주/VV', '세요/EP+EF', '?/SF']
# ['관광/NNG', '안내소/NNG', '까지/JX', '갈/VV+ETM', '방법/NNG', '을/JKO', '가르쳐/VV+EC', '줄/VX+ETM', '수/NNB', '있/VV', '어요/EF', '?/SF']
# ['관광/NNG', '안내소/NNG', '를/JKO', '찾/VV', '고/EC', '있/VX', '는데요/EF', './SF']
# ['관광/NNG', '안내소/NNG', '에/JKB', '가/VV', '는/ETM', '길/NNG', '을/JKO', '가르쳐/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['관광지/NNG', '가/JKS', '실려/VV+EC', '있/VX', '는/ETM', '지도/NNG', '를/JKO', '갖/VV', '고/EC', '싶/VX', '은데요/EF', './SF']
# ['관련/NNG', '기술/NNG', '문제/NNG', '들/XSN', '을/JKO', '우리/NP', '가/JKS', '너무/MAG', '과소/NNG', '평가/NNG', '했/XSV+EP', '나/EC', '봐요/VX+EF', './SF']
# ['관절/NNG', '이/JKS', '쑤/VV', '셔요/EP+EF', './SF']
# ['관절/NNG', '이/JKS', '탈구/NNG', '됐/XSV+EP', '어요/EF', './SF']
# ['광고/NNG', '담당자/NNG', '를/JKO', '부탁/NNG', '드려요/VV+EF', './SF']
# ['광고부/NNG', '를/JKO', '부탁/NNG', '드려요/VV+EF', './SF']
# ['광고/NNG', '회사/NNG', '에/JKB', '근무/NNG', '하/XSV', '고/EC', '있/VX', '어요/EF', './SF']
# ['광우병/NNG', '따위/NNB', '전혀/MAG', '무섭/VA', '지/EC', '않/VX', '아/EF', './SF']
# ['괜찮/VA', '습니다/EF', './SF', '레오나드/NNP', '씨/NNB', './SY', '손/NNG', '님/XSN', '이/JKS', '사용/NNG', '하/XSV', '실/EP+ETM', '방/NNG', '값/NNG', '은/JX', '신용/NNG', '카드/NNG', '로/JKB', '지불/NNG', '되/XSV', '었/EP', '습니다/EF', './SF']
# ['괜찮/VA', '습니다/EF', './SF', '몇/MM', '호실/NNG', '이/VCP', '십니까/EP+EF', '?/SF']
# ['아뇨/IC', ',/SC', '괜찮/VA', '습니다/EF', './SF']
# ['괜찮/VA', '아/EF', './SF', '그저/MAG', '무사히/MAG', '와서/VV+EC', '다행/NNG', '이/VCP', '야/EF', './SF', '그래/IC', '그/MM', '동안/NNG', '어떻게/MAG', '지냈/VV+EP', '니/EF', '?/SF']
# ['괜찮/VA', '아/EF', '?/SF']
# ['괜찮/VA', '아요/EF', ',/SC', '그/MM', '주문품/NNG', '부터/JX', '지불/NNG', '기한/NNG', '을/JKO', '90/SN', '일/NNBC', '로/JKB', '연장/NNG', '해/XSV+EC', '주/VX', '기/ETN', '로/JKB', '했/VV+EP', '거든요/EF', './SF']
# ['괜찮/VA', '아요/EF', ',/SC', '댄/NNG', './SF', '진정/XR', '해요/XSA+EF', './SF']
# ['호텔/NNG', '가/VV', '서/EC', '체크인/NNG', '하/XSV', '고/EC', '거기/NP', '서/JKB', '나/NP', '한테/JKB', '전화/NNG', '좀/MAG', '줘요/VV+EF', './SF']
# ['당신/NP', '에게/JKB', '사진/NNG', '이나/JC', '뭐/IC', '다른/MM', '걸/NNB+JKO', '이메일/NNG', '로/JKB', '보내/VV+EC', '줄/VX+ETM', '수/NNB', '없/VA', '는지/EC', '한/MM', '번/NNBC', '알/VV', '아/EC', '볼게요/VX+EF', './SF']
# ['괜찮/VA', '아요/EF', './SF']
# ['괜찮/VA', '아요/EF', './SF']
# ['괜찮/VA', '아요/EF', './SF']
# ['괜찮/VA', '아요/EF', './SF', '난/NP+JX', '금요일/NNG', '이/JKS', '더/MAG', '좋/VA', '아요/EF', './SF']
# ['괜찮/VA', '아요/EF', './SF', '저/NP', '도/JX', '몇/MM', '분/NNBC', '전/NNG', '에/JKB', '왔/VV+EP', '는걸요/EF', './SF']
# ['괜찮/VA', '아요/EF', './SF', '질/NNG', '이/JKS', '그리/MAG', '좋/VA', '을/ETM', '필요/NNG', '는/JX', '없/VA', '어요/EF', './SF', '사진/NNG', '전용/NNG', '인화지/NNG', '를/JKO', '사용/NNG', '하/XSV', '면/EC', '차이/NNG', '가/JKS', '많이/MAG', '날까/VV+EC', '요/JX', '?/SF']
# ['괜찮/VA', '아요/EF', './SF', '한/MM', '시간/NNG', '차이/NNG', '인데요/VCP+EF', ',/SC', '뭐/IC', './SF']
# ['괜찮/VA', '아요/EF', '?/SF']
# ['괜찮/VA', '은/ETM', '것/NNB', '같/VA', '아요/EF', './SF', '요즘/MAG', '좀/MAG', '피곤/NNG', '했/XSA+EP', '습니다/EF', './SF']
# ['괜찮/VA', '은/ETM', '의사/NNG', '알/VV', '고/EC', '있/VX', '어/EF', '?/SF']
# ['괜찮/VA', '은/ETM', '이탈리아/NNP', '음식점/NNG', '이/JKS', '있/VA', '습니까/EF', '?/SF']
# ['괜찮/VA', '은데요/EF', './SF', '이/MM', '패키지/NNG', '로/JKB', '예약/NNG', '하/XSV', '겠/EP', '어요/EF', './SF']
# ['괜찮/VA', '을/ETM', '것/NNB', '같/VA', '아/EC', ',/SC', '하지만/MAJ', '사장/NNG', '님/XSN', '이/JKS', '기획/NNG', '회의/NNG', '를/JKO', '소집/NNG', '하/XSV', '실/EP+ETM', '지도/NNG', '몰라/VV+EF', './SF']
# ['괜히/MAG', '열/NNG', '이/JKS', '받/VV', '아서/EC', './SF']
# ['굉장/XR', '한데요/XSA+EF', './SF', '비용/NNG', '이/JKS', '얼마나/MAG', '들/VV', '죠/EF', '?/SF']
# ['굉장히/MAG', '기뻐요/VA+EF', '!/SF']
# ['굉장히/MAG', './SF', '너/NP', '는/JX', '?/SF']
# ['교과서/NNG', '를/JKO', '빌려/VV+EC', '줄래요/VX+EF', '?/SF']
# ['교사/NNG', '자격/NNG', '을/JKO', '취득/NNG', '하/XSV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['교섭/NNG', '자체/NNG', '가/JKS', '적성/NNG', '에/JKB', '안/MAG', '맞/VV', '아요/EF', './SF']
# ['교섭/NNG', '은/JX', '진행/NNG', '되/XSV', '고/EC', '있/VX', '어요/EF', '?/SF']
# ['교차로/NNG', '를/JKO', '건너/VV', '가요/EF', './SF']
# ['교통비/NNG', '가/JKS', '조금/MAG', '더/MAG', '많이/MAG', '나오/VV', '긴/ETN+JX', '하/VX', '겠/EP', '지만/EC', ',/SC', '그래도/MAJ', '장기/NNG', '적/XSN', '으로/JKB', '보/VV', '면/EC', '경비/NNG', '가/JKS', '절감/NNG', '될/XSV+ETM', '거/NNB', '예요/VCP+EF', './SF']
# ['교통사고/NNG', '를/JKO', '겪/VV', '었/EP', '어요/EF', './SF']
# ['교통/NNG', '상태/NNG', '에/JKB', '따라/VV+EC', '결정/NNG', '이/JKS', '되/VV', '요/EF', './SF']
# ['교통/NNG', '체증/NNG', '때문/NNB', '이/JKC', '아닐까요/VCN+EF', './SF']
# ['교환원/NNG', '이/JKS', '전화/NNG', '걸/VV', '고/EC', '있/VX', '습니다/EF', './SF']
# ['교환/NNG', '할/XSV+ETM', '수/NNB', '있/VV', '습니까/EF', '?/SF']
# ['구급차/NNG', '를/JKO', '불러/VV+EC', '주/VX', '세요/EP+EF', './SF']
# ['구두/NNG', '매장/NNG', '은/JX', '어디/NP', '예요/VCP+EF', '?/SF']
# ['구두/NNG', '한/MM', '켤레/NNBC', '를/JKO', '갖/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['구두/NNG', '를/JKO', '갖/VV', '고/EC', '싶/VX', '어요/EF', './SF']
# ['구운/VV+ETM', '감자/NNG', ',/SC', '으깬/VV+ETM', '감자/NNG', ',/SC', '프렌치/NNG', '후/NNG', '라이/NNG', '가/JKS', '있/VA', '지만/EC', './SF']
# ['구운/VV+ETM', '감자/NNG', '로/JKB', '할게요/VV+EF', './SF']
# ['구체/NNG', '적/XSN', '으로/JKB', '무슨/MM', '일/NNG', '을/JKO', '하/VV', '세요/EP+EF', ',/SC', '헤/IC', '걸스/NNP', '톤/NNP', '씨/NNB', '?/SF']
# ['국적/NNG', '은/JX', '어디/NP', '입니까/VCP+EF', '?/SF']
# ['국제/NNG', '전화/NNG', '를/JKO', '걸/VV', '고/EC', '싶/VX', '은데요/EF', './SF']
# ['국제/NNG', '면허증/NNG', '은/JX', '가지/VV', '고/EC', '계십니까/VX+EF', '?/SF']
# ['국제/NNG', '화/XSN', '에/JKB', '대해/VV+EC', '어떻게/MAG', '생각/NNG', '해요/XSA+EF', '?/SF']
# ['굴/NNG', '은/JX', '영양가/NNG', '높/VA', '은/ETM', '식품/NNG', '입니다/VCP+EF', './SF']
# ['굴/NNG', '은/JX', '칼슘/NNG', ',/SC', '마그네슘/NNG', ',/SC', '아연/NNG', '등/NNB', '의/JKG', '미네랄/NNG', '을/JKO', '풍부/XR', '하/XSA', '게/EC', '포함/NNG', '하/XSV', '고/EC', '있/VX', '습니다/EF', './SF']
# ['굴/NNG', '이/JKS', '정력제/NNG', '라고/VCP+EC', '불리/VV', '는/ETM', '것/NNB', '은/JX', '그/MM', '때문/NNB', '입니다/VCP+EF', './SF']
# ['궁금/XR', '하/XSA', '신/EP+ETM', '점/NNG', '이/JKS', '있/VV', '으면/EC', '언제/NP', '라도/VCP+EC', '전화/NNG', '주/VV', '세요/EP+EF', './SF']
# ['궁금/XR', '하/XSA', '신/EP+ETM', '점/NNG', '이/JKS', '있/VV', '으면/EC', ',/SC', '오늘/MAG', '밤/NNG', '8/SN', '시/NNBC', '이후/NNG', '에/JKB', '집/NNG', '에/JKB', '있/VV', '을/ETM', '겁니다/NNB+VCP+EF', './SF']
# ['궁지/NNG', '에/JKB', '몰리/VV', '고/EC', '있/VX', '어요/EF', './SF']
# ['권/NNG', '하/XSV', '는/ETM', '메뉴/NNG', '는/JX', '뭐/NP', '예요/VCP+EF', '?/SF']
# ['귀/NNG', '울림/NNG', '이/JKS', '있/VA', '습니다/EF', './SF']
# ['귀/NNG', '울음/NNG', '이/JKS', '울려요/VV+EF', './SF']
# ['귀/NNG', '위/NNG', '로/JKB', '잘라/VV+EC', '드릴까요/VX+EF', '?/SF']
# ['귀/NNG', '가/JKS', '잘/MAG', '들리/VV', '지/EC', '않/VX', '습니다/EF', './SF']
# ['귀가/NNG', '가/JKS', '늦/VA', '어요/EF', './SF']
# ['귀가/NNG', '는/JX', '8/SN', '시/NNBC', '넘/VV', '을/ETM', '것/NNB', '같/VA', '아요/EF', './SF']
# ['귀가/NNG', '는/JX', '늦/VA', '을/ETM', '것/NNB', '같/VA', '아요/EF', './SF']
# ['귀찮/VA', '게/EC', '좀/MAG', '하/VV', '지/EC', '마/VX+EF', './SF']
# ['귀찮/VA', '게/EC', '좀/MAG', '하/VV', '지/EC', '마/VX+EF', '!/SF']
# ['귀찮/VA', '게/EC', '좀/MAG', '하/VV', '지/EC', '마/VX+EF', './SF']
# ['귀찮/VA', '게/EC', '해서/VV+EC', '죄송/XR', '합니다/XSA+EF', './SF']
# ['규칙/NNG', '적/XSN', '인/VCP+ETM', '생활/NNG', '을/JKO', '하/VV', '게/EC', '되/VV', '고/EC', '나/VX', '서/EC', '컨디션/NNG', '이/JKS', '좋/VA', '아요/EF', './SF']

# %%
import pandas as pd
number = 400
texts = pd.read_table('./data/hgu_clean.kr', sep ='\n')[:number]
texts = texts['26일이요?']

ch = Changer()

for i in range(200, number):
    tt = ch.processText(texts[i])
    print(tt)
# Out:
#
#
# CD가 테이프보다 더 비싸지?
# CD가게로 갈 거야.
# CD가게에서 남부 올스타즈의 앨범을 샀어.
#
# DVD는 화질이 좋아서 좋다?
# DVD를 사는 것은 영원히 소장할 수 있기 때문이다.
# DVD플레이어를 갖고 싶어.
# E-메일을 보내줘서 고마워요.
# EPA 는 나쁜 콜레스테롤을 줄여준다.
# E메일의 주고받기와 인터넷을 할 줄 몰라.
# HP사에서 곧 면접을 봐. 그 회사의 복장 규정은 비즈니스 캐주얼인데, 어떤 옷을 입는 게 좋을까?
# 나는 존이라고 한다.
# IT에 대해 어떻게 생각해?
# Joe's에 잘 오셨다!
# John이야. 나에게 전화하셨다면서.
# KIM전기와 교섭 중이야.
#
#
# LA에 출장 갔어.
# LD01332이다.
# L라면 너무 커.
# MD플레이어를 갖고 싶어.
# MTV에서 재미있는 프로그램을 보고 있어.
# M을 입어볼게.
#
# TV 연속극 애인 본 적 있어?
#
#
#
# TV로 스포츠를 봐.
# TV를 꺼줄래?
# TV를 별로 보지 않아.
# TV를 별로 좋아하지 않아.
# TV를 보고 있어.
# TV를 보지 않을 때는 꺼줘나.
# TV를 볼 거야.
#
# TV를 켜줄래?
# TV시청을 좋아해.
#
#
# T셔츠를 찾고 있어.
# UCLA까지는 어느 정도 걸리나?
# UCLA에서 1개월정도 어학연수를 받을 겁니다.
# VAMC의 쉐논 잭슨이라고 한다.
# V넥 스웨터는 있어?
#
# YBM의 잭 심슨 씨야.
#
# 화성탐험이라는 SF영화이다.
# travelers의 체크카드는 사용 가능하나?
#
# 참치의 뱃살은 일본인이 가장 좋아하는 부분이다.
#
# 가게 안의 느낌이 좋지 않았어.
# 가게 안이 멋졌어.
# 가게에 가서 프랑스산 포도주 좀 사올래?
# 가게에서 접대를 한다.
# 가격 때문이라면 망설이지 마나. 대량 주문 할면 싸게 해드릴 수 있어. 가령 5천개 주문하면 20% 할인해 드릴게.
# 가격에 따라 결정이 되.
# 가격은 세금포함이야?
# 가격은 어땠어?
# 가격을 낮추면 매출을 늘릴 수 있을 거야.
# 가격을 확인 중이야.
# 가격이 아주 저렴하다.
# 가격이 양심적이었어.
#
# 가구점을 여러 곳 돌아다녀 봤는데. 대부분이 똑같은 제품을 팔고 있는데, 이 제품은 여기서 처음 보다.
#
# 가까운 데로 일박여행은 어때?
# 가까운 슈퍼까지 얼마나 걸리나?
# 가까운 시 내로 만나.
# 가까운 시일 내에 다시 와 줘나.
# 가까운 편의점까지 얼마나 걸리나?
# 가끔 골프를 하는 정도이다.
# 가끔 수업에 빠져.
# 가끔 영화를 보러 나가.
# 가끔 온천에 가요.
# 가끔씩은 스테이크를 드셔도 돼. 자, 이걸 한 번 맛보나.
# 가끔은 휴일도 출근을 해.
# 가능하면 매일 영어를 공부하도록 유의하고 있어.
# 가능하면 몇 주 안야. 접수계원이 검사 날짜를 잡아드릴 수 있을 겁니다.
# 가능한 한 가까운 길로 가 줘나.
# 가능한 한 빨리 주문해 주셨으면 한다.
# 가드레일을 들이받았다.
# 가랑비가 내려.
# 가래가 나와서 곤란하다.
# 가래가 생겨.
# 가래는 무슨 색이야?
# 가려워.
# 가르치는 것이 특기야.
#
#
#
# 가방 매장은 어디야?
# 가방 안에 면도기가 들어있는데 괜찮어?
#
# 가방은 이리 줘나.
# 가방은 자기 방에 가지고 가나.
# 가방을 찾고 있어.
# 가벼운 운동을 좋아해.
# 가볼 만한 곳을 알려 줄어?
# 가사를 해.
# 가스는 언제부터 넣어 주나?
# 전자 레인지도 새 것으로 썼으면 한다.
# 최고급 가전제품을 갖고 싶다.
# 허리부분을 줄여 줘나.
# 가요프로그램을 많이 좋아해.
# 가을 옷을 갖고 싶어.
# 가을은 내가 좋아하는 계절이야.
# 가을은 단풍이 아름다워.
# 가장 가까운 관광 안내소가 어디이야?
# 가장 가까운 전철역은 어디야?
# 가장 가까운 지하철역은 어디야?
# 가장 싼 것은 어느 것이야?
# 가장 싼 항공사를 가르쳐 줘나.
# 가장 하고 싶은 것은 뭐야?
# 가정 용품은 어디에 있어?
# 가져갈ㄹ 겁니까, 아니면 안에서 들ㄹ 겁니까?
# 가져오지 않았는데.
# 가족 모두가 기뻐하고 있어.
# 가족끼리만의 오붓한 시간을 보내고 싶어.
# 가족들에게 안부 전해줘나.
# 가족은 평안하니?
# 가족을 돌봐줘서 감사하자.
# 가족이랑 느긋하게 있어.
# 가족이랑 리노에 일박여행을 갔어.
# 가족이랑 워싱턴 디씨에 일박여행을 할 거야.
# 가족이랑 하이킹에 갔어.
# 가죽 부츠를 갖고 싶어.
# 가지각색인 사람들이 있으니깐.
# 가지러 올ㄹ 겁니까? 아니면 배달할ㄹ 겁니까?
# 각 페이지를 2장씩 복사해 줄래?
# 각각 계산해 줘나.
#
# 간단하게 먹고 싶은데.
# 간단한 식사는 뭐야?
# 간단한 아침을 먹어.
# 간단한 아침을 먹어.
#
#
# 간단해. 브로드웨이로 해서 89번 가까지 가요. 서쪽으로 계속 가면 포레스트 애비뉴가 나오는데, 사무실은 89번 가와 포레스트가 만나는 모퉁이에 있어.
# 간단히 말하면, A형과B형의 특징을 함께 가진 사람이다.
# 간단히 말해서, 당신의 영업 철학은 뭐야?
# 간식은 피하는 것이 좋아.
# 노인 건강 보험에 대해 어떻게 생각해?
# 갈림길을 우측으로 가요.
# 감격스럽다!
# 감격스럽다!
# 감기는 거의 안 걸려.
# 감기에 걸렸어.
# 감기에 걸렸어.
#
# 감동을 했어.
# 감동했어. 마음 깊이 느꼈어. 인상적이었어.
# 감동했어.
# 감명을 받았어.
#
# 감사한 마음을 전하고 싶어서 작은 선물을 준비했어.
# 감사하다, 스타인 씨. 필요한 것은 이게 전부이다.
# 대단히 감사하다.
# 대단히 감사하다.
# 감사하다.
# 감사하다. 고객께서는 이 항공편으로 200마일리지를 받을게 되고, 앞으로 여행할 수 있는 100달러 쿠폰을 받을게 된다.
# 감사하다. 그 새 항공편은 노스이스트 8988편으로 8시 15분에 JFK 공항을 출발하다. 나희 단골 고객 클럽의 회원이나?
# 감사하다. 또 방문해줘라.
# 감사하다. 실례했다.
# 감사하다. 아르고 씨 대신 사과 드리다. 일주일 내내 회의에 참석 할느라고 바쁘나.
# 감사하다. 오늘 실험실에서 선생님의 신체 검사 결과가 나왔다.
#
# 감사하자.
# 감사하자.
# 감사하자.
# 감자 튀김을 곁들일어?
# 감자는 비타민C가 풍부하다.
# 감자는 어떻게 해드릴까?
#
# 감자수프가 있어?
# 감자에는 칼슘도 풍부하게 포함되어 있다.
# 감자튀김으로 줘나.
# 감정표현이 서툴러.
#
# 갑자기 회의가 생겨서.
# 갑작스러운 한마디가 잘 나오지 않아.
# 강 선생님 있어?
#
# 강에 어린 여자 아이가 빠졌다.
#
#
# 강의 중에는 별로 발언하지 않아.
# 강하게 해 줘나.
# 강하게 해 줘나.
# 갖고 싶은 것이 보이질 않다.
# 같은 실수를 반복하는 것 같아.
# 같은 토양 층에서 동물의 뼈와 불을 사용한 증거를 발견했는데, 방사성 탄소 연대 측정법을 사용해서 그걸 분석했어.
# 같이 못 가나?
# 같이 쇼핑을 하러 가지 않을래.
# 같이 캠프에 가지 않을래?

# %%
####Convert to Aihub_low.kr

# %%
number = 1935515
texts = pd.read_table('./data/hgu_clean.kr', sep ='\n')[:number]
texts = texts['26일이요?']
# el_list = []
# for sentence in tqdm(texts):
#    try:
#        el_list.append(mec.pos(sentence))
#    except:
#        pass
# ch = Changer()
# f = open('./Aihub_low.kr', 'w')
# for i in range(0, number):
#     tt = ch.processText(texts[i])
#     f.write(tt)
#     f.write('\n')
# f.close()

# %%
# fr = open('./data/hgu_clean.kr', mode ='r', encoding ='utf-8')
# line = fr.readline()
# print(texts[0])
# #line = re.sub("\n","",line)
# line = fr.readline()
# print(line)

# for i in range(0, number):
#     file = open("./Aihub_low.kr", "a")
#     tt = ch.processText(texts[i])
#     file.write(tt)
#     file.write('\n')
#     file.close()

# %%
fr = open('./data/hgu_clean_all.kr', mode ='r', encoding ='utf-8')
while True:
    file = open("./Aihub_low.kr", "a")
    line = fr.readline()
    #맨 끝에 마침표가 없으면 마침표를찍기
    if line[-2] == ' ':
        line = line + '.'
    line = re.sub("\n","",line)
    converted_sent = ch.processText(line)
    file.write(converted_sent)
    file.write('\n')
    file.close()
    if not line: break
fr.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-5dcc5be00eb7> in <module>
#       7         line = line + '.'
#       8     line = re.sub("\n","",line)
# ----> 9     converted_sent = ch.processText(line)
#      10     file.write(converted_sent)
#      11     file.write('\n')
#
# <ipython-input-49-bfd571ccb1d7> in processText(self, stc)
#     444     def processText(self,stc):
#     445         result = stc
# --> 446         res = self.high_low(result)
#     447         #spacing = Spacing()
#     448         #res = spacing(res)
#
# <ipython-input-49-bfd571ccb1d7> in high_low(self, stc)
#     357         key = -1
#     358         for i in H_LIST:
# --> 359             if i in lis_word[-2]:
#     360                 key = 1
#     361         lis = []
#
# IndexError: list index out of range

# %%
fr = open('./data/hgu_clean_all.kr', mode ='r', encoding ='utf-8')
line = fr.readline()
print(line[-2])
if line[-2] == ' ':
    print("yees!")
fr.close()
# Out:
# ?

# %%
fr = open('./data/hgu_clean_all.kr', mode ='r', encoding ='utf-8')
count =0
while True:
    line == fr.readline()
    if line == '제가 참고하고 싶은 책이 도서관에 없어요':break
    else: count = count+1
fr.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-eb55e042ee1f> in <module>
#       2 count =0
#       3 while True:
# ----> 4     line == fr.readline()
#       5     if line == '제가 참고하고 싶은 책이 도서관에 없어요':break
#       6     else: count = count+1
#
# ~/opt/anaconda3/envs/jh/lib/python3.9/codecs.py in decode(self, input, final)
#     317         raise NotImplementedError
#     318
# --> 319     def decode(self, input, final=False):
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
#
# KeyboardInterrupt:

# %%
print(count)
# Out:
# 0
